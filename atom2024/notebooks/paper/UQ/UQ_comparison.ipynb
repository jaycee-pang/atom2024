# %%
import pyforest

# %% [markdown]
# Look at each model’s uncertainty for the exact same molecule in the test set
#
#
# 1. get all molecules that are used in the test set
# 2. make comparions across all models in the same test set (separate GP/RF)
# 3. maybe try comparing same models but different NEKs
#
#
# The dfs were obtained from the notebook where I got all the compound names and compared their classification type (tn/fp/fn/fp)

# %%
def get_tree_probabilities(model, x_data): 
    test_proba0_df = pd.DataFrame()
    test_proba1_df = pd.DataFrame()
    for tree_num in np.arange(len(model.estimators_)):
        test_proba_temp = model.estimators_[tree_num].predict_proba(x_data)
        test_proba0_df[tree_num] = test_proba_temp[:,0]
        test_proba1_df[tree_num] = test_proba_temp[:,1]
    std0 = test_proba0_df.std(axis=1)
    std1 = test_proba1_df.std(axis=1)
    return std0, std1

# %% [markdown]
# # RF model uncertainty: tree probability agreement

# %%
df_path = '/Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/paper/datasets/80train_20test/featurized/'
neks = ['NEK2_binding', 'NEK2_inhibition', 'NEK3_binding', 'NEK5_binding', 'NEK9_binding', 'NEK9_inhibition']
model_types = ['GP', 'RF']
feat_types=['MOE','MFP']
RF_types = ['RF', 'RF_BCW', 'BRFC', 'BRFC_BCW'] 
samplings = ['none_scaled','UNDER','SMOTE']
rf_path = '/Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/paper/results/RF_results/'
gp_path = '/Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/paper/results/GP_results/'
cmpd_df_path = '/Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/paper/results/compound_TNFPFNTP/'
col_order = ['NEK', 'feat_type', 'strategy','modeling_type', 'compound_id', 'active', 'prediction' , 'RF_type']


for nek in neks:
    for feat in feat_types: 
        for samp in samplings: 
            full_df = pd.read_csv(f'{df_path}{nek}_{feat}_{samp}.csv')
            test=full_df[full_df['subset']=='test'] 
            drop_cols=['NEK'	,'compound_id',	'base_rdkit_smiles',	'subset'	,'active']
            x_data=test.drop(columns=drop_cols).to_numpy()
     
            for rf in RF_types:
                with open(f'{rf_path}{nek}_{feat}_{samp}_{rf}_prod.pkl', 'rb') as f: 
                    model = pickle.load(f) 
                std0, std1=get_tree_probabilities(model, x_data)
                print(f'{nek} {feat} {samp} {rf}')
                model_name=rf
                df = pd.read_csv(f'{cmpd_df_path}{nek}_{feat}_{samp}_{model_name}_cmpd_class.csv')
                df['std0']=std0 # use if 
                df['std1']=std1
                df['UQ_metric_value'] = df.apply(lambda x:x['std0'] if x['prediction_type'] in ['TN','FN'] else x['std1'], axis=1)
                display(df)
                df.to_csv(f'{cmpd_df_path}{nek}_{feat}_{samp}_{model_name}_cmpd_class.csv', index=False)
# Out:
# NEK2_binding MOE none_scaled RF
#               NEK feat_type     strategy modeling_type compound_id  active  \
# 0    NEK2_binding       MOE  none_scaled            RF    kdb_2562       0
# 1    NEK2_binding       MOE  none_scaled            RF    kdb_2854       0
# 2    NEK2_binding       MOE  none_scaled            RF    kdb_2631       0
# 3    NEK2_binding       MOE  none_scaled            RF    kdb_2754       0
# 4    NEK2_binding       MOE  none_scaled            RF    kdb_3508       0
# ..            ...       ...          ...           ...         ...     ...
# 278  NEK2_binding       MOE  none_scaled            RF    kdb_2800       0
# 279  NEK2_binding       MOE  none_scaled            RF    kdb_2110       0
# 280  NEK2_binding       MOE  none_scaled            RF    kdb_2993       0
# 281  NEK2_binding       MOE  none_scaled            RF    kdb_2219       0
# 282  NEK2_binding       MOE  none_scaled            RF    kdb_2275       0
#
#      prediction RF_type prediction_type  std0  std1  UQ_metric_value
# 0             0      RF              TN   0.0   0.0              0.0
# 1             0      RF              TN   0.0   0.0              0.0
# 2             1      RF              FP   0.0   0.0              0.0
# 3             0      RF              TN   0.0   0.0              0.0
# 4             0      RF              TN   0.0   0.0              0.0
# ..          ...     ...             ...   ...   ...              ...
# 278           0      RF              TN   0.0   0.0              0.0
# 279           0      RF              TN   0.0   0.0              0.0
# 280           1      RF              FP   0.0   0.0              0.0
# 281           1      RF              FP   0.5   0.5              0.5
# 282           0      RF              TN   0.0   0.0              0.0
#
# [283 rows x 12 columns]
# NEK2_binding MOE none_scaled RF_BCW
#               NEK feat_type     strategy modeling_type compound_id  active  \
# 0    NEK2_binding       MOE  none_scaled            RF    kdb_2562       0
# 1    NEK2_binding       MOE  none_scaled            RF    kdb_2854       0
# 2    NEK2_binding       MOE  none_scaled            RF    kdb_2631       0
# 3    NEK2_binding       MOE  none_scaled            RF    kdb_2754       0
# 4    NEK2_binding       MOE  none_scaled            RF    kdb_3508       0
# ..            ...       ...          ...           ...         ...     ...
# 278  NEK2_binding       MOE  none_scaled            RF    kdb_2800       0
# 279  NEK2_binding       MOE  none_scaled            RF    kdb_2110       0
# 280  NEK2_binding       MOE  none_scaled            RF    kdb_2993       0
# 281  NEK2_binding       MOE  none_scaled            RF    kdb_2219       0
# 282  NEK2_binding       MOE  none_scaled            RF    kdb_2275       0
#
#      prediction RF_type prediction_type  std0  std1  UQ_metric_value
# 0             0  RF_BCW              TN   0.0   0.0              0.0
# 1             0  RF_BCW              TN   0.0   0.0              0.0
# 2             1  RF_BCW              FP   0.0   0.0              0.0
# 3             0  RF_BCW              TN   0.0   0.0              0.0
# 4             0  RF_BCW              TN   0.0   0.0              0.0
# ..          ...     ...             ...   ...   ...              ...
# 278           0  RF_BCW              TN   0.0   0.0              0.0
# 279           0  RF_BCW              TN   0.0   0.0              0.0
# 280           1  RF_BCW              FP   0.0   0.0              0.0
# 281           1  RF_BCW              FP   0.0   0.0              0.0
# 282           0  RF_BCW              TN   0.0   0.0              0.0
#
# [283 rows x 12 columns]
# NEK2_binding MOE none_scaled BRFC
#               NEK feat_type     strategy modeling_type compound_id  active  \
# 0    NEK2_binding       MOE  none_scaled            RF    kdb_2562       0
# 1    NEK2_binding       MOE  none_scaled            RF    kdb_2854       0
# 2    NEK2_binding       MOE  none_scaled            RF    kdb_2631       0
# 3    NEK2_binding       MOE  none_scaled            RF    kdb_2754       0
# 4    NEK2_binding       MOE  none_scaled            RF    kdb_3508       0
# ..            ...       ...          ...           ...         ...     ...
# 278  NEK2_binding       MOE  none_scaled            RF    kdb_2800       0
# 279  NEK2_binding       MOE  none_scaled            RF    kdb_2110       0
# 280  NEK2_binding       MOE  none_scaled            RF    kdb_2993       0
# 281  NEK2_binding       MOE  none_scaled            RF    kdb_2219       0
# 282  NEK2_binding       MOE  none_scaled            RF    kdb_2275       0
#
#      prediction RF_type prediction_type      std0      std1  UQ_metric_value
# 0             0    BRFC              TN  0.502519  0.502519         0.502519
# 1             0    BRFC              TN  0.456048  0.456048         0.456048
# 2             1    BRFC              FP  0.501614  0.501614         0.501614
# 3             0    BRFC              TN  0.479372  0.479372         0.479372
# 4             0    BRFC              TN  0.468826  0.468826         0.468826
# ..          ...     ...             ...       ...       ...              ...
# 278           0    BRFC              TN  0.500000  0.500000         0.500000
# 279           0    BRFC              TN  0.485237  0.485237         0.485237
# 280           1    BRFC              FP  0.497570  0.497570         0.497570
# 281           1    BRFC              FP  0.435194  0.435194         0.435194
# 282           0    BRFC              TN  0.502418  0.502418         0.502418
#
# [283 rows x 12 columns]
# NEK2_binding MOE none_scaled BRFC_BCW
#               NEK feat_type     strategy modeling_type compound_id  active  \
# 0    NEK2_binding       MOE  none_scaled            RF    kdb_2562       0
# 1    NEK2_binding       MOE  none_scaled            RF    kdb_2854       0
# 2    NEK2_binding       MOE  none_scaled            RF    kdb_2631       0
# 3    NEK2_binding       MOE  none_scaled            RF    kdb_2754       0
# 4    NEK2_binding       MOE  none_scaled            RF    kdb_3508       0
# ..            ...       ...          ...           ...         ...     ...
# 278  NEK2_binding       MOE  none_scaled            RF    kdb_2800       0
# 279  NEK2_binding       MOE  none_scaled            RF    kdb_2110       0
# 280  NEK2_binding       MOE  none_scaled            RF    kdb_2993       0
# 281  NEK2_binding       MOE  none_scaled            RF    kdb_2219       0
# 282  NEK2_binding       MOE  none_scaled            RF    kdb_2275       0
#
#      prediction   RF_type prediction_type      std0      std1  UQ_metric_value
# 0             0  BRFC_BCW              TN  0.219043  0.219043         0.219043
# 1             0  BRFC_BCW              TN  0.487832  0.487832         0.487832
# 2             1  BRFC_BCW              FP  0.487832  0.487832         0.487832
# 3             0  BRFC_BCW              TN  0.337998  0.337998         0.337998
# 4             0  BRFC_BCW              TN  0.402015  0.402015         0.402015
# ..          ...       ...             ...       ...       ...              ...
# 278           0  BRFC_BCW              TN  0.422953  0.422953         0.422953
# 279           0  BRFC_BCW              TN  0.377525  0.377525         0.377525
# 280           1  BRFC_BCW              FP  0.409360  0.409360         0.409360
# 281           1  BRFC_BCW              FP  0.314466  0.314466         0.314466
# 282           0  BRFC_BCW              TN  0.440844  0.440844         0.440844
#
# [283 rows x 12 columns]
# NEK2_binding MOE UNDER RF
#               NEK feat_type strategy modeling_type compound_id  active  \
# 0    NEK2_binding       MOE    UNDER            RF    kdb_2562       0
# 1    NEK2_binding       MOE    UNDER            RF    kdb_2854       0
# 2    NEK2_binding       MOE    UNDER            RF    kdb_2631       0
# 3    NEK2_binding       MOE    UNDER            RF    kdb_2754       0
# 4    NEK2_binding       MOE    UNDER            RF    kdb_3508       0
# ..            ...       ...      ...           ...         ...     ...
# 278  NEK2_binding       MOE    UNDER            RF    kdb_2800       0
# 279  NEK2_binding       MOE    UNDER            RF    kdb_2110       0
# 280  NEK2_binding       MOE    UNDER            RF    kdb_2993       0
# 281  NEK2_binding       MOE    UNDER            RF    kdb_2219       0
# 282  NEK2_binding       MOE    UNDER            RF    kdb_2275       0
#
#      prediction RF_type prediction_type      std0      std1  UQ_metric_value
# 0             1      RF              FP  0.000000  0.000000         0.000000
# 1             0      RF              TN  0.196946  0.196946         0.196946
# 2             1      RF              FP  0.000000  0.000000         0.000000
# 3             0      RF              TN  0.140705  0.140705         0.140705
# 4             1      RF              FP  0.238683  0.238683         0.238683
# ..          ...     ...             ...       ...       ...              ...
# 278           0      RF              TN  0.000000  0.000000         0.000000
# 279           1      RF              FP  0.196946  0.196946         0.196946
# 280           0      RF              TN  0.000000  0.000000         0.000000
# 281           1      RF              FP  0.000000  0.000000         0.000000
# 282           1      RF              FP  0.000000  0.000000         0.000000
#
# [283 rows x 12 columns]
# NEK2_binding MOE UNDER RF_BCW
#               NEK feat_type strategy modeling_type compound_id  active  \
# 0    NEK2_binding       MOE    UNDER            RF    kdb_2562       0
# 1    NEK2_binding       MOE    UNDER            RF    kdb_2854       0
# 2    NEK2_binding       MOE    UNDER            RF    kdb_2631       0
# 3    NEK2_binding       MOE    UNDER            RF    kdb_2754       0
# 4    NEK2_binding       MOE    UNDER            RF    kdb_3508       0
# ..            ...       ...      ...           ...         ...     ...
# 278  NEK2_binding       MOE    UNDER            RF    kdb_2800       0
# 279  NEK2_binding       MOE    UNDER            RF    kdb_2110       0
# 280  NEK2_binding       MOE    UNDER            RF    kdb_2993       0
# 281  NEK2_binding       MOE    UNDER            RF    kdb_2219       0
# 282  NEK2_binding       MOE    UNDER            RF    kdb_2275       0
#
#      prediction RF_type prediction_type      std0      std1  UQ_metric_value
# 0             1  RF_BCW              FP  0.000000  0.000000         0.000000
# 1             0  RF_BCW              TN  0.256432  0.256432         0.256432
# 2             1  RF_BCW              FP  0.000000  0.000000         0.000000
# 3             0  RF_BCW              TN  0.272660  0.272660         0.272660
# 4             1  RF_BCW              FP  0.219043  0.219043         0.219043
# ..          ...     ...             ...       ...       ...              ...
# 278           0  RF_BCW              TN  0.000000  0.000000         0.000000
# 279           1  RF_BCW              FP  0.287623  0.287623         0.287623
# 280           0  RF_BCW              TN  0.000000  0.000000         0.000000
# 281           1  RF_BCW              FP  0.000000  0.000000         0.000000
# 282           1  RF_BCW              FP  0.000000  0.000000         0.000000
#
# [283 rows x 12 columns]
# NEK2_binding MOE UNDER BRFC
#               NEK feat_type strategy modeling_type compound_id  active  \
# 0    NEK2_binding       MOE    UNDER            RF    kdb_2562       0
# 1    NEK2_binding       MOE    UNDER            RF    kdb_2854       0
# 2    NEK2_binding       MOE    UNDER            RF    kdb_2631       0
# 3    NEK2_binding       MOE    UNDER            RF    kdb_2754       0
# 4    NEK2_binding       MOE    UNDER            RF    kdb_3508       0
# ..            ...       ...      ...           ...         ...     ...
# 278  NEK2_binding       MOE    UNDER            RF    kdb_2800       0
# 279  NEK2_binding       MOE    UNDER            RF    kdb_2110       0
# 280  NEK2_binding       MOE    UNDER            RF    kdb_2993       0
# 281  NEK2_binding       MOE    UNDER            RF    kdb_2219       0
# 282  NEK2_binding       MOE    UNDER            RF    kdb_2275       0
#
#      prediction RF_type prediction_type      std0      std1  UQ_metric_value
# 0             1    BRFC              FP  0.000000  0.000000         0.000000
# 1             0    BRFC              TN  0.219043  0.219043         0.219043
# 2             1    BRFC              FP  0.000000  0.000000         0.000000
# 3             0    BRFC              TN  0.272660  0.272660         0.272660
# 4             1    BRFC              FP  0.171447  0.171447         0.171447
# ..          ...     ...             ...       ...       ...              ...
# 278           0    BRFC              TN  0.000000  0.000000         0.000000
# 279           1    BRFC              FP  0.219043  0.219043         0.219043
# 280           0    BRFC              TN  0.000000  0.000000         0.000000
# 281           1    BRFC              FP  0.000000  0.000000         0.000000
# 282           1    BRFC              FP  0.000000  0.000000         0.000000
#
# [283 rows x 12 columns]
# NEK2_binding MOE UNDER BRFC_BCW
#               NEK feat_type strategy modeling_type compound_id  active  \
# 0    NEK2_binding       MOE    UNDER            RF    kdb_2562       0
# 1    NEK2_binding       MOE    UNDER            RF    kdb_2854       0
# 2    NEK2_binding       MOE    UNDER            RF    kdb_2631       0
# 3    NEK2_binding       MOE    UNDER            RF    kdb_2754       0
# 4    NEK2_binding       MOE    UNDER            RF    kdb_3508       0
# ..            ...       ...      ...           ...         ...     ...
# 278  NEK2_binding       MOE    UNDER            RF    kdb_2800       0
# 279  NEK2_binding       MOE    UNDER            RF    kdb_2110       0
# 280  NEK2_binding       MOE    UNDER            RF    kdb_2993       0
# 281  NEK2_binding       MOE    UNDER            RF    kdb_2219       0
# 282  NEK2_binding       MOE    UNDER            RF    kdb_2275       0
#
#      prediction   RF_type prediction_type      std0      std1  UQ_metric_value
# 0             1  BRFC_BCW              FP  0.000000  0.000000         0.000000
# 1             0  BRFC_BCW              TN  0.287623  0.287623         0.287623
# 2             1  BRFC_BCW              FP  0.000000  0.000000         0.000000
# 3             0  BRFC_BCW              TN  0.171447  0.171447         0.171447
# 4             1  BRFC_BCW              FP  0.238683  0.238683         0.238683
# ..          ...       ...             ...       ...       ...              ...
# 278           0  BRFC_BCW              TN  0.000000  0.000000         0.000000
# 279           1  BRFC_BCW              FP  0.140705  0.140705         0.140705
# 280           0  BRFC_BCW              TN  0.000000  0.000000         0.000000
# 281           1  BRFC_BCW              FP  0.000000  0.000000         0.000000
# 282           1  BRFC_BCW              FP  0.000000  0.000000         0.000000
#
# [283 rows x 12 columns]
# NEK2_binding MOE SMOTE RF
#               NEK feat_type strategy modeling_type compound_id  active  \
# 0    NEK2_binding       MOE    SMOTE            RF    kdb_2562       0
# 1    NEK2_binding       MOE    SMOTE            RF    kdb_2854       0
# 2    NEK2_binding       MOE    SMOTE            RF    kdb_2631       0
# 3    NEK2_binding       MOE    SMOTE            RF    kdb_2754       0
# 4    NEK2_binding       MOE    SMOTE            RF    kdb_3508       0
# ..            ...       ...      ...           ...         ...     ...
# 278  NEK2_binding       MOE    SMOTE            RF    kdb_2800       0
# 279  NEK2_binding       MOE    SMOTE            RF    kdb_2110       0
# 280  NEK2_binding       MOE    SMOTE            RF    kdb_2993       0
# 281  NEK2_binding       MOE    SMOTE            RF    kdb_2219       0
# 282  NEK2_binding       MOE    SMOTE            RF    kdb_2275       0
#
#      prediction RF_type prediction_type      std0      std1  UQ_metric_value
# 0             0      RF              TN  0.460566  0.460566         0.460566
# 1             0      RF              TN  0.000000  0.000000         0.000000
# 2             0      RF              TN  0.000000  0.000000         0.000000
# 3             0      RF              TN  0.000000  0.000000         0.000000
# 4             0      RF              TN  0.000000  0.000000         0.000000
# ..          ...     ...             ...       ...       ...              ...
# 278           0      RF              TN  0.000000  0.000000         0.000000
# 279           0      RF              TN  0.000000  0.000000         0.000000
# 280           1      RF              FP  0.219043  0.219043         0.219043
# 281           0      RF              TN  0.000000  0.000000         0.000000
# 282           0      RF              TN  0.000000  0.000000         0.000000
#
# [283 rows x 12 columns]
# NEK2_binding MOE SMOTE RF_BCW
#               NEK feat_type strategy modeling_type compound_id  active  \
# 0    NEK2_binding       MOE    SMOTE            RF    kdb_2562       0
# 1    NEK2_binding       MOE    SMOTE            RF    kdb_2854       0
# 2    NEK2_binding       MOE    SMOTE            RF    kdb_2631       0
# 3    NEK2_binding       MOE    SMOTE            RF    kdb_2754       0
# 4    NEK2_binding       MOE    SMOTE            RF    kdb_3508       0
# ..            ...       ...      ...           ...         ...     ...
# 278  NEK2_binding       MOE    SMOTE            RF    kdb_2800       0
# 279  NEK2_binding       MOE    SMOTE            RF    kdb_2110       0
# 280  NEK2_binding       MOE    SMOTE            RF    kdb_2993       0
# 281  NEK2_binding       MOE    SMOTE            RF    kdb_2219       0
# 282  NEK2_binding       MOE    SMOTE            RF    kdb_2275       0
#
#      prediction RF_type prediction_type      std0      std1  UQ_metric_value
# 0             0  RF_BCW              TN  0.451261  0.451261         0.451261
# 1             0  RF_BCW              TN  0.000000  0.000000         0.000000
# 2             0  RF_BCW              TN  0.000000  0.000000         0.000000
# 3             0  RF_BCW              TN  0.000000  0.000000         0.000000
# 4             0  RF_BCW              TN  0.000000  0.000000         0.000000
# ..          ...     ...             ...       ...       ...              ...
# 278           0  RF_BCW              TN  0.000000  0.000000         0.000000
# 279           0  RF_BCW              TN  0.000000  0.000000         0.000000
# 280           1  RF_BCW              FP  0.272660  0.272660         0.272660
# 281           0  RF_BCW              TN  0.000000  0.000000         0.000000
# 282           0  RF_BCW              TN  0.000000  0.000000         0.000000
#
# [283 rows x 12 columns]
# NEK2_binding MOE SMOTE BRFC
#               NEK feat_type strategy modeling_type compound_id  active  \
# 0    NEK2_binding       MOE    SMOTE            RF    kdb_2562       0
# 1    NEK2_binding       MOE    SMOTE            RF    kdb_2854       0
# 2    NEK2_binding       MOE    SMOTE            RF    kdb_2631       0
# 3    NEK2_binding       MOE    SMOTE            RF    kdb_2754       0
# 4    NEK2_binding       MOE    SMOTE            RF    kdb_3508       0
# ..            ...       ...      ...           ...         ...     ...
# 278  NEK2_binding       MOE    SMOTE            RF    kdb_2800       0
# 279  NEK2_binding       MOE    SMOTE            RF    kdb_2110       0
# 280  NEK2_binding       MOE    SMOTE            RF    kdb_2993       0
# 281  NEK2_binding       MOE    SMOTE            RF    kdb_2219       0
# 282  NEK2_binding       MOE    SMOTE            RF    kdb_2275       0
#
#      prediction RF_type prediction_type      std0      std1  UQ_metric_value
# 0             0    BRFC              TN  0.446196  0.446196         0.446196
# 1             0    BRFC              TN  0.000000  0.000000         0.000000
# 2             0    BRFC              TN  0.000000  0.000000         0.000000
# 3             0    BRFC              TN  0.000000  0.000000         0.000000
# 4             0    BRFC              TN  0.000000  0.000000         0.000000
# ..          ...     ...             ...       ...       ...              ...
# 278           0    BRFC              TN  0.000000  0.000000         0.000000
# 279           0    BRFC              TN  0.000000  0.000000         0.000000
# 280           1    BRFC              FP  0.196946  0.196946         0.196946
# 281           0    BRFC              TN  0.000000  0.000000         0.000000
# 282           0    BRFC              TN  0.000000  0.000000         0.000000
#
# [283 rows x 12 columns]
# NEK2_binding MOE SMOTE BRFC_BCW
#               NEK feat_type strategy modeling_type compound_id  active  \
# 0    NEK2_binding       MOE    SMOTE            RF    kdb_2562       0
# 1    NEK2_binding       MOE    SMOTE            RF    kdb_2854       0
# 2    NEK2_binding       MOE    SMOTE            RF    kdb_2631       0
# 3    NEK2_binding       MOE    SMOTE            RF    kdb_2754       0
# 4    NEK2_binding       MOE    SMOTE            RF    kdb_3508       0
# ..            ...       ...      ...           ...         ...     ...
# 278  NEK2_binding       MOE    SMOTE            RF    kdb_2800       0
# 279  NEK2_binding       MOE    SMOTE            RF    kdb_2110       0
# 280  NEK2_binding       MOE    SMOTE            RF    kdb_2993       0
# 281  NEK2_binding       MOE    SMOTE            RF    kdb_2219       0
# 282  NEK2_binding       MOE    SMOTE            RF    kdb_2275       0
#
#      prediction   RF_type prediction_type      std0      std1  UQ_metric_value
# 0             0  BRFC_BCW              TN  0.435194  0.435194         0.435194
# 1             0  BRFC_BCW              TN  0.000000  0.000000         0.000000
# 2             0  BRFC_BCW              TN  0.000000  0.000000         0.000000
# 3             0  BRFC_BCW              TN  0.000000  0.000000         0.000000
# 4             0  BRFC_BCW              TN  0.000000  0.000000         0.000000
# ..          ...       ...             ...       ...       ...              ...
# 278           0  BRFC_BCW              TN  0.000000  0.000000         0.000000
# 279           0  BRFC_BCW              TN  0.000000  0.000000         0.000000
# 280           1  BRFC_BCW              FP  0.196946  0.196946         0.196946
# 281           0  BRFC_BCW              TN  0.000000  0.000000         0.000000
# 282           0  BRFC_BCW              TN  0.000000  0.000000         0.000000
#
# [283 rows x 12 columns]
# NEK2_binding MFP none_scaled RF
#               NEK feat_type     strategy modeling_type compound_id  active  \
# 0    NEK2_binding       MFP  none_scaled            RF     kdb_115       0
# 1    NEK2_binding       MFP  none_scaled            RF     kdb_120       0
# 2    NEK2_binding       MFP  none_scaled            RF    kdb_1219       0
# 3    NEK2_binding       MFP  none_scaled            RF     kdb_122       0
# 4    NEK2_binding       MFP  none_scaled            RF     kdb_130       0
# ..            ...       ...          ...           ...         ...     ...
# 278  NEK2_binding       MFP  none_scaled            RF    kdb_2667       1
# 279  NEK2_binding       MFP  none_scaled            RF    kdb_2696       1
# 280  NEK2_binding       MFP  none_scaled            RF    kdb_2840       1
# 281  NEK2_binding       MFP  none_scaled            RF    kdb_2863       1
# 282  NEK2_binding       MFP  none_scaled            RF     kdb_980       1
#
#      prediction RF_type prediction_type      std0      std1  UQ_metric_value
# 0             0      RF              TN  0.000000  0.000000         0.000000
# 1             1      RF              FP  0.000000  0.000000         0.000000
# 2             1      RF              FP  0.000000  0.000000         0.000000
# 3             1      RF              FP  0.000000  0.000000         0.000000
# 4             0      RF              TN  0.000000  0.000000         0.000000
# ..          ...     ...             ...       ...       ...              ...
# 278           0      RF              FN  0.140705  0.140705         0.140705
# 279           1      RF              TP  0.000000  0.000000         0.000000
# 280           1      RF              TP  0.000000  0.000000         0.000000
# 281           1      RF              TP  0.000000  0.000000         0.000000
# 282           0      RF              FN  0.000000  0.000000         0.000000
#
# [283 rows x 12 columns]
# NEK2_binding MFP none_scaled RF_BCW
#               NEK feat_type     strategy modeling_type compound_id  active  \
# 0    NEK2_binding       MFP  none_scaled            RF     kdb_115       0
# 1    NEK2_binding       MFP  none_scaled            RF     kdb_120       0
# 2    NEK2_binding       MFP  none_scaled            RF    kdb_1219       0
# 3    NEK2_binding       MFP  none_scaled            RF     kdb_122       0
# 4    NEK2_binding       MFP  none_scaled            RF     kdb_130       0
# ..            ...       ...          ...           ...         ...     ...
# 278  NEK2_binding       MFP  none_scaled            RF    kdb_2667       1
# 279  NEK2_binding       MFP  none_scaled            RF    kdb_2696       1
# 280  NEK2_binding       MFP  none_scaled            RF    kdb_2840       1
# 281  NEK2_binding       MFP  none_scaled            RF    kdb_2863       1
# 282  NEK2_binding       MFP  none_scaled            RF     kdb_980       1
#
#      prediction RF_type prediction_type      std0      std1  UQ_metric_value
# 0             0  RF_BCW              TN  0.000000  0.000000         0.000000
# 1             1  RF_BCW              FP  0.000000  0.000000         0.000000
# 2             1  RF_BCW              FP  0.000000  0.000000         0.000000
# 3             1  RF_BCW              FP  0.000000  0.000000         0.000000
# 4             0  RF_BCW              TN  0.000000  0.000000         0.000000
# ..          ...     ...             ...       ...       ...              ...
# 278           0  RF_BCW              FN  0.386123  0.386123         0.386123
# 279           1  RF_BCW              TP  0.000000  0.000000         0.000000
# 280           1  RF_BCW              TP  0.000000  0.000000         0.000000
# 281           1  RF_BCW              TP  0.000000  0.000000         0.000000
# 282           0  RF_BCW              FN  0.000000  0.000000         0.000000
#
# [283 rows x 12 columns]
# NEK2_binding MFP none_scaled BRFC
#               NEK feat_type     strategy modeling_type compound_id  active  \
# 0    NEK2_binding       MFP  none_scaled            RF     kdb_115       0
# 1    NEK2_binding       MFP  none_scaled            RF     kdb_120       0
# 2    NEK2_binding       MFP  none_scaled            RF    kdb_1219       0
# 3    NEK2_binding       MFP  none_scaled            RF     kdb_122       0
# 4    NEK2_binding       MFP  none_scaled            RF     kdb_130       0
# ..            ...       ...          ...           ...         ...     ...
# 278  NEK2_binding       MFP  none_scaled            RF    kdb_2667       1
# 279  NEK2_binding       MFP  none_scaled            RF    kdb_2696       1
# 280  NEK2_binding       MFP  none_scaled            RF    kdb_2840       1
# 281  NEK2_binding       MFP  none_scaled            RF    kdb_2863       1
# 282  NEK2_binding       MFP  none_scaled            RF     kdb_980       1
#
#      prediction RF_type prediction_type      std0      std1  UQ_metric_value
# 0             0    BRFC              TN  0.479372  0.479372         0.479372
# 1             1    BRFC              FP  0.497570  0.497570         0.497570
# 2             1    BRFC              FP  0.497570  0.497570         0.497570
# 3             1    BRFC              FP  0.456048  0.456048         0.456048
# 4             0    BRFC              TN  0.500000  0.500000         0.500000
# ..          ...     ...             ...       ...       ...              ...
# 278           0    BRFC              FN  0.219043  0.219043         0.219043
# 279           1    BRFC              TP  0.472582  0.472582         0.472582
# 280           1    BRFC              TP  0.314466  0.314466         0.314466
# 281           1    BRFC              TP  0.337998  0.337998         0.337998
# 282           0    BRFC              FN  0.502117  0.502117         0.502117
#
# [283 rows x 12 columns]
# NEK2_binding MFP none_scaled BRFC_BCW
#               NEK feat_type     strategy modeling_type compound_id  active  \
# 0    NEK2_binding       MFP  none_scaled            RF     kdb_115       0
# 1    NEK2_binding       MFP  none_scaled            RF     kdb_120       0
# 2    NEK2_binding       MFP  none_scaled            RF    kdb_1219       0
# 3    NEK2_binding       MFP  none_scaled            RF     kdb_122       0
# 4    NEK2_binding       MFP  none_scaled            RF     kdb_130       0
# ..            ...       ...          ...           ...         ...     ...
# 278  NEK2_binding       MFP  none_scaled            RF    kdb_2667       1
# 279  NEK2_binding       MFP  none_scaled            RF    kdb_2696       1
# 280  NEK2_binding       MFP  none_scaled            RF    kdb_2840       1
# 281  NEK2_binding       MFP  none_scaled            RF    kdb_2863       1
# 282  NEK2_binding       MFP  none_scaled            RF     kdb_980       1
#
#      prediction   RF_type prediction_type      std0      std1  UQ_metric_value
# 0             0  BRFC_BCW              TN  0.256432  0.256432         0.256432
# 1             1  BRFC_BCW              FP  0.435194  0.435194         0.435194
# 2             1  BRFC_BCW              FP  0.497570  0.497570         0.497570
# 3             1  BRFC_BCW              FP  0.394277  0.394277         0.394277
# 4             0  BRFC_BCW              TN  0.496045  0.496045         0.496045
# ..          ...       ...             ...       ...       ...              ...
# 278           0  BRFC_BCW              FN  0.492366  0.492366         0.492366
# 279           1  BRFC_BCW              TP  0.337998  0.337998         0.337998
# 280           1  BRFC_BCW              TP  0.287623  0.287623         0.287623
# 281           1  BRFC_BCW              TP  0.377525  0.377525         0.377525
# 282           0  BRFC_BCW              FN  0.476095  0.476095         0.476095
#
# [283 rows x 12 columns]
# NEK2_binding MFP UNDER RF
#               NEK feat_type strategy modeling_type compound_id  active  \
# 0    NEK2_binding       MFP    UNDER            RF     kdb_115       0
# 1    NEK2_binding       MFP    UNDER            RF     kdb_120       0
# 2    NEK2_binding       MFP    UNDER            RF    kdb_1219       0
# 3    NEK2_binding       MFP    UNDER            RF     kdb_122       0
# 4    NEK2_binding       MFP    UNDER            RF     kdb_130       0
# ..            ...       ...      ...           ...         ...     ...
# 278  NEK2_binding       MFP    UNDER            RF    kdb_2667       1
# 279  NEK2_binding       MFP    UNDER            RF    kdb_2696       1
# 280  NEK2_binding       MFP    UNDER            RF    kdb_2840       1
# 281  NEK2_binding       MFP    UNDER            RF    kdb_2863       1
# 282  NEK2_binding       MFP    UNDER            RF     kdb_980       1
#
#      prediction RF_type prediction_type      std0      std1  UQ_metric_value
# 0             0      RF              TN  0.196946  0.196946         0.196946
# 1             0      RF              TN  0.238683  0.238683         0.238683
# 2             0      RF              TN  0.000000  0.000000         0.000000
# 3             1      RF              FP  0.000000  0.000000         0.000000
# 4             0      RF              TN  0.435194  0.435194         0.435194
# ..          ...     ...             ...       ...       ...              ...
# 278           1      RF              TP  0.000000  0.000000         0.000000
# 279           0      RF              FN  0.000000  0.000000         0.000000
# 280           1      RF              TP  0.000000  0.000000         0.000000
# 281           1      RF              TP  0.000000  0.000000         0.000000
# 282           0      RF              FN  0.301511  0.301511         0.301511
#
# [283 rows x 12 columns]
# NEK2_binding MFP UNDER RF_BCW
#               NEK feat_type strategy modeling_type compound_id  active  \
# 0    NEK2_binding       MFP    UNDER            RF     kdb_115       0
# 1    NEK2_binding       MFP    UNDER            RF     kdb_120       0
# 2    NEK2_binding       MFP    UNDER            RF    kdb_1219       0
# 3    NEK2_binding       MFP    UNDER            RF     kdb_122       0
# 4    NEK2_binding       MFP    UNDER            RF     kdb_130       0
# ..            ...       ...      ...           ...         ...     ...
# 278  NEK2_binding       MFP    UNDER            RF    kdb_2667       1
# 279  NEK2_binding       MFP    UNDER            RF    kdb_2696       1
# 280  NEK2_binding       MFP    UNDER            RF    kdb_2840       1
# 281  NEK2_binding       MFP    UNDER            RF    kdb_2863       1
# 282  NEK2_binding       MFP    UNDER            RF     kdb_980       1
#
#      prediction RF_type prediction_type      std0      std1  UQ_metric_value
# 0             0  RF_BCW              TN  0.238683  0.238683         0.238683
# 1             0  RF_BCW              TN  0.171447  0.171447         0.171447
# 2             0  RF_BCW              TN  0.000000  0.000000         0.000000
# 3             1  RF_BCW              FP  0.000000  0.000000         0.000000
# 4             0  RF_BCW              TN  0.456048  0.456048         0.456048
# ..          ...     ...             ...       ...       ...              ...
# 278           1  RF_BCW              TP  0.000000  0.000000         0.000000
# 279           0  RF_BCW              FN  0.000000  0.000000         0.000000
# 280           1  RF_BCW              TP  0.000000  0.000000         0.000000
# 281           1  RF_BCW              TP  0.000000  0.000000         0.000000
# 282           0  RF_BCW              FN  0.256432  0.256432         0.256432
#
# [283 rows x 12 columns]
# NEK2_binding MFP UNDER BRFC
#               NEK feat_type strategy modeling_type compound_id  active  \
# 0    NEK2_binding       MFP    UNDER            RF     kdb_115       0
# 1    NEK2_binding       MFP    UNDER            RF     kdb_120       0
# 2    NEK2_binding       MFP    UNDER            RF    kdb_1219       0
# 3    NEK2_binding       MFP    UNDER            RF     kdb_122       0
# 4    NEK2_binding       MFP    UNDER            RF     kdb_130       0
# ..            ...       ...      ...           ...         ...     ...
# 278  NEK2_binding       MFP    UNDER            RF    kdb_2667       1
# 279  NEK2_binding       MFP    UNDER            RF    kdb_2696       1
# 280  NEK2_binding       MFP    UNDER            RF    kdb_2840       1
# 281  NEK2_binding       MFP    UNDER            RF    kdb_2863       1
# 282  NEK2_binding       MFP    UNDER            RF     kdb_980       1
#
#      prediction RF_type prediction_type      std0      std1  UQ_metric_value
# 0             0    BRFC              TN  0.238683  0.238683         0.238683
# 1             0    BRFC              TN  0.171447  0.171447         0.171447
# 2             0    BRFC              TN  0.000000  0.000000         0.000000
# 3             1    BRFC              FP  0.000000  0.000000         0.000000
# 4             0    BRFC              TN  0.460566  0.460566         0.460566
# ..          ...     ...             ...       ...       ...              ...
# 278           1    BRFC              TP  0.000000  0.000000         0.000000
# 279           0    BRFC              FN  0.000000  0.000000         0.000000
# 280           1    BRFC              TP  0.000000  0.000000         0.000000
# 281           1    BRFC              TP  0.000000  0.000000         0.000000
# 282           0    BRFC              FN  0.196946  0.196946         0.196946
#
# [283 rows x 12 columns]
# NEK2_binding MFP UNDER BRFC_BCW
#               NEK feat_type strategy modeling_type compound_id  active  \
# 0    NEK2_binding       MFP    UNDER            RF     kdb_115       0
# 1    NEK2_binding       MFP    UNDER            RF     kdb_120       0
# 2    NEK2_binding       MFP    UNDER            RF    kdb_1219       0
# 3    NEK2_binding       MFP    UNDER            RF     kdb_122       0
# 4    NEK2_binding       MFP    UNDER            RF     kdb_130       0
# ..            ...       ...      ...           ...         ...     ...
# 278  NEK2_binding       MFP    UNDER            RF    kdb_2667       1
# 279  NEK2_binding       MFP    UNDER            RF    kdb_2696       1
# 280  NEK2_binding       MFP    UNDER            RF    kdb_2840       1
# 281  NEK2_binding       MFP    UNDER            RF    kdb_2863       1
# 282  NEK2_binding       MFP    UNDER            RF     kdb_980       1
#
#      prediction   RF_type prediction_type      std0      std1  UQ_metric_value
# 0             0  BRFC_BCW              TN  0.238683  0.238683         0.238683
# 1             0  BRFC_BCW              TN  0.196946  0.196946         0.196946
# 2             0  BRFC_BCW              TN  0.000000  0.000000         0.000000
# 3             1  BRFC_BCW              FP  0.000000  0.000000         0.000000
# 4             0  BRFC_BCW              TN  0.472582  0.472582         0.472582
# ..          ...       ...             ...       ...       ...              ...
# 278           1  BRFC_BCW              TP  0.000000  0.000000         0.000000
# 279           0  BRFC_BCW              FN  0.000000  0.000000         0.000000
# 280           1  BRFC_BCW              TP  0.000000  0.000000         0.000000
# 281           1  BRFC_BCW              TP  0.000000  0.000000         0.000000
# 282           0  BRFC_BCW              FN  0.272660  0.272660         0.272660
#
# [283 rows x 12 columns]
# NEK2_binding MFP SMOTE RF
#               NEK feat_type strategy modeling_type compound_id  active  \
# 0    NEK2_binding       MFP    SMOTE            RF     kdb_115       0
# 1    NEK2_binding       MFP    SMOTE            RF     kdb_120       0
# 2    NEK2_binding       MFP    SMOTE            RF    kdb_1219       0
# 3    NEK2_binding       MFP    SMOTE            RF     kdb_122       0
# 4    NEK2_binding       MFP    SMOTE            RF     kdb_130       0
# ..            ...       ...      ...           ...         ...     ...
# 278  NEK2_binding       MFP    SMOTE            RF    kdb_2667       1
# 279  NEK2_binding       MFP    SMOTE            RF    kdb_2696       1
# 280  NEK2_binding       MFP    SMOTE            RF    kdb_2840       1
# 281  NEK2_binding       MFP    SMOTE            RF    kdb_2863       1
# 282  NEK2_binding       MFP    SMOTE            RF     kdb_980       1
#
#      prediction RF_type prediction_type  std0  std1  UQ_metric_value
# 0             0      RF              TN   0.0   0.0              0.0
# 1             0      RF              TN   0.0   0.0              0.0
# 2             0      RF              TN   0.0   0.0              0.0
# 3             0      RF              TN   0.0   0.0              0.0
# 4             0      RF              TN   0.0   0.0              0.0
# ..          ...     ...             ...   ...   ...              ...
# 278           0      RF              FN   0.0   0.0              0.0
# 279           0      RF              FN   0.0   0.0              0.0
# 280           1      RF              TP   0.0   0.0              0.0
# 281           0      RF              FN   0.0   0.0              0.0
# 282           0      RF              FN   0.0   0.0              0.0
#
# [283 rows x 12 columns]
# NEK2_binding MFP SMOTE RF_BCW
#               NEK feat_type strategy modeling_type compound_id  active  \
# 0    NEK2_binding       MFP    SMOTE            RF     kdb_115       0
# 1    NEK2_binding       MFP    SMOTE            RF     kdb_120       0
# 2    NEK2_binding       MFP    SMOTE            RF    kdb_1219       0
# 3    NEK2_binding       MFP    SMOTE            RF     kdb_122       0
# 4    NEK2_binding       MFP    SMOTE            RF     kdb_130       0
# ..            ...       ...      ...           ...         ...     ...
# 278  NEK2_binding       MFP    SMOTE            RF    kdb_2667       1
# 279  NEK2_binding       MFP    SMOTE            RF    kdb_2696       1
# 280  NEK2_binding       MFP    SMOTE            RF    kdb_2840       1
# 281  NEK2_binding       MFP    SMOTE            RF    kdb_2863       1
# 282  NEK2_binding       MFP    SMOTE            RF     kdb_980       1
#
#      prediction RF_type prediction_type  std0  std1  UQ_metric_value
# 0             0  RF_BCW              TN   0.0   0.0              0.0
# 1             0  RF_BCW              TN   0.0   0.0              0.0
# 2             0  RF_BCW              TN   0.0   0.0              0.0
# 3             0  RF_BCW              TN   0.0   0.0              0.0
# 4             0  RF_BCW              TN   0.0   0.0              0.0
# ..          ...     ...             ...   ...   ...              ...
# 278           0  RF_BCW              FN   0.0   0.0              0.0
# 279           0  RF_BCW              FN   0.0   0.0              0.0
# 280           1  RF_BCW              TP   0.0   0.0              0.0
# 281           0  RF_BCW              FN   0.0   0.0              0.0
# 282           0  RF_BCW              FN   0.0   0.0              0.0
#
# [283 rows x 12 columns]
# NEK2_binding MFP SMOTE BRFC
#               NEK feat_type strategy modeling_type compound_id  active  \
# 0    NEK2_binding       MFP    SMOTE            RF     kdb_115       0
# 1    NEK2_binding       MFP    SMOTE            RF     kdb_120       0
# 2    NEK2_binding       MFP    SMOTE            RF    kdb_1219       0
# 3    NEK2_binding       MFP    SMOTE            RF     kdb_122       0
# 4    NEK2_binding       MFP    SMOTE            RF     kdb_130       0
# ..            ...       ...      ...           ...         ...     ...
# 278  NEK2_binding       MFP    SMOTE            RF    kdb_2667       1
# 279  NEK2_binding       MFP    SMOTE            RF    kdb_2696       1
# 280  NEK2_binding       MFP    SMOTE            RF    kdb_2840       1
# 281  NEK2_binding       MFP    SMOTE            RF    kdb_2863       1
# 282  NEK2_binding       MFP    SMOTE            RF     kdb_980       1
#
#      prediction RF_type prediction_type  std0  std1  UQ_metric_value
# 0             0    BRFC              TN   0.0   0.0              0.0
# 1             0    BRFC              TN   0.0   0.0              0.0
# 2             0    BRFC              TN   0.0   0.0              0.0
# 3             0    BRFC              TN   0.0   0.0              0.0
# 4             0    BRFC              TN   0.0   0.0              0.0
# ..          ...     ...             ...   ...   ...              ...
# 278           0    BRFC              FN   0.0   0.0              0.0
# 279           0    BRFC              FN   0.0   0.0              0.0
# 280           1    BRFC              TP   0.0   0.0              0.0
# 281           0    BRFC              FN   0.0   0.0              0.0
# 282           0    BRFC              FN   0.0   0.0              0.0
#
# [283 rows x 12 columns]
# NEK2_binding MFP SMOTE BRFC_BCW
#               NEK feat_type strategy modeling_type compound_id  active  \
# 0    NEK2_binding       MFP    SMOTE            RF     kdb_115       0
# 1    NEK2_binding       MFP    SMOTE            RF     kdb_120       0
# 2    NEK2_binding       MFP    SMOTE            RF    kdb_1219       0
# 3    NEK2_binding       MFP    SMOTE            RF     kdb_122       0
# 4    NEK2_binding       MFP    SMOTE            RF     kdb_130       0
# ..            ...       ...      ...           ...         ...     ...
# 278  NEK2_binding       MFP    SMOTE            RF    kdb_2667       1
# 279  NEK2_binding       MFP    SMOTE            RF    kdb_2696       1
# 280  NEK2_binding       MFP    SMOTE            RF    kdb_2840       1
# 281  NEK2_binding       MFP    SMOTE            RF    kdb_2863       1
# 282  NEK2_binding       MFP    SMOTE            RF     kdb_980       1
#
#      prediction   RF_type prediction_type  std0  std1  UQ_metric_value
# 0             0  BRFC_BCW              TN   0.0   0.0              0.0
# 1             0  BRFC_BCW              TN   0.0   0.0              0.0
# 2             0  BRFC_BCW              TN   0.0   0.0              0.0
# 3             0  BRFC_BCW              TN   0.0   0.0              0.0
# 4             0  BRFC_BCW              TN   0.0   0.0              0.0
# ..          ...       ...             ...   ...   ...              ...
# 278           0  BRFC_BCW              FN   0.0   0.0              0.0
# 279           0  BRFC_BCW              FN   0.0   0.0              0.0
# 280           1  BRFC_BCW              TP   0.0   0.0              0.0
# 281           0  BRFC_BCW              FN   0.0   0.0              0.0
# 282           0  BRFC_BCW              FN   0.0   0.0              0.0
#
# [283 rows x 12 columns]
# NEK2_inhibition MOE none_scaled RF
#                  NEK feat_type     strategy modeling_type compound_id  active  \
# 0    NEK2_inhibition       MOE  none_scaled            RF     kdb_819       1
# 1    NEK2_inhibition       MOE  none_scaled            RF     kdb_952       0
# 2    NEK2_inhibition       MOE  none_scaled            RF     kdb_682       0
# 3    NEK2_inhibition       MOE  none_scaled            RF    kdb_1216       0
# 4    NEK2_inhibition       MOE  none_scaled            RF     kdb_481       0
# ..               ...       ...          ...           ...         ...     ...
# 402  NEK2_inhibition       MOE  none_scaled            RF    kdb_1458       0
# 403  NEK2_inhibition       MOE  none_scaled            RF    kdb_3179       0
# 404  NEK2_inhibition       MOE  none_scaled            RF     kdb_794       0
# 405  NEK2_inhibition       MOE  none_scaled            RF     kdb_687       0
# 406  NEK2_inhibition       MOE  none_scaled            RF     kdb_875       0
#
#      prediction RF_type prediction_type  std0  std1  UQ_metric_value
# 0             0      RF              FN   0.0   0.0              0.0
# 1             0      RF              TN   0.0   0.0              0.0
# 2             0      RF              TN   0.0   0.0              0.0
# 3             0      RF              TN   0.0   0.0              0.0
# 4             0      RF              TN   0.0   0.0              0.0
# ..          ...     ...             ...   ...   ...              ...
# 402           1      RF              FP   0.0   0.0              0.0
# 403           1      RF              FP   0.0   0.0              0.0
# 404           0      RF              TN   0.0   0.0              0.0
# 405           0      RF              TN   0.0   0.0              0.0
# 406           1      RF              FP   0.0   0.0              0.0
#
# [407 rows x 12 columns]
# NEK2_inhibition MOE none_scaled RF_BCW
#                  NEK feat_type     strategy modeling_type compound_id  active  \
# 0    NEK2_inhibition       MOE  none_scaled            RF     kdb_819       1
# 1    NEK2_inhibition       MOE  none_scaled            RF     kdb_952       0
# 2    NEK2_inhibition       MOE  none_scaled            RF     kdb_682       0
# 3    NEK2_inhibition       MOE  none_scaled            RF    kdb_1216       0
# 4    NEK2_inhibition       MOE  none_scaled            RF     kdb_481       0
# ..               ...       ...          ...           ...         ...     ...
# 402  NEK2_inhibition       MOE  none_scaled            RF    kdb_1458       0
# ...
# 79  NEK9_inhibition       MFP  none_scaled            RF    kdb_3772       1
#
#     prediction   RF_type prediction_type      std0      std1  UQ_metric_value
# 0            0  BRFC_BCW              TN  0.272660  0.272660         0.272660
# 1            0  BRFC_BCW              TN  0.494311  0.494311         0.494311
# 2            0  BRFC_BCW              TN  0.394277  0.394277         0.394277
# 3            0  BRFC_BCW              TN  0.000000  0.000000         0.000000
# 4            0  BRFC_BCW              TN  0.238683  0.238683         0.238683
# ..         ...       ...             ...       ...       ...              ...
# 75           1  BRFC_BCW              TP  0.000000  0.000000         0.000000
# 76           1  BRFC_BCW              TP  0.000000  0.000000         0.000000
# 77           1  BRFC_BCW              TP  0.446196  0.446196         0.446196
# 78           1  BRFC_BCW              TP  0.000000  0.000000         0.000000
# 79           1  BRFC_BCW              TP  0.171447  0.171447         0.171447
#
# [80 rows x 12 columns]
# NEK9_inhibition MFP UNDER RF
#                 NEK feat_type strategy modeling_type compound_id  active  \
# 0   NEK9_inhibition       MFP    UNDER            RF    kdb_2013       0
# 1   NEK9_inhibition       MFP    UNDER            RF    kdb_2205       0
# 2   NEK9_inhibition       MFP    UNDER            RF    kdb_2212       0
# 3   NEK9_inhibition       MFP    UNDER            RF    kdb_2227       0
# 4   NEK9_inhibition       MFP    UNDER            RF    kdb_2230       0
# ..              ...       ...      ...           ...         ...     ...
# 75  NEK9_inhibition       MFP    UNDER            RF    kdb_3756       1
# 76  NEK9_inhibition       MFP    UNDER            RF    kdb_3757       1
# 77  NEK9_inhibition       MFP    UNDER            RF    kdb_3761       1
# 78  NEK9_inhibition       MFP    UNDER            RF    kdb_3762       1
# 79  NEK9_inhibition       MFP    UNDER            RF    kdb_3772       1
#
#     prediction RF_type prediction_type  std0  std1  UQ_metric_value
# 0            0      RF              TN   0.0   0.0              0.0
# 1            0      RF              TN   0.0   0.0              0.0
# 2            0      RF              TN   0.0   0.0              0.0
# 3            0      RF              TN   0.0   0.0              0.0
# 4            0      RF              TN   0.0   0.0              0.0
# ..         ...     ...             ...   ...   ...              ...
# 75           1      RF              TP   0.0   0.0              0.0
# 76           1      RF              TP   0.0   0.0              0.0
# 77           1      RF              TP   0.0   0.0              0.0
# 78           1      RF              TP   0.0   0.0              0.0
# 79           1      RF              TP   0.0   0.0              0.0
#
# [80 rows x 12 columns]
# NEK9_inhibition MFP UNDER RF_BCW
#                 NEK feat_type strategy modeling_type compound_id  active  \
# 0   NEK9_inhibition       MFP    UNDER            RF    kdb_2013       0
# 1   NEK9_inhibition       MFP    UNDER            RF    kdb_2205       0
# 2   NEK9_inhibition       MFP    UNDER            RF    kdb_2212       0
# 3   NEK9_inhibition       MFP    UNDER            RF    kdb_2227       0
# 4   NEK9_inhibition       MFP    UNDER            RF    kdb_2230       0
# ..              ...       ...      ...           ...         ...     ...
# 75  NEK9_inhibition       MFP    UNDER            RF    kdb_3756       1
# 76  NEK9_inhibition       MFP    UNDER            RF    kdb_3757       1
# 77  NEK9_inhibition       MFP    UNDER            RF    kdb_3761       1
# 78  NEK9_inhibition       MFP    UNDER            RF    kdb_3762       1
# 79  NEK9_inhibition       MFP    UNDER            RF    kdb_3772       1
#
#     prediction RF_type prediction_type  std0  std1  UQ_metric_value
# 0            0  RF_BCW              TN   0.0   0.0              0.0
# 1            0  RF_BCW              TN   0.0   0.0              0.0
# 2            0  RF_BCW              TN   0.0   0.0              0.0
# 3            0  RF_BCW              TN   0.0   0.0              0.0
# 4            0  RF_BCW              TN   0.0   0.0              0.0
# ..         ...     ...             ...   ...   ...              ...
# 75           1  RF_BCW              TP   0.0   0.0              0.0
# 76           1  RF_BCW              TP   0.0   0.0              0.0
# 77           1  RF_BCW              TP   0.0   0.0              0.0
# 78           1  RF_BCW              TP   0.0   0.0              0.0
# 79           1  RF_BCW              TP   0.0   0.0              0.0
#
# [80 rows x 12 columns]
# NEK9_inhibition MFP UNDER BRFC
#                 NEK feat_type strategy modeling_type compound_id  active  \
# 0   NEK9_inhibition       MFP    UNDER            RF    kdb_2013       0
# 1   NEK9_inhibition       MFP    UNDER            RF    kdb_2205       0
# 2   NEK9_inhibition       MFP    UNDER            RF    kdb_2212       0
# 3   NEK9_inhibition       MFP    UNDER            RF    kdb_2227       0
# 4   NEK9_inhibition       MFP    UNDER            RF    kdb_2230       0
# ..              ...       ...      ...           ...         ...     ...
# 75  NEK9_inhibition       MFP    UNDER            RF    kdb_3756       1
# 76  NEK9_inhibition       MFP    UNDER            RF    kdb_3757       1
# 77  NEK9_inhibition       MFP    UNDER            RF    kdb_3761       1
# 78  NEK9_inhibition       MFP    UNDER            RF    kdb_3762       1
# 79  NEK9_inhibition       MFP    UNDER            RF    kdb_3772       1
#
#     prediction RF_type prediction_type  std0  std1  UQ_metric_value
# 0            0    BRFC              TN   0.0   0.0              0.0
# 1            0    BRFC              TN   0.0   0.0              0.0
# 2            0    BRFC              TN   0.0   0.0              0.0
# 3            0    BRFC              TN   0.0   0.0              0.0
# 4            0    BRFC              TN   0.0   0.0              0.0
# ..         ...     ...             ...   ...   ...              ...
# 75           1    BRFC              TP   0.0   0.0              0.0
# 76           1    BRFC              TP   0.0   0.0              0.0
# 77           1    BRFC              TP   0.0   0.0              0.0
# 78           1    BRFC              TP   0.0   0.0              0.0
# 79           1    BRFC              TP   0.0   0.0              0.0
#
# [80 rows x 12 columns]
# NEK9_inhibition MFP UNDER BRFC_BCW
#                 NEK feat_type strategy modeling_type compound_id  active  \
# 0   NEK9_inhibition       MFP    UNDER            RF    kdb_2013       0
# 1   NEK9_inhibition       MFP    UNDER            RF    kdb_2205       0
# 2   NEK9_inhibition       MFP    UNDER            RF    kdb_2212       0
# 3   NEK9_inhibition       MFP    UNDER            RF    kdb_2227       0
# 4   NEK9_inhibition       MFP    UNDER            RF    kdb_2230       0
# ..              ...       ...      ...           ...         ...     ...
# 75  NEK9_inhibition       MFP    UNDER            RF    kdb_3756       1
# 76  NEK9_inhibition       MFP    UNDER            RF    kdb_3757       1
# 77  NEK9_inhibition       MFP    UNDER            RF    kdb_3761       1
# 78  NEK9_inhibition       MFP    UNDER            RF    kdb_3762       1
# 79  NEK9_inhibition       MFP    UNDER            RF    kdb_3772       1
#
#     prediction   RF_type prediction_type  std0  std1  UQ_metric_value
# 0            0  BRFC_BCW              TN   0.0   0.0              0.0
# 1            0  BRFC_BCW              TN   0.0   0.0              0.0
# 2            0  BRFC_BCW              TN   0.0   0.0              0.0
# 3            0  BRFC_BCW              TN   0.0   0.0              0.0
# 4            0  BRFC_BCW              TN   0.0   0.0              0.0
# ..         ...       ...             ...   ...   ...              ...
# 75           1  BRFC_BCW              TP   0.0   0.0              0.0
# 76           1  BRFC_BCW              TP   0.0   0.0              0.0
# 77           1  BRFC_BCW              TP   0.0   0.0              0.0
# 78           1  BRFC_BCW              TP   0.0   0.0              0.0
# 79           1  BRFC_BCW              TP   0.0   0.0              0.0
#
# [80 rows x 12 columns]
# NEK9_inhibition MFP SMOTE RF
#                 NEK feat_type strategy modeling_type compound_id  active  \
# 0   NEK9_inhibition       MFP    SMOTE            RF    kdb_2013       0
# 1   NEK9_inhibition       MFP    SMOTE            RF    kdb_2205       0
# 2   NEK9_inhibition       MFP    SMOTE            RF    kdb_2212       0
# 3   NEK9_inhibition       MFP    SMOTE            RF    kdb_2227       0
# 4   NEK9_inhibition       MFP    SMOTE            RF    kdb_2230       0
# ..              ...       ...      ...           ...         ...     ...
# 75  NEK9_inhibition       MFP    SMOTE            RF    kdb_3756       1
# 76  NEK9_inhibition       MFP    SMOTE            RF    kdb_3757       1
# 77  NEK9_inhibition       MFP    SMOTE            RF    kdb_3761       1
# 78  NEK9_inhibition       MFP    SMOTE            RF    kdb_3762       1
# 79  NEK9_inhibition       MFP    SMOTE            RF    kdb_3772       1
#
#     prediction RF_type prediction_type      std0      std1  UQ_metric_value
# 0            0      RF              TN  0.000000  0.000000         0.000000
# 1            0      RF              TN  0.256432  0.256432         0.256432
# 2            0      RF              TN  0.000000  0.000000         0.000000
# 3            0      RF              TN  0.000000  0.000000         0.000000
# 4            0      RF              TN  0.000000  0.000000         0.000000
# ..         ...     ...             ...       ...       ...              ...
# 75           1      RF              TP  0.000000  0.000000         0.000000
# 76           1      RF              TP  0.000000  0.000000         0.000000
# 77           1      RF              TP  0.377525  0.377525         0.377525
# 78           1      RF              TP  0.000000  0.000000         0.000000
# 79           1      RF              TP  0.000000  0.000000         0.000000
#
# [80 rows x 12 columns]
# NEK9_inhibition MFP SMOTE RF_BCW
#                 NEK feat_type strategy modeling_type compound_id  active  \
# 0   NEK9_inhibition       MFP    SMOTE            RF    kdb_2013       0
# 1   NEK9_inhibition       MFP    SMOTE            RF    kdb_2205       0
# 2   NEK9_inhibition       MFP    SMOTE            RF    kdb_2212       0
# 3   NEK9_inhibition       MFP    SMOTE            RF    kdb_2227       0
# 4   NEK9_inhibition       MFP    SMOTE            RF    kdb_2230       0
# ..              ...       ...      ...           ...         ...     ...
# 75  NEK9_inhibition       MFP    SMOTE            RF    kdb_3756       1
# 76  NEK9_inhibition       MFP    SMOTE            RF    kdb_3757       1
# 77  NEK9_inhibition       MFP    SMOTE            RF    kdb_3761       1
# 78  NEK9_inhibition       MFP    SMOTE            RF    kdb_3762       1
# 79  NEK9_inhibition       MFP    SMOTE            RF    kdb_3772       1
#
#     prediction RF_type prediction_type      std0      std1  UQ_metric_value
# 0            0  RF_BCW              TN  0.000000  0.000000         0.000000
# 1            0  RF_BCW              TN  0.256432  0.256432         0.256432
# 2            0  RF_BCW              TN  0.000000  0.000000         0.000000
# 3            0  RF_BCW              TN  0.000000  0.000000         0.000000
# 4            0  RF_BCW              TN  0.000000  0.000000         0.000000
# ..         ...     ...             ...       ...       ...              ...
# 75           1  RF_BCW              TP  0.000000  0.000000         0.000000
# 76           1  RF_BCW              TP  0.000000  0.000000         0.000000
# 77           1  RF_BCW              TP  0.394277  0.394277         0.394277
# 78           1  RF_BCW              TP  0.000000  0.000000         0.000000
# 79           1  RF_BCW              TP  0.000000  0.000000         0.000000
#
# [80 rows x 12 columns]
# NEK9_inhibition MFP SMOTE BRFC
#                 NEK feat_type strategy modeling_type compound_id  active  \
# 0   NEK9_inhibition       MFP    SMOTE            RF    kdb_2013       0
# 1   NEK9_inhibition       MFP    SMOTE            RF    kdb_2205       0
# 2   NEK9_inhibition       MFP    SMOTE            RF    kdb_2212       0
# 3   NEK9_inhibition       MFP    SMOTE            RF    kdb_2227       0
# 4   NEK9_inhibition       MFP    SMOTE            RF    kdb_2230       0
# ..              ...       ...      ...           ...         ...     ...
# 75  NEK9_inhibition       MFP    SMOTE            RF    kdb_3756       1
# 76  NEK9_inhibition       MFP    SMOTE            RF    kdb_3757       1
# 77  NEK9_inhibition       MFP    SMOTE            RF    kdb_3761       1
# 78  NEK9_inhibition       MFP    SMOTE            RF    kdb_3762       1
# 79  NEK9_inhibition       MFP    SMOTE            RF    kdb_3772       1
#
#     prediction RF_type prediction_type      std0      std1  UQ_metric_value
# 0            0    BRFC              TN  0.000000  0.000000         0.000000
# 1            0    BRFC              TN  0.219043  0.219043         0.219043
# 2            0    BRFC              TN  0.000000  0.000000         0.000000
# 3            0    BRFC              TN  0.000000  0.000000         0.000000
# 4            0    BRFC              TN  0.000000  0.000000         0.000000
# ..         ...     ...             ...       ...       ...              ...
# 75           1    BRFC              TP  0.000000  0.000000         0.000000
# 76           1    BRFC              TP  0.000000  0.000000         0.000000
# 77           1    BRFC              TP  0.435194  0.435194         0.435194
# 78           1    BRFC              TP  0.000000  0.000000         0.000000
# 79           1    BRFC              TP  0.000000  0.000000         0.000000
#
# [80 rows x 12 columns]
# NEK9_inhibition MFP SMOTE BRFC_BCW
#                 NEK feat_type strategy modeling_type compound_id  active  \
# 0   NEK9_inhibition       MFP    SMOTE            RF    kdb_2013       0
# 1   NEK9_inhibition       MFP    SMOTE            RF    kdb_2205       0
# 2   NEK9_inhibition       MFP    SMOTE            RF    kdb_2212       0
# 3   NEK9_inhibition       MFP    SMOTE            RF    kdb_2227       0
# 4   NEK9_inhibition       MFP    SMOTE            RF    kdb_2230       0
# ..              ...       ...      ...           ...         ...     ...
# 75  NEK9_inhibition       MFP    SMOTE            RF    kdb_3756       1
# 76  NEK9_inhibition       MFP    SMOTE            RF    kdb_3757       1
# 77  NEK9_inhibition       MFP    SMOTE            RF    kdb_3761       1
# 78  NEK9_inhibition       MFP    SMOTE            RF    kdb_3762       1
# 79  NEK9_inhibition       MFP    SMOTE            RF    kdb_3772       1
#
#     prediction   RF_type prediction_type      std0      std1  UQ_metric_value
# 0            0  BRFC_BCW              TN  0.000000  0.000000         0.000000
# 1            0  BRFC_BCW              TN  0.238683  0.238683         0.238683
# 2            0  BRFC_BCW              TN  0.000000  0.000000         0.000000
# 3            0  BRFC_BCW              TN  0.000000  0.000000         0.000000
# 4            0  BRFC_BCW              TN  0.000000  0.000000         0.000000
# ..         ...       ...             ...       ...       ...              ...
# 75           1  BRFC_BCW              TP  0.000000  0.000000         0.000000
# 76           1  BRFC_BCW              TP  0.000000  0.000000         0.000000
# 77           1  BRFC_BCW              TP  0.409360  0.409360         0.409360
# 78           1  BRFC_BCW              TP  0.000000  0.000000         0.000000
# 79           1  BRFC_BCW              TP  0.000000  0.000000         0.000000
#
# [80 rows x 12 columns]

# %% [markdown]
# # GP uncertainty: predictive variance

# %%
for nek in neks:
    for feat in feat_types: 
        for samp in samplings: 
            results_df = pd.read_csv(f'{gp_path}{nek}_{feat}_{samp}_matern_prod_test.csv')
            print(f'{nek} {feat} {samp} GP_matern')
            df = pd.read_csv(f'{cmpd_df_path}{nek}_{feat}_{samp}_GP_matern_cmpd_class.csv')
            df['var0']=results_df['var_pred_class0']
            df['var1']=results_df['var_pred_class1']
            df['UQ_metric_value'] = df.apply(lambda x:x['var0'] if x['prediction_type'] in ['TN','FN'] else x['var1'], axis=1)
            df.to_csv(f'{cmpd_df_path}{nek}_{feat}_{samp}_{model_name}_GP_matern_cmpd_class.csv', index=False)
# Out:
# NEK2_binding MOE none_scaled GP_matern
# NEK2_binding MOE UNDER GP_matern
# NEK2_binding MOE SMOTE GP_matern
# NEK2_binding MFP none_scaled GP_matern
# NEK2_binding MFP UNDER GP_matern
# NEK2_binding MFP SMOTE GP_matern
# NEK2_inhibition MOE none_scaled GP_matern
# NEK2_inhibition MOE UNDER GP_matern
# NEK2_inhibition MOE SMOTE GP_matern
# NEK2_inhibition MFP none_scaled GP_matern
# NEK2_inhibition MFP UNDER GP_matern
# NEK2_inhibition MFP SMOTE GP_matern
# NEK3_binding MOE none_scaled GP_matern
# NEK3_binding MOE UNDER GP_matern
# NEK3_binding MOE SMOTE GP_matern
# NEK3_binding MFP none_scaled GP_matern
# NEK3_binding MFP UNDER GP_matern
# NEK3_binding MFP SMOTE GP_matern
# NEK5_binding MOE none_scaled GP_matern
# NEK5_binding MOE UNDER GP_matern
# NEK5_binding MOE SMOTE GP_matern
# NEK5_binding MFP none_scaled GP_matern
# NEK5_binding MFP UNDER GP_matern
# NEK5_binding MFP SMOTE GP_matern
# NEK9_binding MOE none_scaled GP_matern
# NEK9_binding MOE UNDER GP_matern
# NEK9_binding MOE SMOTE GP_matern
# NEK9_binding MFP none_scaled GP_matern
# NEK9_binding MFP UNDER GP_matern
# NEK9_binding MFP SMOTE GP_matern
# NEK9_inhibition MOE none_scaled GP_matern
# NEK9_inhibition MOE UNDER GP_matern
# NEK9_inhibition MOE SMOTE GP_matern
# NEK9_inhibition MFP none_scaled GP_matern
# NEK9_inhibition MFP UNDER GP_matern
# NEK9_inhibition MFP SMOTE GP_matern
