# %%
import pyforest

# %%
results='/Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/paper/gp_models/'
gp=pd.read_csv(f'{results}GP_test_results_all_NEK_kfold_val_10x.csv')
gp['1-specificity']=1-gp['specificity']
gp['strategy_kernel'] = gp['strategy'].astype(str)+'_'+gp['kernel_type']

# %%
for nek in gp['NEK'].unique():
    fig, axs = plt.subplots(1,2, figsize=(12,6))
    nek_df = gp[gp['NEK']==nek] 
    moe_df = nek_df[nek_df['feat_type']=='MOE'] 
    mfp_df =nek_df[nek_df['feat_type']=='MFP'] 
    sns.scatterplot(data=moe_df, x='1-specificity', y='recall', hue='strategy_kernel', style='fold',
                     s=300, alpha=0.6, ax=axs[0], legend=True)
    sns.scatterplot(data=mfp_df, x='1-specificity', y='recall', hue='strategy_kernel', style='fold',
                s=300, alpha=0.6, ax=axs[1],legend=False)
    plt.suptitle('Modeling Results\nSensitivity vs. 1-Specificity', fontsize=18, x=0.49, y =.96)
    for i, ax in enumerate(axs): 
        axs[i].plot([-0.1, 1.1],[-0.1,1.1], linestyle='--', color='gray')
        axs[i].set_xlim(-0.1, 1.1)
        axs[i].set_ylim(-0.1, 1.1)
        axs[i].set_xlabel('1 - Specificity', fontsize=16)
        axs[i].set_ylabel('Sensitivity (Recall)', fontsize=16)
        # axs[i].get_legend().remove()
        
    axs[0].set_title(f'{nek} moe', fontsize=16)
    axs[1].set_title(f'{nek} mfp', fontsize=16)
    axs[1].legend(ncols=1, bbox_to_anchor=(1.45, 0.75))
    plt.tight_layout()
    # plt.savefig(f'.png',bbox_inches='tight')

    plt.show();
# Out:
# /var/folders/wb/cvnnx9qn3tj18cq5_9wx39xm0000gn/T/ipykernel_32447/1376670484.py:22: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[1].legend(ncols=1, bbox_to_anchor=(1.45, 0.75))
# /var/folders/wb/cvnnx9qn3tj18cq5_9wx39xm0000gn/T/ipykernel_32447/1376670484.py:22: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[1].legend(ncols=1, bbox_to_anchor=(1.45, 0.75))
# /var/folders/wb/cvnnx9qn3tj18cq5_9wx39xm0000gn/T/ipykernel_32447/1376670484.py:22: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[1].legend(ncols=1, bbox_to_anchor=(1.45, 0.75))
# /var/folders/wb/cvnnx9qn3tj18cq5_9wx39xm0000gn/T/ipykernel_32447/1376670484.py:22: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[1].legend(ncols=1, bbox_to_anchor=(1.45, 0.75))
# /var/folders/wb/cvnnx9qn3tj18cq5_9wx39xm0000gn/T/ipykernel_32447/1376670484.py:22: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[1].legend(ncols=1, bbox_to_anchor=(1.45, 0.75))
# /var/folders/wb/cvnnx9qn3tj18cq5_9wx39xm0000gn/T/ipykernel_32447/1376670484.py:22: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[1].legend(ncols=1, bbox_to_anchor=(1.45, 0.75))

# %%
for nek in gp['NEK'].unique():
    fig, axs = plt.subplots(1,2, figsize=(12,6))
    nek_df = gp[gp['NEK']==nek] 
    moe_df = nek_df[nek_df['feat_type']=='MOE'] 
    mfp_df =nek_df[nek_df['feat_type']=='MFP'] 
    sns.scatterplot(data=moe_df, x='1-specificity', y='recall', hue='strategy', style='kernel_type',
                     s=300, alpha=0.6, ax=axs[0], legend=True)
    sns.scatterplot(data=mfp_df, x='1-specificity', y='recall', hue='strategy', style='kernel_type',
                s=300, alpha=0.6, ax=axs[1],legend=False)
    plt.suptitle('Modeling Results\nSensitivity vs. 1-Specificity', fontsize=18, x=0.49, y =.96)
    for i, ax in enumerate(axs): 
        axs[i].plot([-0.1, 1.1],[-0.1,1.1], linestyle='--', color='gray')
        axs[i].set_xlim(-0.1, 1.1)
        axs[i].set_ylim(-0.1, 1.1)
        axs[i].set_xlabel('1 - Specificity', fontsize=16)
        axs[i].set_ylabel('Sensitivity (Recall)', fontsize=16)
        # axs[i].get_legend().remove()
        
    axs[0].set_title(f'{nek} moe', fontsize=16)
    axs[1].set_title(f'{nek} mfp', fontsize=16)
    axs[1].legend(ncols=1, bbox_to_anchor=(1.45, 0.75))
    plt.tight_layout()
    # plt.savefig(f'.png',bbox_inches='tight')

    plt.show();
# Out:
# /var/folders/wb/cvnnx9qn3tj18cq5_9wx39xm0000gn/T/ipykernel_32447/372123430.py:21: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[1].legend(ncols=1, bbox_to_anchor=(1.45, 0.75))
# /var/folders/wb/cvnnx9qn3tj18cq5_9wx39xm0000gn/T/ipykernel_32447/372123430.py:21: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[1].legend(ncols=1, bbox_to_anchor=(1.45, 0.75))
# /var/folders/wb/cvnnx9qn3tj18cq5_9wx39xm0000gn/T/ipykernel_32447/372123430.py:21: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[1].legend(ncols=1, bbox_to_anchor=(1.45, 0.75))
# /var/folders/wb/cvnnx9qn3tj18cq5_9wx39xm0000gn/T/ipykernel_32447/372123430.py:21: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[1].legend(ncols=1, bbox_to_anchor=(1.45, 0.75))
# /var/folders/wb/cvnnx9qn3tj18cq5_9wx39xm0000gn/T/ipykernel_32447/372123430.py:21: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[1].legend(ncols=1, bbox_to_anchor=(1.45, 0.75))
# /var/folders/wb/cvnnx9qn3tj18cq5_9wx39xm0000gn/T/ipykernel_32447/372123430.py:21: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[1].legend(ncols=1, bbox_to_anchor=(1.45, 0.75))

# %%
for nek in gp['NEK'].unique():
    fig, axs = plt.subplots(1,2, figsize=(12,6))
    nek_df = gp[gp['NEK']==nek] 
    moe_df = nek_df[nek_df['feat_type']=='MOE'] 
    mfp_df =nek_df[nek_df['feat_type']=='MFP'] 
    sns.scatterplot(data=moe_df, x='1-specificity', y='recall', hue='iteration', style='fold',
                     s=300, alpha=0.6, ax=axs[0], legend=True)
    sns.scatterplot(data=mfp_df, x='1-specificity', y='recall', hue='iteration', style='fold',
                s=300, alpha=0.6, ax=axs[1],legend=False)
    plt.suptitle('Modeling Results\nSensitivity vs. 1-Specificity', fontsize=18, x=0.49, y =.96)
    for i, ax in enumerate(axs): 
        axs[i].plot([-0.1, 1.1],[-0.1,1.1], linestyle='--', color='gray')
        axs[i].set_xlim(-0.1, 1.1)
        axs[i].set_ylim(-0.1, 1.1)
        axs[i].set_xlabel('1 - Specificity', fontsize=16)
        axs[i].set_ylabel('Sensitivity (Recall)', fontsize=16)
        # axs[i].get_legend().remove()
        
    axs[0].set_title(f'{nek} moe', fontsize=16)
    axs[1].set_title(f'{nek} mfp', fontsize=16)
    axs[1].legend(ncols=1, bbox_to_anchor=(1.45, 0.75))
    plt.tight_layout()
    # plt.savefig(f'.png',bbox_inches='tight')

    plt.show();
# Out:
# /var/folders/wb/cvnnx9qn3tj18cq5_9wx39xm0000gn/T/ipykernel_32447/789304341.py:21: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[1].legend(ncols=1, bbox_to_anchor=(1.45, 0.75))
# /var/folders/wb/cvnnx9qn3tj18cq5_9wx39xm0000gn/T/ipykernel_32447/789304341.py:21: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[1].legend(ncols=1, bbox_to_anchor=(1.45, 0.75))
# /var/folders/wb/cvnnx9qn3tj18cq5_9wx39xm0000gn/T/ipykernel_32447/789304341.py:21: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[1].legend(ncols=1, bbox_to_anchor=(1.45, 0.75))
# /var/folders/wb/cvnnx9qn3tj18cq5_9wx39xm0000gn/T/ipykernel_32447/789304341.py:21: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[1].legend(ncols=1, bbox_to_anchor=(1.45, 0.75))
# /var/folders/wb/cvnnx9qn3tj18cq5_9wx39xm0000gn/T/ipykernel_32447/789304341.py:21: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[1].legend(ncols=1, bbox_to_anchor=(1.45, 0.75))
# /var/folders/wb/cvnnx9qn3tj18cq5_9wx39xm0000gn/T/ipykernel_32447/789304341.py:21: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[1].legend(ncols=1, bbox_to_anchor=(1.45, 0.75))
