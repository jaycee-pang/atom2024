# %%
data_dir = '/Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/'
nek_nums = [2, 3, 5, 9]
samplings = ['scaled', 'UNDER', 'SMOTE', 'ADASYN']
features = ['moe', 'mfp']
NEK = 'NEK'

html_content = """
<!DOCTYPE html>
<html>
<body>

<h2>NEK GP Swarm plots</h2>

"""

for n in nek_nums:
    nek = str(n)
    # nek_path = f'{data_dir}NEK{nek}/bind/'
    nek_path='/Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/UQ_all_nek_gp/'
    html_content += f'<h3>NEK{nek}</h3>'
    
    for feat in features:
        for samp in samplings:
            file_root = f'NEK{nek}_binding_{feat}_{samp}'
            img_path = f"{nek_path}{file_root}_test_GP_swarm_plot_GP.png"
            html_content += f'<img src="{img_path}" alt="{file_root}" width="500" height="333">\n'
    
    if n == 2 or n == 9:
        # nek_path = f'{data_dir}NEK{nek}/inhib/'
        nek_path='/Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/UQ_all_nek_gp/'
        for feat in features:
            for samp in samplings:
                file_root = f'NEK{nek}_inhibition_{feat}_{samp}_test_GP_swarm_plot_GP'
                img_path = f"{nek_path}{file_root}.png"
                html_content += f'<img src="{img_path}" alt="{file_root}" width="500" height="333">\n'
    
    html_content += '<br>\n'

html_content += """
</body>
</html>
"""

print(html_content)


with open('GP_swarm_plots.html', 'w') as f:
    f.write(html_content)
# Out:
# <!DOCTYPE html>
# <html>
# <body>
#
# <h2>NEK GP Swarm plots</h2>
#
# <h3>NEK2</h3><img src="/Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/UQ_all_nek_gp/NEK2_binding_moe_scaled_test_GP_swarm_plot_GP.png" alt="NEK2_binding_moe_scaled" width="500" height="333">
# <img src="/Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/UQ_all_nek_gp/NEK2_binding_moe_UNDER_test_GP_swarm_plot_GP.png" alt="NEK2_binding_moe_UNDER" width="500" height="333">
# <img src="/Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/UQ_all_nek_gp/NEK2_binding_moe_SMOTE_test_GP_swarm_plot_GP.png" alt="NEK2_binding_moe_SMOTE" width="500" height="333">
# <img src="/Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/UQ_all_nek_gp/NEK2_binding_moe_ADASYN_test_GP_swarm_plot_GP.png" alt="NEK2_binding_moe_ADASYN" width="500" height="333">
# ...
