# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import accuracy_score, balanced_accuracy_score,precision_score, f1_score, roc_auc_score, roc_curve, precision_recall_curve, auc, recall_score, confusion_matrix,matthews_corrcoef
import sys 
import pickle

from imblearn.under_sampling import RandomUnderSampler
sys.path.append('/Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/')
from RF_atomver import *
from VisUtils import *

# %%
def add_cm2(df): 
    true_labels = df['y'] 
    predictions = df['prediction']
    cm = confusion_matrix(true_labels, predictions )
    cm_flattened = cm.flatten().tolist()
    df['cm'] = [cm_flattened]* len(df)
    df['prediction_type'] = df.apply(lambda x: prediction_type(x['y'], x['prediction']), axis=1)
    
    df['f1'] = f1_score(df['y'], df['prediction'])
    df['ROC-AUC'] = roc_auc_score(df['y'], df['prediction'])
    # df['ROC-AUC'] ='NA'
    df['MCC'] = matthews_corrcoef(df['y'], df['prediction'])
    df['Balanced Accuracy'] = balanced_accuracy_score(df['y'], df['prediction'])
    return df

# %%
drop_cols = ['subset', 'compound_id', 'base_rdkit_smiles', 'fold', 'active'] 
this_dir='/Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/undersampler_validation/under_batch2_jp/'
RF_type = 'RF'
neks = ['2','3','5','9']
for i, nek in enumerate(neks):
    if nek in ['2','9']: 
        bind_inhib = ['binding', 'inhibition']
    else: 
        bind_inhib = ['binding'] 
    for bi in bind_inhib: 
        if bi == 'binding': 
            this_bi = 'bind'
        else: 
            this_bi = 'inhib' 
        for feat in ['moe', 'mfp']:
            print(f'NEK{nek} {bi} {feat}')
            
            df = pd.read_csv(f'{this_dir}NEK{nek}_{bi}_{feat}_UNDER_batch2.csv')
            if 'active.1' in drop_cols: 
                drop_cols.append('active.1') 
            if 'subset.1' in drop_cols: 
                drop_cols.append('subset.1') 
            train = df[df['subset'] == 'train'] 
            test = df[df['subset'] == 'test']
            
            trainX = train.drop(columns=drop_cols).to_numpy()
            train_y = train['active'].to_numpy() 

            testX = test.drop(columns=drop_cols).to_numpy()
            test_y = test['active'].to_numpy() 
    
            model = rf_models(trainX, train_y, testX, test_y, RF_type, {})
            train_df = gather_rf_results(model, trainX, train_y)
            test_df = gather_rf_results(model, testX, test_y)
            train_df['subset'] = 'train' 
            test_df['subset'] = 'test' 
            model_name = f'NEK{nek}_{bi}_{feat}_UNDER_RF_batch2' 
            train_df['model'] = model_name
            test_df['model'] = model_name
            
            train_df = add_cm2(train_df)
            test_df = add_cm2(test_df)
            
            train_df['NEK'] = f'NEK{nek}_{bi}'
            train_df['feat_type'] = feat
            train_df['strategy'] = 'UNDER'
            train_df['RF_type'] = RF_type
            test_df['NEK'] = f'NEK{nek}_{bi}'
            test_df['feat_type'] = feat
            test_df['strategy'] = 'UNDER'
            test_df['RF_type'] = RF_type
            
            with open(f'{this_dir}{model_name}.pkl', 'wb') as f: 
                pickle.dump(model,f)
    
            train_df.to_csv(f'{this_dir}{model_name}_train_results.csv',index=False) 
            test_df.to_csv(f'{this_dir}{model_name}_test_results.csv',index=False)
# Out:
# NEK2 binding moe
# TRAIN: accuracy: 1.000, precision: 1.000, recall: 1.000, specificity: 1.000
# TEST: accuracy: 0.618, precision: 0.079, recall: 0.750, specificity: 0.613
# NEK2 binding mfp
# TRAIN: accuracy: 0.978, precision: 1.000, recall: 0.956, specificity: 1.000
# TEST: accuracy: 0.403, precision: 0.056, recall: 0.833, specificity: 0.384
# NEK2 inhibition moe
# TRAIN: accuracy: 1.000, precision: 1.000, recall: 1.000, specificity: 1.000
# TEST: accuracy: 0.743, precision: 0.171, recall: 0.714, specificity: 0.745
# NEK2 inhibition mfp
# TRAIN: accuracy: 0.946, precision: 1.000, recall: 0.893, specificity: 1.000
# TEST: accuracy: 0.451, precision: 0.062, recall: 0.500, specificity: 0.447
# NEK3 binding moe
# TRAIN: accuracy: 1.000, precision: 1.000, recall: 1.000, specificity: 1.000
# TEST: accuracy: 0.571, precision: 0.081, recall: 0.588, specificity: 0.570
# NEK3 binding mfp
# TRAIN: accuracy: 0.969, precision: 1.000, recall: 0.938, specificity: 1.000
# TEST: accuracy: 0.489, precision: 0.050, recall: 0.412, specificity: 0.494
# NEK5 binding moe
# TRAIN: accuracy: 1.000, precision: 1.000, recall: 1.000, specificity: 1.000
# TEST: accuracy: 0.605, precision: 0.125, recall: 0.650, specificity: 0.601
# NEK5 binding mfp
# TRAIN: accuracy: 0.948, precision: 1.000, recall: 0.896, specificity: 1.000
# TEST: accuracy: 0.500, precision: 0.074, recall: 0.450, specificity: 0.504
# NEK9 binding moe
# TRAIN: accuracy: 1.000, precision: 1.000, recall: 1.000, specificity: 1.000
# TEST: accuracy: 0.661, precision: 0.072, recall: 0.538, specificity: 0.667
# NEK9 binding mfp
# TRAIN: accuracy: 0.979, precision: 1.000, recall: 0.958, specificity: 1.000
# TEST: accuracy: 0.442, precision: 0.038, recall: 0.462, specificity: 0.441
# NEK9 inhibition moe
# TRAIN: accuracy: 1.000, precision: 1.000, recall: 1.000, specificity: 1.000
# TEST: accuracy: 0.838, precision: 0.375, recall: 0.667, specificity: 0.859
# NEK9 inhibition mfp
# TRAIN: accuracy: 0.894, precision: 1.000, recall: 0.788, specificity: 1.000
# TEST: accuracy: 0.438, precision: 0.125, recall: 0.667, specificity: 0.408

# %%
results = [] 
metric_cols = ['accuracy', 'precision', 'recall', 'specificity','TN', 'FN', 'FP', 'TP','f1', 'ROC-AUC', 'MCC', 'Balanced Accuracy',
       'model', 'cm', 'prediction_type', 'NEK', 'feat_type', 'strategy','RF_type']
for i, nek in enumerate(neks):
    if nek in ['2','9']: 
        bind_inhib = ['binding', 'inhibition']
    else: 
        bind_inhib = ['binding'] 
    for bi in bind_inhib: 
        if bi == 'binding': 
            this_bi = 'bind'
        else: 
            this_bi = 'inhib' 
        for feat in ['moe', 'mfp']: 
            result_df = pd.read_csv(f'{this_dir}NEK{nek}_{bi}_{feat}_UNDER_RF_batch2_test_results.csv')
            results.append(result_df.iloc[[0]][metric_cols].values.flatten())
results_df =  pd.DataFrame(results,columns=metric_cols)
results_df['model'] = results_df['model'].str.replace('scaled', 'raw')
results_df['strategy'] =results_df['strategy'].str.replace('scaled', 'raw')
results_df['strategy'] = results_df['strategy'].str.replace('scaled', 'raw')
results_df.to_csv(this_dir+'RF_results_UDNER_batch2.csv', index=False) 
results_df['modeling_type'] = 'RF' 
results_df['set'] = 'UNDER_batch2'

# %%
original_results = pd.read_csv('/Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/general_NEK/final_paper_models.csv')
original_results = original_results[(original_results['set']=='original') & (original_results['modeling_type'] == 'RF')]
only_under = original_results[(original_results['strategy'] == 'UNDER') &(original_results['RF_type'] == 'RF')]
all_under_rf = pd.concat([results_df, only_under])
comparison = all_under_rf[['NEK', 'feat_type','set','cm', 'recall', 'specificity']]
comparison = comparison.sort_values(['NEK', 'feat_type'])
comparison
# Out:
#                  NEK feat_type           set                  cm    recall  \
# 1       NEK2_binding       mfp  UNDER_batch2   [104, 167, 2, 10]  0.833333
# 68      NEK2_binding       mfp      original    [153, 118, 4, 8]  0.666667
# 0       NEK2_binding       moe  UNDER_batch2    [166, 105, 3, 9]  0.750000
# 52      NEK2_binding       moe      original     [191, 80, 6, 6]  0.500000
# 3    NEK2_inhibition       mfp  UNDER_batch2  [170, 210, 14, 14]  0.500000
# 100  NEK2_inhibition       mfp      original  [171, 209, 14, 14]  0.500000
# 2    NEK2_inhibition       moe  UNDER_batch2    [283, 97, 8, 20]  0.714286
# 84   NEK2_inhibition       moe      original    [305, 75, 4, 24]  0.857143
# 5       NEK3_binding       mfp  UNDER_batch2   [131, 134, 10, 7]  0.411765
# 132     NEK3_binding       mfp      original   [127, 138, 5, 12]  0.705882
# 4       NEK3_binding       moe  UNDER_batch2   [151, 114, 7, 10]  0.588235
# 116     NEK3_binding       moe      original   [135, 130, 3, 14]  0.823529
# 7       NEK5_binding       mfp  UNDER_batch2   [115, 113, 11, 9]  0.450000
# 164     NEK5_binding       mfp      original   [121, 107, 12, 8]  0.400000
# 6       NEK5_binding       moe  UNDER_batch2    [137, 91, 7, 13]  0.650000
# 148     NEK5_binding       moe      original    [161, 67, 3, 17]  0.850000
# 9       NEK9_binding       mfp  UNDER_batch2    [119, 151, 7, 6]  0.461538
# 196     NEK9_binding       mfp      original    [138, 132, 6, 7]  0.538462
# 8       NEK9_binding       moe  UNDER_batch2     [180, 90, 6, 7]  0.538462
# 180     NEK9_binding       moe      original     [177, 93, 4, 9]  0.692308
# 11   NEK9_inhibition       mfp  UNDER_batch2      [29, 42, 3, 6]  0.666667
# 228  NEK9_inhibition       mfp      original      [32, 39, 6, 3]  0.333333
# 10   NEK9_inhibition       moe  UNDER_batch2      [61, 10, 3, 6]  0.666667
# 212  NEK9_inhibition       moe      original      [61, 10, 3, 6]  0.666667
#
#      specificity
# 1       0.383764
# 68      0.564576
# 0       0.612546
# 52      0.704797
# 3       0.447368
# 100     0.450000
# 2       0.744737
# 84      0.802632
# 5       0.494340
# 132     0.479245
# 4       0.569811
# 116     0.509434
# 7       0.504386
# 164     0.530702
# 6       0.600877
# 148     0.706140
# 9       0.440741
# 196     0.511111
# 8       0.666667
# 180     0.655556
# 11      0.408451
# 228     0.450704
# 10      0.859155
# 212     0.859155

# %%
def df_tree_probs(model, x_data): 
    test_proba0_df = pd.DataFrame()
    test_proba1_df = pd.DataFrame()
    for tree_num in np.arange(len(model.estimators_)):
        test_proba_temp = model.estimators_[tree_num].predict_proba(x_data)
        print(f'tree_num: {tree_num}, test_proba_temp shape: {test_proba_temp.shape}')
        test_proba0_df[tree_num] = test_proba_temp[:,0]
        test_proba1_df[tree_num] = test_proba_temp[:,1]
        print(f'test_proba0_df shape: {test_proba0_df.shape}, test_proba1_df shape: {test_proba1_df.shape}')
    std0 = test_proba0_df.std(axis=1)
    std1 = test_proba1_df.std(axis=1)

    print(f'in df tree prob function. std0 shape: {std0.shape}, std1 shape: {std1.shape}')
    return std0, std1

# %%
datapath = f'/Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/undersampler_validation/under_batch2_jp/'
prob_path = '/Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/undersampler_validation/under_batch2_jp/'
neks = ['2','3','5','9']
feat_types=['moe','mfp']
for i, nek in enumerate(neks):
    if nek in ['2','9']: 
        bind_inhib = ['binding', 'inhibition']
    else: 
        bind_inhib = ['binding'] 
    for bi in bind_inhib: 
        if bi == 'binding': 
            this_bi = 'bind'
        else: 
            this_bi = 'inhib' 
        combined_feats= []
        df = pd.DataFrame()
        std0s = pd.DataFrame() 
        std1s = pd.DataFrame() 
        for feat in feat_types: 
            print(f'NEK{nek} {bi} {feat}')
            NEK = f'NEK{nek}_{bi}'
            df = pd.read_csv(f'{datapath}NEK{nek}_{bi}_{feat}_UNDER_batch2.csv')
            test = df[df['subset']=='test']
            testX = test.drop(columns=['active', 'compound_id', 'subset','base_rdkit_smiles','fold']).to_numpy()
            print(f'test X shape {testX.shape}') 
            model_name = f'NEK{nek}_{bi}_{feat}_UNDER_RF_batch2'
            results_df = pd.read_csv(f'{datapath}{model_name}_test_results.csv')
 
            predictions = results_df['prediction'].to_numpy()
            test_y =  test['active'].to_numpy()
            with open(datapath+model_name+'.pkl', 'rb') as f: 
                model = pickle.load(f)
                std0, std1 = df_tree_probs(model, testX)
                
                this_std0 = pd.DataFrame(std0) 
                this_std1 = pd.DataFrame(std1) 
                label0 = f'std0_{feat}'
                label1 = f'std1_{feat}'
                std0s[label0] = this_std0 
                std1s[label1] = this_std1 
    
            print('feat: '+feat)
            df = pd.concat([std0s, std1s],axis=1)
            df['model'] = model_name 
            df['NEK'] = NEK
            samp='UNDER_batch2'
            if samp == 'scaled': 
                
                df['strategy'] = 'raw'
            else: 
                df['strategy'] = 'UNDER_batch2'
            
            df['feat_type'] = feat 
            df['RF_type'] = 'RF'
            display(df)
            print('done')
            df.to_csv(f'{prob_path}{NEK}_std_prob_UNDER_batch2_RF.csv')
            nan_rows = df[df.isna().any(axis=1)]
    
            print(f'concated df shape: {df.shape}')
# Out:
# NEK2 binding moe
# test X shape (283, 306)
# tree_num: 0, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 1), test_proba1_df shape: (283, 1)
# tree_num: 1, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 2), test_proba1_df shape: (283, 2)
# tree_num: 2, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 3), test_proba1_df shape: (283, 3)
# tree_num: 3, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 4), test_proba1_df shape: (283, 4)
# tree_num: 4, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 5), test_proba1_df shape: (283, 5)
# tree_num: 5, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 6), test_proba1_df shape: (283, 6)
# tree_num: 6, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 7), test_proba1_df shape: (283, 7)
# tree_num: 7, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 8), test_proba1_df shape: (283, 8)
# tree_num: 8, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 9), test_proba1_df shape: (283, 9)
# tree_num: 9, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 10), test_proba1_df shape: (283, 10)
# tree_num: 10, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 11), test_proba1_df shape: (283, 11)
# tree_num: 11, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 12), test_proba1_df shape: (283, 12)
# tree_num: 12, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 13), test_proba1_df shape: (283, 13)
# tree_num: 13, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 14), test_proba1_df shape: (283, 14)
# tree_num: 14, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 15), test_proba1_df shape: (283, 15)
# tree_num: 15, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 16), test_proba1_df shape: (283, 16)
# tree_num: 16, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 17), test_proba1_df shape: (283, 17)
# tree_num: 17, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 18), test_proba1_df shape: (283, 18)
# tree_num: 18, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 19), test_proba1_df shape: (283, 19)
# tree_num: 19, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 20), test_proba1_df shape: (283, 20)
# tree_num: 20, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 21), test_proba1_df shape: (283, 21)
# tree_num: 21, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 22), test_proba1_df shape: (283, 22)
# tree_num: 22, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 23), test_proba1_df shape: (283, 23)
# tree_num: 23, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 24), test_proba1_df shape: (283, 24)
# tree_num: 24, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 25), test_proba1_df shape: (283, 25)
# tree_num: 25, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 26), test_proba1_df shape: (283, 26)
# tree_num: 26, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 27), test_proba1_df shape: (283, 27)
# tree_num: 27, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 28), test_proba1_df shape: (283, 28)
# tree_num: 28, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 29), test_proba1_df shape: (283, 29)
# tree_num: 29, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 30), test_proba1_df shape: (283, 30)
# tree_num: 30, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 31), test_proba1_df shape: (283, 31)
# tree_num: 31, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 32), test_proba1_df shape: (283, 32)
# tree_num: 32, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 33), test_proba1_df shape: (283, 33)
# tree_num: 33, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 34), test_proba1_df shape: (283, 34)
# tree_num: 34, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 35), test_proba1_df shape: (283, 35)
# tree_num: 35, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 36), test_proba1_df shape: (283, 36)
# tree_num: 36, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 37), test_proba1_df shape: (283, 37)
# tree_num: 37, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 38), test_proba1_df shape: (283, 38)
# tree_num: 38, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 39), test_proba1_df shape: (283, 39)
# tree_num: 39, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 40), test_proba1_df shape: (283, 40)
# tree_num: 40, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 41), test_proba1_df shape: (283, 41)
# tree_num: 41, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 42), test_proba1_df shape: (283, 42)
# tree_num: 42, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 43), test_proba1_df shape: (283, 43)
# tree_num: 43, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 44), test_proba1_df shape: (283, 44)
# tree_num: 44, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 45), test_proba1_df shape: (283, 45)
# tree_num: 45, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 46), test_proba1_df shape: (283, 46)
# tree_num: 46, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 47), test_proba1_df shape: (283, 47)
# tree_num: 47, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 48), test_proba1_df shape: (283, 48)
# tree_num: 48, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 49), test_proba1_df shape: (283, 49)
# tree_num: 49, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 50), test_proba1_df shape: (283, 50)
# tree_num: 50, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 51), test_proba1_df shape: (283, 51)
# tree_num: 51, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 52), test_proba1_df shape: (283, 52)
# tree_num: 52, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 53), test_proba1_df shape: (283, 53)
# tree_num: 53, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 54), test_proba1_df shape: (283, 54)
# tree_num: 54, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 55), test_proba1_df shape: (283, 55)
# tree_num: 55, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 56), test_proba1_df shape: (283, 56)
# tree_num: 56, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 57), test_proba1_df shape: (283, 57)
# tree_num: 57, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 58), test_proba1_df shape: (283, 58)
# tree_num: 58, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 59), test_proba1_df shape: (283, 59)
# tree_num: 59, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 60), test_proba1_df shape: (283, 60)
# tree_num: 60, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 61), test_proba1_df shape: (283, 61)
# tree_num: 61, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 62), test_proba1_df shape: (283, 62)
# tree_num: 62, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 63), test_proba1_df shape: (283, 63)
# tree_num: 63, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 64), test_proba1_df shape: (283, 64)
# tree_num: 64, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 65), test_proba1_df shape: (283, 65)
# tree_num: 65, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 66), test_proba1_df shape: (283, 66)
# tree_num: 66, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 67), test_proba1_df shape: (283, 67)
# tree_num: 67, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 68), test_proba1_df shape: (283, 68)
# tree_num: 68, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 69), test_proba1_df shape: (283, 69)
# tree_num: 69, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 70), test_proba1_df shape: (283, 70)
# tree_num: 70, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 71), test_proba1_df shape: (283, 71)
# tree_num: 71, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 72), test_proba1_df shape: (283, 72)
# tree_num: 72, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 73), test_proba1_df shape: (283, 73)
# tree_num: 73, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 74), test_proba1_df shape: (283, 74)
# tree_num: 74, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 75), test_proba1_df shape: (283, 75)
# tree_num: 75, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 76), test_proba1_df shape: (283, 76)
# tree_num: 76, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 77), test_proba1_df shape: (283, 77)
# tree_num: 77, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 78), test_proba1_df shape: (283, 78)
# tree_num: 78, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 79), test_proba1_df shape: (283, 79)
# tree_num: 79, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 80), test_proba1_df shape: (283, 80)
# tree_num: 80, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 81), test_proba1_df shape: (283, 81)
# tree_num: 81, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 82), test_proba1_df shape: (283, 82)
# tree_num: 82, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 83), test_proba1_df shape: (283, 83)
# tree_num: 83, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 84), test_proba1_df shape: (283, 84)
# tree_num: 84, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 85), test_proba1_df shape: (283, 85)
# tree_num: 85, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 86), test_proba1_df shape: (283, 86)
# tree_num: 86, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 87), test_proba1_df shape: (283, 87)
# tree_num: 87, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 88), test_proba1_df shape: (283, 88)
# tree_num: 88, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 89), test_proba1_df shape: (283, 89)
# tree_num: 89, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 90), test_proba1_df shape: (283, 90)
# tree_num: 90, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 91), test_proba1_df shape: (283, 91)
# tree_num: 91, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 92), test_proba1_df shape: (283, 92)
# tree_num: 92, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 93), test_proba1_df shape: (283, 93)
# tree_num: 93, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 94), test_proba1_df shape: (283, 94)
# tree_num: 94, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 95), test_proba1_df shape: (283, 95)
# tree_num: 95, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 96), test_proba1_df shape: (283, 96)
# tree_num: 96, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 97), test_proba1_df shape: (283, 97)
# tree_num: 97, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 98), test_proba1_df shape: (283, 98)
# tree_num: 98, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 99), test_proba1_df shape: (283, 99)
# tree_num: 99, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 100), test_proba1_df shape: (283, 100)
# in df tree prob function. std0 shape: (283,), std1 shape: (283,)
# feat: moe
#      std0_moe  std1_moe                             model           NEK  \
# 0    0.000000  0.000000  NEK2_binding_moe_UNDER_RF_batch2  NEK2_binding
# 1    0.314466  0.314466  NEK2_binding_moe_UNDER_RF_batch2  NEK2_binding
# 2    0.502418  0.502418  NEK2_binding_moe_UNDER_RF_batch2  NEK2_binding
# 3    0.487832  0.487832  NEK2_binding_moe_UNDER_RF_batch2  NEK2_binding
# 4    0.196946  0.196946  NEK2_binding_moe_UNDER_RF_batch2  NEK2_binding
# ..        ...       ...                               ...           ...
# 278  0.000000  0.000000  NEK2_binding_moe_UNDER_RF_batch2  NEK2_binding
# 279  0.416333  0.416333  NEK2_binding_moe_UNDER_RF_batch2  NEK2_binding
# 280  0.460566  0.460566  NEK2_binding_moe_UNDER_RF_batch2  NEK2_binding
# 281  0.000000  0.000000  NEK2_binding_moe_UNDER_RF_batch2  NEK2_binding
# 282  0.000000  0.000000  NEK2_binding_moe_UNDER_RF_batch2  NEK2_binding
#
#          strategy feat_type RF_type
# 0    UNDER_batch2       moe      RF
# 1    UNDER_batch2       moe      RF
# 2    UNDER_batch2       moe      RF
# 3    UNDER_batch2       moe      RF
# 4    UNDER_batch2       moe      RF
# ..            ...       ...     ...
# 278  UNDER_batch2       moe      RF
# 279  UNDER_batch2       moe      RF
# 280  UNDER_batch2       moe      RF
# 281  UNDER_batch2       moe      RF
# 282  UNDER_batch2       moe      RF
#
# [283 rows x 7 columns]
# done
# concated df shape: (283, 7)
# NEK2 binding mfp
# test X shape (283, 2048)
# tree_num: 0, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 1), test_proba1_df shape: (283, 1)
# tree_num: 1, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 2), test_proba1_df shape: (283, 2)
# tree_num: 2, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 3), test_proba1_df shape: (283, 3)
# tree_num: 3, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 4), test_proba1_df shape: (283, 4)
# tree_num: 4, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 5), test_proba1_df shape: (283, 5)
# tree_num: 5, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 6), test_proba1_df shape: (283, 6)
# tree_num: 6, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 7), test_proba1_df shape: (283, 7)
# tree_num: 7, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 8), test_proba1_df shape: (283, 8)
# tree_num: 8, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 9), test_proba1_df shape: (283, 9)
# tree_num: 9, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 10), test_proba1_df shape: (283, 10)
# tree_num: 10, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 11), test_proba1_df shape: (283, 11)
# tree_num: 11, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 12), test_proba1_df shape: (283, 12)
# tree_num: 12, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 13), test_proba1_df shape: (283, 13)
# tree_num: 13, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 14), test_proba1_df shape: (283, 14)
# tree_num: 14, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 15), test_proba1_df shape: (283, 15)
# tree_num: 15, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 16), test_proba1_df shape: (283, 16)
# tree_num: 16, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 17), test_proba1_df shape: (283, 17)
# tree_num: 17, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 18), test_proba1_df shape: (283, 18)
# tree_num: 18, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 19), test_proba1_df shape: (283, 19)
# tree_num: 19, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 20), test_proba1_df shape: (283, 20)
# tree_num: 20, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 21), test_proba1_df shape: (283, 21)
# tree_num: 21, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 22), test_proba1_df shape: (283, 22)
# tree_num: 22, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 23), test_proba1_df shape: (283, 23)
# tree_num: 23, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 24), test_proba1_df shape: (283, 24)
# tree_num: 24, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 25), test_proba1_df shape: (283, 25)
# tree_num: 25, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 26), test_proba1_df shape: (283, 26)
# tree_num: 26, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 27), test_proba1_df shape: (283, 27)
# tree_num: 27, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 28), test_proba1_df shape: (283, 28)
# tree_num: 28, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 29), test_proba1_df shape: (283, 29)
# tree_num: 29, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 30), test_proba1_df shape: (283, 30)
# tree_num: 30, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 31), test_proba1_df shape: (283, 31)
# tree_num: 31, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 32), test_proba1_df shape: (283, 32)
# tree_num: 32, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 33), test_proba1_df shape: (283, 33)
# tree_num: 33, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 34), test_proba1_df shape: (283, 34)
# tree_num: 34, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 35), test_proba1_df shape: (283, 35)
# tree_num: 35, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 36), test_proba1_df shape: (283, 36)
# tree_num: 36, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 37), test_proba1_df shape: (283, 37)
# tree_num: 37, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 38), test_proba1_df shape: (283, 38)
# tree_num: 38, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 39), test_proba1_df shape: (283, 39)
# tree_num: 39, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 40), test_proba1_df shape: (283, 40)
# tree_num: 40, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 41), test_proba1_df shape: (283, 41)
# tree_num: 41, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 42), test_proba1_df shape: (283, 42)
# tree_num: 42, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 43), test_proba1_df shape: (283, 43)
# tree_num: 43, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 44), test_proba1_df shape: (283, 44)
# tree_num: 44, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 45), test_proba1_df shape: (283, 45)
# tree_num: 45, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 46), test_proba1_df shape: (283, 46)
# tree_num: 46, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 47), test_proba1_df shape: (283, 47)
# tree_num: 47, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 48), test_proba1_df shape: (283, 48)
# tree_num: 48, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 49), test_proba1_df shape: (283, 49)
# tree_num: 49, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 50), test_proba1_df shape: (283, 50)
# tree_num: 50, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 51), test_proba1_df shape: (283, 51)
# tree_num: 51, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 52), test_proba1_df shape: (283, 52)
# tree_num: 52, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 53), test_proba1_df shape: (283, 53)
# tree_num: 53, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 54), test_proba1_df shape: (283, 54)
# tree_num: 54, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 55), test_proba1_df shape: (283, 55)
# tree_num: 55, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 56), test_proba1_df shape: (283, 56)
# tree_num: 56, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 57), test_proba1_df shape: (283, 57)
# tree_num: 57, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 58), test_proba1_df shape: (283, 58)
# tree_num: 58, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 59), test_proba1_df shape: (283, 59)
# tree_num: 59, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 60), test_proba1_df shape: (283, 60)
# tree_num: 60, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 61), test_proba1_df shape: (283, 61)
# tree_num: 61, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 62), test_proba1_df shape: (283, 62)
# tree_num: 62, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 63), test_proba1_df shape: (283, 63)
# tree_num: 63, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 64), test_proba1_df shape: (283, 64)
# tree_num: 64, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 65), test_proba1_df shape: (283, 65)
# tree_num: 65, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 66), test_proba1_df shape: (283, 66)
# tree_num: 66, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 67), test_proba1_df shape: (283, 67)
# tree_num: 67, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 68), test_proba1_df shape: (283, 68)
# tree_num: 68, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 69), test_proba1_df shape: (283, 69)
# tree_num: 69, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 70), test_proba1_df shape: (283, 70)
# tree_num: 70, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 71), test_proba1_df shape: (283, 71)
# tree_num: 71, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 72), test_proba1_df shape: (283, 72)
# tree_num: 72, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 73), test_proba1_df shape: (283, 73)
# tree_num: 73, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 74), test_proba1_df shape: (283, 74)
# tree_num: 74, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 75), test_proba1_df shape: (283, 75)
# tree_num: 75, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 76), test_proba1_df shape: (283, 76)
# tree_num: 76, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 77), test_proba1_df shape: (283, 77)
# tree_num: 77, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 78), test_proba1_df shape: (283, 78)
# tree_num: 78, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 79), test_proba1_df shape: (283, 79)
# tree_num: 79, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 80), test_proba1_df shape: (283, 80)
# tree_num: 80, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 81), test_proba1_df shape: (283, 81)
# tree_num: 81, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 82), test_proba1_df shape: (283, 82)
# tree_num: 82, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 83), test_proba1_df shape: (283, 83)
# tree_num: 83, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 84), test_proba1_df shape: (283, 84)
# tree_num: 84, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 85), test_proba1_df shape: (283, 85)
# tree_num: 85, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 86), test_proba1_df shape: (283, 86)
# tree_num: 86, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 87), test_proba1_df shape: (283, 87)
# tree_num: 87, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 88), test_proba1_df shape: (283, 88)
# tree_num: 88, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 89), test_proba1_df shape: (283, 89)
# tree_num: 89, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 90), test_proba1_df shape: (283, 90)
# tree_num: 90, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 91), test_proba1_df shape: (283, 91)
# tree_num: 91, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 92), test_proba1_df shape: (283, 92)
# tree_num: 92, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 93), test_proba1_df shape: (283, 93)
# tree_num: 93, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 94), test_proba1_df shape: (283, 94)
# tree_num: 94, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 95), test_proba1_df shape: (283, 95)
# tree_num: 95, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 96), test_proba1_df shape: (283, 96)
# tree_num: 96, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 97), test_proba1_df shape: (283, 97)
# tree_num: 97, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 98), test_proba1_df shape: (283, 98)
# tree_num: 98, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 99), test_proba1_df shape: (283, 99)
# tree_num: 99, test_proba_temp shape: (283, 2)
# test_proba0_df shape: (283, 100), test_proba1_df shape: (283, 100)
# in df tree prob function. std0 shape: (283,), std1 shape: (283,)
# feat: mfp
#      std0_moe  std0_mfp  std1_moe  std1_mfp                             model  \
# 0    0.000000  0.000000  0.000000  0.000000  NEK2_binding_mfp_UNDER_RF_batch2
# 1    0.314466  0.196946  0.314466  0.196946  NEK2_binding_mfp_UNDER_RF_batch2
# 2    0.502418  0.100000  0.502418  0.100000  NEK2_binding_mfp_UNDER_RF_batch2
# 3    0.487832  0.000000  0.487832  0.000000  NEK2_binding_mfp_UNDER_RF_batch2
# 4    0.196946  0.462618  0.196946  0.462618  NEK2_binding_mfp_UNDER_RF_batch2
# ..        ...       ...       ...       ...                               ...
# 278  0.000000  0.464361  0.000000  0.464361  NEK2_binding_mfp_UNDER_RF_batch2
# 279  0.416333  0.456048  0.416333  0.456048  NEK2_binding_mfp_UNDER_RF_batch2
# 280  0.460566  0.000000  0.460566  0.000000  NEK2_binding_mfp_UNDER_RF_batch2
# 281  0.000000  0.140705  0.000000  0.140705  NEK2_binding_mfp_UNDER_RF_batch2
# 282  0.000000  0.181186  0.000000  0.181186  NEK2_binding_mfp_UNDER_RF_batch2
#
#               NEK      strategy feat_type RF_type
# 0    NEK2_binding  UNDER_batch2       mfp      RF
# 1    NEK2_binding  UNDER_batch2       mfp      RF
# 2    NEK2_binding  UNDER_batch2       mfp      RF
# 3    NEK2_binding  UNDER_batch2       mfp      RF
# 4    NEK2_binding  UNDER_batch2       mfp      RF
# ..            ...           ...       ...     ...
# 278  NEK2_binding  UNDER_batch2       mfp      RF
# 279  NEK2_binding  UNDER_batch2       mfp      RF
# 280  NEK2_binding  UNDER_batch2       mfp      RF
# 281  NEK2_binding  UNDER_batch2       mfp      RF
# 282  NEK2_binding  UNDER_batch2       mfp      RF
#
# [283 rows x 9 columns]
# done
# concated df shape: (283, 9)
# NEK2 inhibition moe
# test X shape (408, 306)
# tree_num: 0, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 1), test_proba1_df shape: (408, 1)
# tree_num: 1, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 2), test_proba1_df shape: (408, 2)
# tree_num: 2, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 3), test_proba1_df shape: (408, 3)
# tree_num: 3, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 4), test_proba1_df shape: (408, 4)
# tree_num: 4, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 5), test_proba1_df shape: (408, 5)
# tree_num: 5, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 6), test_proba1_df shape: (408, 6)
# tree_num: 6, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 7), test_proba1_df shape: (408, 7)
# tree_num: 7, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 8), test_proba1_df shape: (408, 8)
# tree_num: 8, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 9), test_proba1_df shape: (408, 9)
# tree_num: 9, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 10), test_proba1_df shape: (408, 10)
# tree_num: 10, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 11), test_proba1_df shape: (408, 11)
# tree_num: 11, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 12), test_proba1_df shape: (408, 12)
# tree_num: 12, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 13), test_proba1_df shape: (408, 13)
# tree_num: 13, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 14), test_proba1_df shape: (408, 14)
# tree_num: 14, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 15), test_proba1_df shape: (408, 15)
# tree_num: 15, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 16), test_proba1_df shape: (408, 16)
# tree_num: 16, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 17), test_proba1_df shape: (408, 17)
# tree_num: 17, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 18), test_proba1_df shape: (408, 18)
# tree_num: 18, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 19), test_proba1_df shape: (408, 19)
# tree_num: 19, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 20), test_proba1_df shape: (408, 20)
# tree_num: 20, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 21), test_proba1_df shape: (408, 21)
# tree_num: 21, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 22), test_proba1_df shape: (408, 22)
# tree_num: 22, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 23), test_proba1_df shape: (408, 23)
# tree_num: 23, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 24), test_proba1_df shape: (408, 24)
# tree_num: 24, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 25), test_proba1_df shape: (408, 25)
# tree_num: 25, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 26), test_proba1_df shape: (408, 26)
# tree_num: 26, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 27), test_proba1_df shape: (408, 27)
# tree_num: 27, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 28), test_proba1_df shape: (408, 28)
# tree_num: 28, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 29), test_proba1_df shape: (408, 29)
# tree_num: 29, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 30), test_proba1_df shape: (408, 30)
# tree_num: 30, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 31), test_proba1_df shape: (408, 31)
# tree_num: 31, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 32), test_proba1_df shape: (408, 32)
# tree_num: 32, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 33), test_proba1_df shape: (408, 33)
# tree_num: 33, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 34), test_proba1_df shape: (408, 34)
# tree_num: 34, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 35), test_proba1_df shape: (408, 35)
# tree_num: 35, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 36), test_proba1_df shape: (408, 36)
# tree_num: 36, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 37), test_proba1_df shape: (408, 37)
# tree_num: 37, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 38), test_proba1_df shape: (408, 38)
# tree_num: 38, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 39), test_proba1_df shape: (408, 39)
# tree_num: 39, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 40), test_proba1_df shape: (408, 40)
# tree_num: 40, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 41), test_proba1_df shape: (408, 41)
# tree_num: 41, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 42), test_proba1_df shape: (408, 42)
# tree_num: 42, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 43), test_proba1_df shape: (408, 43)
# tree_num: 43, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 44), test_proba1_df shape: (408, 44)
# tree_num: 44, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 45), test_proba1_df shape: (408, 45)
# tree_num: 45, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 46), test_proba1_df shape: (408, 46)
# tree_num: 46, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 47), test_proba1_df shape: (408, 47)
# tree_num: 47, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 48), test_proba1_df shape: (408, 48)
# tree_num: 48, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 49), test_proba1_df shape: (408, 49)
# tree_num: 49, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 50), test_proba1_df shape: (408, 50)
# tree_num: 50, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 51), test_proba1_df shape: (408, 51)
# tree_num: 51, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 52), test_proba1_df shape: (408, 52)
# tree_num: 52, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 53), test_proba1_df shape: (408, 53)
# tree_num: 53, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 54), test_proba1_df shape: (408, 54)
# tree_num: 54, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 55), test_proba1_df shape: (408, 55)
# tree_num: 55, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 56), test_proba1_df shape: (408, 56)
# tree_num: 56, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 57), test_proba1_df shape: (408, 57)
# tree_num: 57, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 58), test_proba1_df shape: (408, 58)
# tree_num: 58, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 59), test_proba1_df shape: (408, 59)
# tree_num: 59, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 60), test_proba1_df shape: (408, 60)
# tree_num: 60, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 61), test_proba1_df shape: (408, 61)
# tree_num: 61, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 62), test_proba1_df shape: (408, 62)
# tree_num: 62, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 63), test_proba1_df shape: (408, 63)
# tree_num: 63, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 64), test_proba1_df shape: (408, 64)
# tree_num: 64, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 65), test_proba1_df shape: (408, 65)
# tree_num: 65, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 66), test_proba1_df shape: (408, 66)
# tree_num: 66, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 67), test_proba1_df shape: (408, 67)
# tree_num: 67, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 68), test_proba1_df shape: (408, 68)
# tree_num: 68, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 69), test_proba1_df shape: (408, 69)
# tree_num: 69, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 70), test_proba1_df shape: (408, 70)
# tree_num: 70, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 71), test_proba1_df shape: (408, 71)
# tree_num: 71, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 72), test_proba1_df shape: (408, 72)
# tree_num: 72, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 73), test_proba1_df shape: (408, 73)
# tree_num: 73, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 74), test_proba1_df shape: (408, 74)
# tree_num: 74, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 75), test_proba1_df shape: (408, 75)
# tree_num: 75, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 76), test_proba1_df shape: (408, 76)
# tree_num: 76, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 77), test_proba1_df shape: (408, 77)
# tree_num: 77, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 78), test_proba1_df shape: (408, 78)
# tree_num: 78, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 79), test_proba1_df shape: (408, 79)
# tree_num: 79, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 80), test_proba1_df shape: (408, 80)
# tree_num: 80, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 81), test_proba1_df shape: (408, 81)
# tree_num: 81, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 82), test_proba1_df shape: (408, 82)
# tree_num: 82, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 83), test_proba1_df shape: (408, 83)
# tree_num: 83, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 84), test_proba1_df shape: (408, 84)
# tree_num: 84, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 85), test_proba1_df shape: (408, 85)
# tree_num: 85, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 86), test_proba1_df shape: (408, 86)
# tree_num: 86, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 87), test_proba1_df shape: (408, 87)
# tree_num: 87, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 88), test_proba1_df shape: (408, 88)
# tree_num: 88, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 89), test_proba1_df shape: (408, 89)
# tree_num: 89, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 90), test_proba1_df shape: (408, 90)
# tree_num: 90, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 91), test_proba1_df shape: (408, 91)
# tree_num: 91, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 92), test_proba1_df shape: (408, 92)
# tree_num: 92, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 93), test_proba1_df shape: (408, 93)
# tree_num: 93, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 94), test_proba1_df shape: (408, 94)
# tree_num: 94, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 95), test_proba1_df shape: (408, 95)
# tree_num: 95, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 96), test_proba1_df shape: (408, 96)
# tree_num: 96, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 97), test_proba1_df shape: (408, 97)
# tree_num: 97, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 98), test_proba1_df shape: (408, 98)
# tree_num: 98, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 99), test_proba1_df shape: (408, 99)
# tree_num: 99, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 100), test_proba1_df shape: (408, 100)
# in df tree prob function. std0 shape: (408,), std1 shape: (408,)
# feat: moe
#      std0_moe  std1_moe                                model              NEK  \
# 0    0.000000  0.000000  NEK2_inhibition_moe_UNDER_RF_batch2  NEK2_inhibition
# 1    0.487832  0.487832  NEK2_inhibition_moe_UNDER_RF_batch2  NEK2_inhibition
# 2    0.422953  0.422953  NEK2_inhibition_moe_UNDER_RF_batch2  NEK2_inhibition
# 3    0.000000  0.000000  NEK2_inhibition_moe_UNDER_RF_batch2  NEK2_inhibition
# 4    0.409360  0.409360  NEK2_inhibition_moe_UNDER_RF_batch2  NEK2_inhibition
# ..        ...       ...                                  ...              ...
# 403  0.326599  0.326599  NEK2_inhibition_moe_UNDER_RF_batch2  NEK2_inhibition
# 404  0.272660  0.272660  NEK2_inhibition_moe_UNDER_RF_batch2  NEK2_inhibition
# 405  0.487832  0.487832  NEK2_inhibition_moe_UNDER_RF_batch2  NEK2_inhibition
# 406  0.000000  0.000000  NEK2_inhibition_moe_UNDER_RF_batch2  NEK2_inhibition
# 407  0.487832  0.487832  NEK2_inhibition_moe_UNDER_RF_batch2  NEK2_inhibition
#
#          strategy feat_type RF_type
# 0    UNDER_batch2       moe      RF
# 1    UNDER_batch2       moe      RF
# 2    UNDER_batch2       moe      RF
# 3    UNDER_batch2       moe      RF
# 4    UNDER_batch2       moe      RF
# ..            ...       ...     ...
# 403  UNDER_batch2       moe      RF
# 404  UNDER_batch2       moe      RF
# 405  UNDER_batch2       moe      RF
# 406  UNDER_batch2       moe      RF
# 407  UNDER_batch2       moe      RF
#
# [408 rows x 7 columns]
# done
# concated df shape: (408, 7)
# NEK2 inhibition mfp
# test X shape (408, 2048)
# tree_num: 0, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 1), test_proba1_df shape: (408, 1)
# tree_num: 1, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 2), test_proba1_df shape: (408, 2)
# tree_num: 2, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 3), test_proba1_df shape: (408, 3)
# tree_num: 3, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 4), test_proba1_df shape: (408, 4)
# tree_num: 4, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 5), test_proba1_df shape: (408, 5)
# tree_num: 5, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 6), test_proba1_df shape: (408, 6)
# tree_num: 6, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 7), test_proba1_df shape: (408, 7)
# tree_num: 7, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 8), test_proba1_df shape: (408, 8)
# tree_num: 8, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 9), test_proba1_df shape: (408, 9)
# tree_num: 9, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 10), test_proba1_df shape: (408, 10)
# tree_num: 10, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 11), test_proba1_df shape: (408, 11)
# tree_num: 11, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 12), test_proba1_df shape: (408, 12)
# tree_num: 12, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 13), test_proba1_df shape: (408, 13)
# tree_num: 13, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 14), test_proba1_df shape: (408, 14)
# tree_num: 14, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 15), test_proba1_df shape: (408, 15)
# tree_num: 15, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 16), test_proba1_df shape: (408, 16)
# tree_num: 16, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 17), test_proba1_df shape: (408, 17)
# tree_num: 17, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 18), test_proba1_df shape: (408, 18)
# tree_num: 18, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 19), test_proba1_df shape: (408, 19)
# tree_num: 19, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 20), test_proba1_df shape: (408, 20)
# tree_num: 20, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 21), test_proba1_df shape: (408, 21)
# tree_num: 21, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 22), test_proba1_df shape: (408, 22)
# tree_num: 22, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 23), test_proba1_df shape: (408, 23)
# tree_num: 23, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 24), test_proba1_df shape: (408, 24)
# tree_num: 24, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 25), test_proba1_df shape: (408, 25)
# tree_num: 25, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 26), test_proba1_df shape: (408, 26)
# tree_num: 26, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 27), test_proba1_df shape: (408, 27)
# tree_num: 27, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 28), test_proba1_df shape: (408, 28)
# tree_num: 28, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 29), test_proba1_df shape: (408, 29)
# tree_num: 29, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 30), test_proba1_df shape: (408, 30)
# tree_num: 30, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 31), test_proba1_df shape: (408, 31)
# tree_num: 31, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 32), test_proba1_df shape: (408, 32)
# tree_num: 32, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 33), test_proba1_df shape: (408, 33)
# tree_num: 33, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 34), test_proba1_df shape: (408, 34)
# tree_num: 34, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 35), test_proba1_df shape: (408, 35)
# tree_num: 35, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 36), test_proba1_df shape: (408, 36)
# tree_num: 36, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 37), test_proba1_df shape: (408, 37)
# tree_num: 37, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 38), test_proba1_df shape: (408, 38)
# tree_num: 38, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 39), test_proba1_df shape: (408, 39)
# tree_num: 39, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 40), test_proba1_df shape: (408, 40)
# tree_num: 40, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 41), test_proba1_df shape: (408, 41)
# tree_num: 41, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 42), test_proba1_df shape: (408, 42)
# tree_num: 42, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 43), test_proba1_df shape: (408, 43)
# tree_num: 43, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 44), test_proba1_df shape: (408, 44)
# tree_num: 44, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 45), test_proba1_df shape: (408, 45)
# tree_num: 45, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 46), test_proba1_df shape: (408, 46)
# tree_num: 46, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 47), test_proba1_df shape: (408, 47)
# tree_num: 47, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 48), test_proba1_df shape: (408, 48)
# tree_num: 48, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 49), test_proba1_df shape: (408, 49)
# tree_num: 49, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 50), test_proba1_df shape: (408, 50)
# tree_num: 50, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 51), test_proba1_df shape: (408, 51)
# tree_num: 51, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 52), test_proba1_df shape: (408, 52)
# tree_num: 52, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 53), test_proba1_df shape: (408, 53)
# tree_num: 53, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 54), test_proba1_df shape: (408, 54)
# tree_num: 54, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 55), test_proba1_df shape: (408, 55)
# tree_num: 55, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 56), test_proba1_df shape: (408, 56)
# tree_num: 56, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 57), test_proba1_df shape: (408, 57)
# tree_num: 57, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 58), test_proba1_df shape: (408, 58)
# tree_num: 58, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 59), test_proba1_df shape: (408, 59)
# tree_num: 59, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 60), test_proba1_df shape: (408, 60)
# tree_num: 60, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 61), test_proba1_df shape: (408, 61)
# tree_num: 61, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 62), test_proba1_df shape: (408, 62)
# tree_num: 62, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 63), test_proba1_df shape: (408, 63)
# tree_num: 63, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 64), test_proba1_df shape: (408, 64)
# tree_num: 64, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 65), test_proba1_df shape: (408, 65)
# tree_num: 65, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 66), test_proba1_df shape: (408, 66)
# tree_num: 66, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 67), test_proba1_df shape: (408, 67)
# tree_num: 67, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 68), test_proba1_df shape: (408, 68)
# tree_num: 68, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 69), test_proba1_df shape: (408, 69)
# tree_num: 69, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 70), test_proba1_df shape: (408, 70)
# tree_num: 70, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 71), test_proba1_df shape: (408, 71)
# tree_num: 71, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 72), test_proba1_df shape: (408, 72)
# tree_num: 72, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 73), test_proba1_df shape: (408, 73)
# tree_num: 73, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 74), test_proba1_df shape: (408, 74)
# tree_num: 74, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 75), test_proba1_df shape: (408, 75)
# tree_num: 75, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 76), test_proba1_df shape: (408, 76)
# tree_num: 76, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 77), test_proba1_df shape: (408, 77)
# tree_num: 77, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 78), test_proba1_df shape: (408, 78)
# tree_num: 78, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 79), test_proba1_df shape: (408, 79)
# tree_num: 79, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 80), test_proba1_df shape: (408, 80)
# tree_num: 80, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 81), test_proba1_df shape: (408, 81)
# tree_num: 81, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 82), test_proba1_df shape: (408, 82)
# tree_num: 82, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 83), test_proba1_df shape: (408, 83)
# tree_num: 83, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 84), test_proba1_df shape: (408, 84)
# tree_num: 84, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 85), test_proba1_df shape: (408, 85)
# tree_num: 85, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 86), test_proba1_df shape: (408, 86)
# tree_num: 86, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 87), test_proba1_df shape: (408, 87)
# tree_num: 87, test_proba_temp shape: (408, 2)
# test_proba0_df shape: (408, 88), test_proba1_df shape: (408, 88)
# tree_num: 88, test_proba_temp shape: (408, 2)
# ...
# test_proba0_df shape: (80, 84), test_proba1_df shape: (80, 84)
# tree_num: 84, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 85), test_proba1_df shape: (80, 85)
# tree_num: 85, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 86), test_proba1_df shape: (80, 86)
# tree_num: 86, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 87), test_proba1_df shape: (80, 87)
# tree_num: 87, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 88), test_proba1_df shape: (80, 88)
# tree_num: 88, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 89), test_proba1_df shape: (80, 89)
# tree_num: 89, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 90), test_proba1_df shape: (80, 90)
# tree_num: 90, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 91), test_proba1_df shape: (80, 91)
# tree_num: 91, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 92), test_proba1_df shape: (80, 92)
# tree_num: 92, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 93), test_proba1_df shape: (80, 93)
# tree_num: 93, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 94), test_proba1_df shape: (80, 94)
# tree_num: 94, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 95), test_proba1_df shape: (80, 95)
# tree_num: 95, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 96), test_proba1_df shape: (80, 96)
# tree_num: 96, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 97), test_proba1_df shape: (80, 97)
# tree_num: 97, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 98), test_proba1_df shape: (80, 98)
# tree_num: 98, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 99), test_proba1_df shape: (80, 99)
# tree_num: 99, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 100), test_proba1_df shape: (80, 100)
# in df tree prob function. std0 shape: (80,), std1 shape: (80,)
# feat: moe
#     std0_moe  std1_moe                                model              NEK  \
# 0   0.000000  0.000000  NEK9_inhibition_moe_UNDER_RF_batch2  NEK9_inhibition
# 1   0.238683  0.238683  NEK9_inhibition_moe_UNDER_RF_batch2  NEK9_inhibition
# 2   0.000000  0.000000  NEK9_inhibition_moe_UNDER_RF_batch2  NEK9_inhibition
# 3   0.196946  0.196946  NEK9_inhibition_moe_UNDER_RF_batch2  NEK9_inhibition
# 4   0.497570  0.497570  NEK9_inhibition_moe_UNDER_RF_batch2  NEK9_inhibition
# ..       ...       ...                                  ...              ...
# 75  0.000000  0.000000  NEK9_inhibition_moe_UNDER_RF_batch2  NEK9_inhibition
# 76  0.368453  0.368453  NEK9_inhibition_moe_UNDER_RF_batch2  NEK9_inhibition
# 77  0.000000  0.000000  NEK9_inhibition_moe_UNDER_RF_batch2  NEK9_inhibition
# 78  0.000000  0.000000  NEK9_inhibition_moe_UNDER_RF_batch2  NEK9_inhibition
# 79  0.000000  0.000000  NEK9_inhibition_moe_UNDER_RF_batch2  NEK9_inhibition
#
#         strategy feat_type RF_type
# 0   UNDER_batch2       moe      RF
# 1   UNDER_batch2       moe      RF
# 2   UNDER_batch2       moe      RF
# 3   UNDER_batch2       moe      RF
# 4   UNDER_batch2       moe      RF
# ..           ...       ...     ...
# 75  UNDER_batch2       moe      RF
# 76  UNDER_batch2       moe      RF
# 77  UNDER_batch2       moe      RF
# 78  UNDER_batch2       moe      RF
# 79  UNDER_batch2       moe      RF
#
# [80 rows x 7 columns]
# done
# concated df shape: (80, 7)
# NEK9 inhibition mfp
# test X shape (80, 2048)
# tree_num: 0, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 1), test_proba1_df shape: (80, 1)
# tree_num: 1, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 2), test_proba1_df shape: (80, 2)
# tree_num: 2, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 3), test_proba1_df shape: (80, 3)
# tree_num: 3, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 4), test_proba1_df shape: (80, 4)
# tree_num: 4, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 5), test_proba1_df shape: (80, 5)
# tree_num: 5, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 6), test_proba1_df shape: (80, 6)
# tree_num: 6, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 7), test_proba1_df shape: (80, 7)
# tree_num: 7, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 8), test_proba1_df shape: (80, 8)
# tree_num: 8, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 9), test_proba1_df shape: (80, 9)
# tree_num: 9, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 10), test_proba1_df shape: (80, 10)
# tree_num: 10, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 11), test_proba1_df shape: (80, 11)
# tree_num: 11, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 12), test_proba1_df shape: (80, 12)
# tree_num: 12, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 13), test_proba1_df shape: (80, 13)
# tree_num: 13, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 14), test_proba1_df shape: (80, 14)
# tree_num: 14, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 15), test_proba1_df shape: (80, 15)
# tree_num: 15, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 16), test_proba1_df shape: (80, 16)
# tree_num: 16, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 17), test_proba1_df shape: (80, 17)
# tree_num: 17, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 18), test_proba1_df shape: (80, 18)
# tree_num: 18, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 19), test_proba1_df shape: (80, 19)
# tree_num: 19, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 20), test_proba1_df shape: (80, 20)
# tree_num: 20, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 21), test_proba1_df shape: (80, 21)
# tree_num: 21, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 22), test_proba1_df shape: (80, 22)
# tree_num: 22, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 23), test_proba1_df shape: (80, 23)
# tree_num: 23, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 24), test_proba1_df shape: (80, 24)
# tree_num: 24, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 25), test_proba1_df shape: (80, 25)
# tree_num: 25, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 26), test_proba1_df shape: (80, 26)
# tree_num: 26, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 27), test_proba1_df shape: (80, 27)
# tree_num: 27, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 28), test_proba1_df shape: (80, 28)
# tree_num: 28, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 29), test_proba1_df shape: (80, 29)
# tree_num: 29, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 30), test_proba1_df shape: (80, 30)
# tree_num: 30, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 31), test_proba1_df shape: (80, 31)
# tree_num: 31, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 32), test_proba1_df shape: (80, 32)
# tree_num: 32, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 33), test_proba1_df shape: (80, 33)
# tree_num: 33, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 34), test_proba1_df shape: (80, 34)
# tree_num: 34, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 35), test_proba1_df shape: (80, 35)
# tree_num: 35, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 36), test_proba1_df shape: (80, 36)
# tree_num: 36, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 37), test_proba1_df shape: (80, 37)
# tree_num: 37, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 38), test_proba1_df shape: (80, 38)
# tree_num: 38, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 39), test_proba1_df shape: (80, 39)
# tree_num: 39, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 40), test_proba1_df shape: (80, 40)
# tree_num: 40, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 41), test_proba1_df shape: (80, 41)
# tree_num: 41, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 42), test_proba1_df shape: (80, 42)
# tree_num: 42, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 43), test_proba1_df shape: (80, 43)
# tree_num: 43, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 44), test_proba1_df shape: (80, 44)
# tree_num: 44, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 45), test_proba1_df shape: (80, 45)
# tree_num: 45, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 46), test_proba1_df shape: (80, 46)
# tree_num: 46, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 47), test_proba1_df shape: (80, 47)
# tree_num: 47, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 48), test_proba1_df shape: (80, 48)
# tree_num: 48, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 49), test_proba1_df shape: (80, 49)
# tree_num: 49, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 50), test_proba1_df shape: (80, 50)
# tree_num: 50, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 51), test_proba1_df shape: (80, 51)
# tree_num: 51, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 52), test_proba1_df shape: (80, 52)
# tree_num: 52, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 53), test_proba1_df shape: (80, 53)
# tree_num: 53, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 54), test_proba1_df shape: (80, 54)
# tree_num: 54, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 55), test_proba1_df shape: (80, 55)
# tree_num: 55, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 56), test_proba1_df shape: (80, 56)
# tree_num: 56, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 57), test_proba1_df shape: (80, 57)
# tree_num: 57, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 58), test_proba1_df shape: (80, 58)
# tree_num: 58, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 59), test_proba1_df shape: (80, 59)
# tree_num: 59, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 60), test_proba1_df shape: (80, 60)
# tree_num: 60, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 61), test_proba1_df shape: (80, 61)
# tree_num: 61, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 62), test_proba1_df shape: (80, 62)
# tree_num: 62, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 63), test_proba1_df shape: (80, 63)
# tree_num: 63, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 64), test_proba1_df shape: (80, 64)
# tree_num: 64, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 65), test_proba1_df shape: (80, 65)
# tree_num: 65, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 66), test_proba1_df shape: (80, 66)
# tree_num: 66, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 67), test_proba1_df shape: (80, 67)
# tree_num: 67, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 68), test_proba1_df shape: (80, 68)
# tree_num: 68, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 69), test_proba1_df shape: (80, 69)
# tree_num: 69, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 70), test_proba1_df shape: (80, 70)
# tree_num: 70, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 71), test_proba1_df shape: (80, 71)
# tree_num: 71, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 72), test_proba1_df shape: (80, 72)
# tree_num: 72, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 73), test_proba1_df shape: (80, 73)
# tree_num: 73, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 74), test_proba1_df shape: (80, 74)
# tree_num: 74, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 75), test_proba1_df shape: (80, 75)
# tree_num: 75, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 76), test_proba1_df shape: (80, 76)
# tree_num: 76, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 77), test_proba1_df shape: (80, 77)
# tree_num: 77, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 78), test_proba1_df shape: (80, 78)
# tree_num: 78, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 79), test_proba1_df shape: (80, 79)
# tree_num: 79, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 80), test_proba1_df shape: (80, 80)
# tree_num: 80, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 81), test_proba1_df shape: (80, 81)
# tree_num: 81, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 82), test_proba1_df shape: (80, 82)
# tree_num: 82, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 83), test_proba1_df shape: (80, 83)
# tree_num: 83, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 84), test_proba1_df shape: (80, 84)
# tree_num: 84, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 85), test_proba1_df shape: (80, 85)
# tree_num: 85, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 86), test_proba1_df shape: (80, 86)
# tree_num: 86, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 87), test_proba1_df shape: (80, 87)
# tree_num: 87, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 88), test_proba1_df shape: (80, 88)
# tree_num: 88, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 89), test_proba1_df shape: (80, 89)
# tree_num: 89, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 90), test_proba1_df shape: (80, 90)
# tree_num: 90, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 91), test_proba1_df shape: (80, 91)
# tree_num: 91, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 92), test_proba1_df shape: (80, 92)
# tree_num: 92, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 93), test_proba1_df shape: (80, 93)
# tree_num: 93, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 94), test_proba1_df shape: (80, 94)
# tree_num: 94, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 95), test_proba1_df shape: (80, 95)
# tree_num: 95, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 96), test_proba1_df shape: (80, 96)
# tree_num: 96, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 97), test_proba1_df shape: (80, 97)
# tree_num: 97, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 98), test_proba1_df shape: (80, 98)
# tree_num: 98, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 99), test_proba1_df shape: (80, 99)
# tree_num: 99, test_proba_temp shape: (80, 2)
# test_proba0_df shape: (80, 100), test_proba1_df shape: (80, 100)
# in df tree prob function. std0 shape: (80,), std1 shape: (80,)
# feat: mfp
#     std0_moe  std0_mfp  std1_moe  std1_mfp  \
# 0   0.000000  0.070353  0.000000  0.070353
# 1   0.238683  0.070353  0.238683  0.070353
# 2   0.000000  0.236291  0.000000  0.236291
# 3   0.196946  0.085723  0.196946  0.085723
# 4   0.497570  0.000000  0.497570  0.000000
# ..       ...       ...       ...       ...
# 75  0.000000  0.429235  0.000000  0.429235
# 76  0.368453  0.150756  0.368453  0.150756
# 77  0.000000  0.000000  0.000000  0.000000
# 78  0.000000  0.000000  0.000000  0.000000
# 79  0.000000  0.429235  0.000000  0.429235
#
#                                   model              NEK      strategy  \
# 0   NEK9_inhibition_mfp_UNDER_RF_batch2  NEK9_inhibition  UNDER_batch2
# 1   NEK9_inhibition_mfp_UNDER_RF_batch2  NEK9_inhibition  UNDER_batch2
# 2   NEK9_inhibition_mfp_UNDER_RF_batch2  NEK9_inhibition  UNDER_batch2
# 3   NEK9_inhibition_mfp_UNDER_RF_batch2  NEK9_inhibition  UNDER_batch2
# 4   NEK9_inhibition_mfp_UNDER_RF_batch2  NEK9_inhibition  UNDER_batch2
# ..                                  ...              ...           ...
# 75  NEK9_inhibition_mfp_UNDER_RF_batch2  NEK9_inhibition  UNDER_batch2
# 76  NEK9_inhibition_mfp_UNDER_RF_batch2  NEK9_inhibition  UNDER_batch2
# 77  NEK9_inhibition_mfp_UNDER_RF_batch2  NEK9_inhibition  UNDER_batch2
# 78  NEK9_inhibition_mfp_UNDER_RF_batch2  NEK9_inhibition  UNDER_batch2
# 79  NEK9_inhibition_mfp_UNDER_RF_batch2  NEK9_inhibition  UNDER_batch2
#
#    feat_type RF_type
# 0        mfp      RF
# 1        mfp      RF
# 2        mfp      RF
# 3        mfp      RF
# 4        mfp      RF
# ..       ...     ...
# 75       mfp      RF
# 76       mfp      RF
# 77       mfp      RF
# 78       mfp      RF
# 79       mfp      RF
#
# [80 rows x 9 columns]
# done
# concated df shape: (80, 9)

# %%
# Out:
# array(['mfp'], dtype=object)
