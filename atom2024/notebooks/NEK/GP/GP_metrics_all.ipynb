# %%
import math
import numpy as np
import pandas as pd
import seaborn as sns
import os
import sklearn
from sklearn.metrics import precision_score, recall_score, roc_auc_score, matthews_corrcoef, balanced_accuracy_score, confusion_matrix
import sys
sys.path.append('/Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/')
from RF_atomver import *

# %% [markdown]
# # adding CM and prediction types to all GP dataframes

# %%
metric_cols = ['model',  'accuracy', 'precision', 'recall', 'specificity',
       'TN', 'FN', 'FP', 'TP', 'cm','ROC-AUC']
def all_GP_metrics(file_path, filename): 
    df = pd.read_csv(file_path+filename)
    
    df['ROC-AUC'] = roc_auc_score(df['y'], df['y_pred'])
    results = df.iloc[[0]]
    results[metric_cols]
    results = results[metric_cols].values
    # model_names = []
    # acc =[] 
    # prec = [] 
    # recall = [] 
    # spec = [] 
    # rocauc = [] 
    # tn = []
    # fn = [] 
    # fp = []
    # train_tp = [] 
    return results

# %%
# df = pd.read_csv(result_path+'NEK2_binding_mfp_ADASYN_train_GP.csv')

# df['ROC-AUC'] = roc_auc_score(df['y'], df['y_pred'])
# train_model_names = []
# train_acc =[] 
# train_prec = [] 
# train_recall = [] 
# train_spec = [] 
# train_rocauc = [] 
# train_tn = []
# train_fn = [] 
# train_fp = []
# train_tp = [] 
# train_results = df.iloc[[0]]


# train_results = train_results[metric_cols]

# %%
data_dir = '/Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/'
result_path  = '/Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/'
nek_nums = [2,3,5,9]
samplings = ['scaled', 'UNDER', 'SMOTE', 'ADASYN'] 
features = ['moe', 'mfp']
NEK= 'NEK'
train_results = [] 
test_results = [] 
for i, n in enumerate(nek_nums):
    nek = str(n)
    # print(f'NEK{nek}')
    nek_path= f'{data_dir}NEK{nek}/bind/'
    for k, feat in enumerate(features): 
        print()
        for j, samp in enumerate(samplings): 
        
            print(f'NEK{nek} bind {feat} {samp}')
            file_root = f'NEK{nek}_binding_{feat}_{samp}'
       
            train = all_GP_metrics(result_path, file_root+'_train_GP.csv') 
            test = all_GP_metrics(result_path, file_root+'_test_GP.csv') 
            train_results.append(train)
            test_results.append(test) 
            
            
        
            print()
            
            
    # print()
    
    if n == 2 or n == 9:

        nek_path= f'{data_dir}NEK{nek}/inhib/'
        for k, feat in enumerate(features): 
            print()
            for j, samp in enumerate(samplings): 
                file_root = f'NEK{nek}_inhibition_{feat}_{samp}'
                print(f'NEK{nek} inbhib{feat} {samp}')
                train = all_GP_metrics(result_path, file_root+'_train_GP.csv') 
                test = all_GP_metrics(result_path, file_root+'_test_GP.csv') 
                train_results.append(train)
                test_results.append(test) 
    
        
            
    print()
# Out:
# NEK2 bind moe scaled
#
# NEK2 bind moe UNDER
#
# NEK2 bind moe SMOTE
#
# NEK2 bind moe ADASYN
#
#
# NEK2 bind mfp scaled
#
# NEK2 bind mfp UNDER
#
# NEK2 bind mfp SMOTE
#
# NEK2 bind mfp ADASYN
#
#
# NEK2 inbhibmoe scaled
# NEK2 inbhibmoe UNDER
# NEK2 inbhibmoe SMOTE
# NEK2 inbhibmoe ADASYN
#
# NEK2 inbhibmfp scaled
# NEK2 inbhibmfp UNDER
# NEK2 inbhibmfp SMOTE
# NEK2 inbhibmfp ADASYN
#
#
# NEK3 bind moe scaled
#
# NEK3 bind moe UNDER
#
# NEK3 bind moe SMOTE
#
# NEK3 bind moe ADASYN
#
#
# NEK3 bind mfp scaled
#
# NEK3 bind mfp UNDER
#
# NEK3 bind mfp SMOTE
#
# NEK3 bind mfp ADASYN
#
#
#
# NEK5 bind moe scaled
#
# NEK5 bind moe UNDER
#
# NEK5 bind moe SMOTE
#
# NEK5 bind moe ADASYN
#
#
# NEK5 bind mfp scaled
#
# NEK5 bind mfp UNDER
#
# NEK5 bind mfp SMOTE
#
# NEK5 bind mfp ADASYN
#
#
#
# NEK9 bind moe scaled
#
# NEK9 bind moe UNDER
#
# NEK9 bind moe SMOTE
#
# NEK9 bind moe ADASYN
#
#
# NEK9 bind mfp scaled
#
# NEK9 bind mfp UNDER
#
# NEK9 bind mfp SMOTE
#
# NEK9 bind mfp ADASYN
#
#
# NEK9 inbhibmoe scaled
# NEK9 inbhibmoe UNDER
# NEK9 inbhibmoe SMOTE
# NEK9 inbhibmoe ADASYN
#
# NEK9 inbhibmfp scaled
# NEK9 inbhibmfp UNDER
# NEK9 inbhibmfp SMOTE
# NEK9 inbhibmfp ADASYN

# %%
train_results = np.squeeze(train_results, axis=1)
train_results

train_df =  pd.DataFrame(train_results,columns=metric_cols)
train_df
# Out:
#                             model  accuracy precision    recall specificity  \
# 0      NEK2_binding_moe_scaled_GP      0.96       0.0       0.0         1.0
# 1       NEK2_binding_moe_UNDER_GP       1.0       1.0       1.0         1.0
# 2       NEK2_binding_moe_SMOTE_GP  0.999074  0.998152       1.0    0.998148
# 3      NEK2_binding_moe_ADASYN_GP   0.99861  0.997225       1.0    0.997222
# 4      NEK2_binding_mfp_scaled_GP      0.96       0.0       0.0         1.0
# 5       NEK2_binding_mfp_UNDER_GP       1.0       1.0       1.0         1.0
# 6       NEK2_binding_mfp_SMOTE_GP  0.993056  0.999063  0.987037    0.999074
# 7      NEK2_binding_mfp_ADASYN_GP  0.994004  0.999071  0.988971    0.999074
# 8   NEK2_inhibition_moe_scaled_GP  0.933333       1.0  0.026786         1.0
# 9    NEK2_inhibition_moe_UNDER_GP       1.0       1.0       1.0         1.0
# 10   NEK2_inhibition_moe_SMOTE_GP  0.997702  0.995425       1.0    0.995404
# 11  NEK2_inhibition_moe_ADASYN_GP  0.997366  0.994744       1.0    0.994747
# 12  NEK2_inhibition_mfp_scaled_GP   0.95474       1.0  0.339286         1.0
# 13   NEK2_inhibition_mfp_UNDER_GP       1.0       1.0       1.0         1.0
# 14   NEK2_inhibition_mfp_SMOTE_GP  0.994419  0.994094  0.994747    0.994091
# 15  NEK2_inhibition_mfp_ADASYN_GP  0.995045  0.994684  0.995346    0.994747
# 16     NEK3_binding_moe_scaled_GP  0.942959       0.0       0.0         1.0
# 17      NEK3_binding_moe_UNDER_GP       1.0       1.0       1.0         1.0
# 18      NEK3_binding_moe_SMOTE_GP       1.0       1.0       1.0         1.0
# 19     NEK3_binding_moe_ADASYN_GP       1.0       1.0       1.0         1.0
# 20     NEK3_binding_mfp_scaled_GP  0.942959       0.0       0.0         1.0
# 21      NEK3_binding_mfp_UNDER_GP       1.0       1.0       1.0         1.0
# 22      NEK3_binding_mfp_SMOTE_GP  0.995747       1.0  0.991493         1.0
# 23     NEK3_binding_mfp_ADASYN_GP  0.996714       1.0   0.99347         1.0
# 24     NEK5_binding_moe_scaled_GP  0.922144       0.0       0.0         1.0
# 25      NEK5_binding_moe_UNDER_GP       1.0       1.0       1.0         1.0
# 26      NEK5_binding_moe_SMOTE_GP  0.999452  0.998905       1.0    0.998904
# 27     NEK5_binding_moe_ADASYN_GP  0.999454  0.998913       1.0    0.998904
# 28     NEK5_binding_mfp_scaled_GP  0.926188       1.0  0.051948         1.0
# 29      NEK5_binding_mfp_UNDER_GP       1.0       1.0       1.0         1.0
# 30      NEK5_binding_mfp_SMOTE_GP  0.995066  0.998895  0.991228    0.998904
# 31     NEK5_binding_mfp_ADASYN_GP  0.996122  0.998874  0.993281    0.998904
# 32     NEK9_binding_moe_scaled_GP  0.957371       0.0       0.0         1.0
# 33      NEK9_binding_moe_UNDER_GP       1.0       1.0       1.0         1.0
# 34      NEK9_binding_moe_SMOTE_GP  0.999536  0.999073       1.0    0.999072
# 35     NEK9_binding_moe_ADASYN_GP  0.999538   0.99908       1.0    0.999072
# 36     NEK9_binding_mfp_scaled_GP  0.957371       0.0       0.0         1.0
# 37      NEK9_binding_mfp_UNDER_GP       1.0       1.0       1.0         1.0
# 38      NEK9_binding_mfp_SMOTE_GP  0.994434  0.998131  0.990724    0.998145
# 39     NEK9_binding_mfp_ADASYN_GP  0.993998  0.998146   0.98989    0.998145
# 40  NEK9_inhibition_moe_scaled_GP  0.897764       1.0  0.030303         1.0
# 41   NEK9_inhibition_moe_UNDER_GP       1.0       1.0       1.0         1.0
# 42   NEK9_inhibition_moe_SMOTE_GP  0.994643  0.989399       1.0    0.989286
# 43  NEK9_inhibition_moe_ADASYN_GP  0.996429  0.992908       1.0    0.992857
# 44  NEK9_inhibition_mfp_scaled_GP  0.968051      0.96  0.727273    0.996429
# 45   NEK9_inhibition_mfp_UNDER_GP  0.984848  0.970588       1.0    0.969697
# 46   NEK9_inhibition_mfp_SMOTE_GP  0.991071  0.989324  0.992857    0.989286
# 47  NEK9_inhibition_mfp_ADASYN_GP  0.994595  0.989209       1.0    0.989286
#
#       TN   FN FP    TP                   cm   ROC-AUC
# 0   1080   45  0     0     [1080, 0, 45, 0]       0.5
# 1     45    0  0    45       [45, 0, 0, 45]       1.0
# 2   1078    0  2  1080   [1078, 2, 0, 1080]  0.999074
# 3   1077    0  3  1078   [1077, 3, 0, 1078]  0.998611
# 4   1080   45  0     0     [1080, 0, 45, 0]       0.5
# 5     45    0  0    45       [45, 0, 0, 45]       1.0
# 6   1079   14  1  1066  [1079, 1, 14, 1066]  0.993056
# 7   1079   12  1  1076  [1079, 1, 12, 1076]  0.994022
# 8   1523  109  0     3    [1523, 0, 109, 3]  0.513393
# 9    112    0  0   112     [112, 0, 0, 112]       1.0
# 10  1516    0  7  1523   [1516, 7, 0, 1523]  0.997702
# 11  1515    0  8  1514   [1515, 8, 0, 1514]  0.997374
# 12  1523   74  0    38    [1523, 0, 74, 38]  0.669643
# 13   112    0  0   112     [112, 0, 0, 112]       1.0
# 14  1514    8  9  1515   [1514, 9, 8, 1515]  0.994419
# 15  1515    7  8  1497   [1515, 8, 7, 1497]  0.995046
# 16  1058   64  0     0     [1058, 0, 64, 0]       0.5
# 17    64    0  0    64       [64, 0, 0, 64]       1.0
# 18  1058    0  0  1058   [1058, 0, 0, 1058]       1.0
# 19  1058    0  0  1055   [1058, 0, 0, 1055]       1.0
# 20  1058   64  0     0     [1058, 0, 64, 0]       0.5
# 21    64    0  0    64       [64, 0, 0, 64]       1.0
# 22  1058    9  0  1049   [1058, 0, 9, 1049]  0.995747
# 23  1058    7  0  1065   [1058, 0, 7, 1065]  0.996735
# 24   912   77  0     0      [912, 0, 77, 0]       0.5
# 25    77    0  0    77       [77, 0, 0, 77]       1.0
# 26   911    0  1   912     [911, 1, 0, 912]  0.999452
# 27   911    0  1   919     [911, 1, 0, 919]  0.999452
# 28   912   73  0     4      [912, 0, 73, 4]  0.525974
# 29    77    0  0    77       [77, 0, 0, 77]       1.0
# 30   911    8  1   904     [911, 1, 8, 904]  0.995066
# 31   911    6  1   887     [911, 1, 6, 887]  0.996092
# 32  1078   48  0     0     [1078, 0, 48, 0]       0.5
# 33    48    0  0    48       [48, 0, 0, 48]       1.0
# 34  1077    0  1  1078   [1077, 1, 0, 1078]  0.999536
# 35  1077    0  1  1086   [1077, 1, 0, 1086]  0.999536
# 36  1078   48  0     0     [1078, 0, 48, 0]       0.5
# 37    48    0  0    48       [48, 0, 0, 48]       1.0
# 38  1076   10  2  1068  [1076, 2, 10, 1068]  0.994434
# 39  1076   11  2  1077  [1076, 2, 11, 1077]  0.994017
# 40   280   32  0     1      [280, 0, 32, 1]  0.515152
# 41    33    0  0    33       [33, 0, 0, 33]       1.0
# 42   277    0  3   280     [277, 3, 0, 280]  0.994643
# 43   278    0  2   280     [278, 2, 0, 280]  0.996429
# 44   279    9  1    24      [279, 1, 9, 24]  0.861851
# 45    32    0  1    33       [32, 1, 0, 33]  0.984848
# 46   277    2  3   278     [277, 3, 2, 278]  0.991071
# 47   277    0  3   275     [277, 3, 0, 275]  0.994643

# %%
test_results = np.squeeze(test_results, axis=1)
test_results

test_df =  pd.DataFrame(test_results,columns=metric_cols)
test_df
# Out:
#                             model  accuracy precision    recall specificity  \
# 0      NEK2_binding_moe_scaled_GP  0.957597       0.0       0.0         1.0
# 1       NEK2_binding_moe_UNDER_GP  0.738516  0.102564  0.666667    0.741697
# 2       NEK2_binding_moe_SMOTE_GP  0.968198       0.8  0.333333     0.99631
# 3      NEK2_binding_moe_ADASYN_GP  0.961131  0.571429  0.333333     0.98893
# 4      NEK2_binding_mfp_scaled_GP  0.957597       0.0       0.0         1.0
# 5       NEK2_binding_mfp_UNDER_GP  0.954064       0.0       0.0     0.99631
# 6       NEK2_binding_mfp_SMOTE_GP  0.964664       1.0  0.166667         1.0
# 7      NEK2_binding_mfp_ADASYN_GP  0.964664       1.0  0.166667         1.0
# 8   NEK2_inhibition_moe_scaled_GP   0.93154       0.0       0.0         1.0
# 9    NEK2_inhibition_moe_UNDER_GP  0.865526  0.309859  0.785714    0.871391
# 10   NEK2_inhibition_moe_SMOTE_GP  0.948655  0.666667       0.5    0.981627
# 11  NEK2_inhibition_moe_ADASYN_GP    0.9511  0.681818  0.535714    0.981627
# 12  NEK2_inhibition_mfp_scaled_GP  0.943765       1.0  0.178571         1.0
# 13   NEK2_inhibition_mfp_UNDER_GP  0.105134  0.068878  0.964286    0.041995
# 14   NEK2_inhibition_mfp_SMOTE_GP  0.968215  0.894737  0.607143    0.994751
# 15  NEK2_inhibition_mfp_ADASYN_GP   0.96577  0.888889  0.571429    0.994751
# 16     NEK3_binding_moe_scaled_GP  0.939716       0.0       0.0         1.0
# 17      NEK3_binding_moe_UNDER_GP  0.932624       0.0       0.0    0.992453
# 18      NEK3_binding_moe_SMOTE_GP  0.890071  0.111111  0.117647    0.939623
# 19     NEK3_binding_moe_ADASYN_GP  0.886525  0.105263  0.117647    0.935849
# 20     NEK3_binding_mfp_scaled_GP  0.939716       0.0       0.0         1.0
# 21      NEK3_binding_mfp_UNDER_GP  0.464539   0.08125  0.764706    0.445283
# 22      NEK3_binding_mfp_SMOTE_GP  0.953901      0.75  0.352941    0.992453
# 23     NEK3_binding_mfp_ADASYN_GP  0.943262  0.555556  0.294118    0.984906
# 24     NEK5_binding_moe_scaled_GP  0.919355       0.0       0.0         1.0
# 25      NEK5_binding_moe_UNDER_GP  0.919355       0.0       0.0         1.0
# 26      NEK5_binding_moe_SMOTE_GP  0.927419      0.55      0.55    0.960526
# 27     NEK5_binding_moe_ADASYN_GP  0.939516  0.619048      0.65    0.964912
# 28     NEK5_binding_mfp_scaled_GP  0.923387       1.0      0.05         1.0
# 29      NEK5_binding_mfp_UNDER_GP  0.548387  0.096491      0.55    0.548246
# 30      NEK5_binding_mfp_SMOTE_GP  0.955645  0.846154      0.55    0.991228
# 31     NEK5_binding_mfp_ADASYN_GP  0.951613  0.833333       0.5    0.991228
# 32     NEK9_binding_moe_scaled_GP  0.954064       0.0       0.0         1.0
# 33      NEK9_binding_moe_UNDER_GP  0.628975  0.057692  0.461538    0.637037
# 34      NEK9_binding_moe_SMOTE_GP  0.943463       0.2  0.076923    0.985185
# 35     NEK9_binding_moe_ADASYN_GP  0.943463       0.2  0.076923    0.985185
# 36     NEK9_binding_mfp_scaled_GP  0.954064       0.0       0.0         1.0
# 37      NEK9_binding_mfp_UNDER_GP  0.954064       0.0       0.0         1.0
# 38      NEK9_binding_mfp_SMOTE_GP   0.95053  0.333333  0.076923    0.992593
# 39     NEK9_binding_mfp_ADASYN_GP   0.95053  0.333333  0.076923    0.992593
# 40  NEK9_inhibition_moe_scaled_GP     0.875       0.0       0.0    0.985915
# 41   NEK9_inhibition_moe_UNDER_GP    0.1125    0.1125       1.0         0.0
# 42   NEK9_inhibition_moe_SMOTE_GP      0.95  0.857143  0.666667    0.985915
# 43  NEK9_inhibition_moe_ADASYN_GP      0.95  0.857143  0.666667    0.985915
# 44  NEK9_inhibition_mfp_scaled_GP    0.9375  0.833333  0.555556    0.985915
# 45   NEK9_inhibition_mfp_UNDER_GP    0.8875       0.0       0.0         1.0
# 46   NEK9_inhibition_mfp_SMOTE_GP      0.95  0.857143  0.666667    0.985915
# 47  NEK9_inhibition_mfp_ADASYN_GP      0.95  0.857143  0.666667    0.985915
#
#      TN  FN   FP  TP                 cm   ROC-AUC
# 0   271  12    0   0    [271, 0, 12, 0]       0.5
# 1   201   4   70   8    [201, 70, 4, 8]  0.704182
# 2   270   8    1   4     [270, 1, 8, 4]  0.664822
# 3   268   8    3   4     [268, 3, 8, 4]  0.661132
# 4   271  12    0   0    [271, 0, 12, 0]       0.5
# 5   270  12    1   0    [270, 1, 12, 0]  0.498155
# 6   271  10    0   2    [271, 0, 10, 2]  0.583333
# 7   271  10    0   2    [271, 0, 10, 2]  0.583333
# 8   381  28    0   0    [381, 0, 28, 0]       0.5
# 9   332   6   49  22   [332, 49, 6, 22]  0.828553
# 10  374  14    7  14   [374, 7, 14, 14]  0.740814
# 11  374  13    7  15   [374, 7, 13, 15]  0.758671
# 12  381  23    0   5    [381, 0, 23, 5]  0.589286
# 13   16   1  365  27   [16, 365, 1, 27]   0.50314
# 14  379  11    2  17   [379, 2, 11, 17]  0.800947
# 15  379  12    2  16   [379, 2, 12, 16]   0.78309
# 16  265  17    0   0    [265, 0, 17, 0]       0.5
# 17  263  17    2   0    [263, 2, 17, 0]  0.496226
# 18  249  15   16   2   [249, 16, 15, 2]  0.528635
# 19  248  15   17   2   [248, 17, 15, 2]  0.526748
# 20  265  17    0   0    [265, 0, 17, 0]       0.5
# 21  118   4  147  13  [118, 147, 4, 13]  0.604994
# 22  263  11    2   6    [263, 2, 11, 6]  0.672697
# 23  261  12    4   5    [261, 4, 12, 5]  0.639512
# 24  228  20    0   0    [228, 0, 20, 0]       0.5
# 25  228  20    0   0    [228, 0, 20, 0]       0.5
# 26  219   9    9  11    [219, 9, 9, 11]  0.755263
# 27  220   7    8  13    [220, 8, 7, 13]  0.807456
# 28  228  19    0   1    [228, 0, 19, 1]     0.525
# 29  125   9  103  11  [125, 103, 9, 11]  0.549123
# 30  226   9    2  11    [226, 2, 9, 11]  0.770614
# 31  226  10    2  10   [226, 2, 10, 10]  0.745614
# 32  270  13    0   0    [270, 0, 13, 0]       0.5
# 33  172   7   98   6    [172, 98, 7, 6]  0.549288
# 34  266  12    4   1    [266, 4, 12, 1]  0.531054
# 35  266  12    4   1    [266, 4, 12, 1]  0.531054
# 36  270  13    0   0    [270, 0, 13, 0]       0.5
# 37  270  13    0   0    [270, 0, 13, 0]       0.5
# 38  268  12    2   1    [268, 2, 12, 1]  0.534758
# 39  268  12    2   1    [268, 2, 12, 1]  0.534758
# 40   70   9    1   0      [70, 1, 9, 0]  0.492958
# 41    0   0   71   9      [0, 71, 0, 9]       0.5
# 42   70   3    1   6      [70, 1, 3, 6]  0.826291
# 43   70   3    1   6      [70, 1, 3, 6]  0.826291
# 44   70   4    1   5      [70, 1, 4, 5]  0.770736
# 45   71   9    0   0      [71, 0, 9, 0]       0.5
# 46   70   3    1   6      [70, 1, 3, 6]  0.826291
# 47   70   3    1   6      [70, 1, 3, 6]  0.826291

# %% [markdown]
# # Try to select the max and min for each of the metrics and display that model
# For all models together

# %%
# max_cols = ['accuracy', 'precision', 'recall', 'specificity',
#        'TN', 'FN', 'FP', 'TP', 'ROC-AUC']
max_cols = ['accuracy', 'precision', 'recall', 'specificity',
       'TN',  'TP', 'ROC-AUC']
min_cols = ['FN', 'FP']
max_rows = test_df.groupby('model')[max_cols].max()

max_rows
# Out:
#                                accuracy precision    recall specificity   TN  \
# model
# NEK2_binding_mfp_ADASYN_GP     0.964664       1.0  0.166667         1.0  271
# NEK2_binding_mfp_SMOTE_GP      0.964664       1.0  0.166667         1.0  271
# NEK2_binding_mfp_UNDER_GP      0.954064       0.0       0.0     0.99631  270
# NEK2_binding_mfp_scaled_GP     0.957597       0.0       0.0         1.0  271
# NEK2_binding_moe_ADASYN_GP     0.961131  0.571429  0.333333     0.98893  268
# NEK2_binding_moe_SMOTE_GP      0.968198       0.8  0.333333     0.99631  270
# NEK2_binding_moe_UNDER_GP      0.738516  0.102564  0.666667    0.741697  201
# NEK2_binding_moe_scaled_GP     0.957597       0.0       0.0         1.0  271
# NEK2_inhibition_mfp_ADASYN_GP   0.96577  0.888889  0.571429    0.994751  379
# NEK2_inhibition_mfp_SMOTE_GP   0.968215  0.894737  0.607143    0.994751  379
# NEK2_inhibition_mfp_UNDER_GP   0.105134  0.068878  0.964286    0.041995   16
# NEK2_inhibition_mfp_scaled_GP  0.943765       1.0  0.178571         1.0  381
# NEK2_inhibition_moe_ADASYN_GP    0.9511  0.681818  0.535714    0.981627  374
# NEK2_inhibition_moe_SMOTE_GP   0.948655  0.666667       0.5    0.981627  374
# NEK2_inhibition_moe_UNDER_GP   0.865526  0.309859  0.785714    0.871391  332
# NEK2_inhibition_moe_scaled_GP   0.93154       0.0       0.0         1.0  381
# NEK3_binding_mfp_ADASYN_GP     0.943262  0.555556  0.294118    0.984906  261
# NEK3_binding_mfp_SMOTE_GP      0.953901      0.75  0.352941    0.992453  263
# NEK3_binding_mfp_UNDER_GP      0.464539   0.08125  0.764706    0.445283  118
# NEK3_binding_mfp_scaled_GP     0.939716       0.0       0.0         1.0  265
# NEK3_binding_moe_ADASYN_GP     0.886525  0.105263  0.117647    0.935849  248
# NEK3_binding_moe_SMOTE_GP      0.890071  0.111111  0.117647    0.939623  249
# NEK3_binding_moe_UNDER_GP      0.932624       0.0       0.0    0.992453  263
# NEK3_binding_moe_scaled_GP     0.939716       0.0       0.0         1.0  265
# NEK5_binding_mfp_ADASYN_GP     0.951613  0.833333       0.5    0.991228  226
# NEK5_binding_mfp_SMOTE_GP      0.955645  0.846154      0.55    0.991228  226
# NEK5_binding_mfp_UNDER_GP      0.548387  0.096491      0.55    0.548246  125
# NEK5_binding_mfp_scaled_GP     0.923387       1.0      0.05         1.0  228
# NEK5_binding_moe_ADASYN_GP     0.939516  0.619048      0.65    0.964912  220
# NEK5_binding_moe_SMOTE_GP      0.927419      0.55      0.55    0.960526  219
# NEK5_binding_moe_UNDER_GP      0.919355       0.0       0.0         1.0  228
# NEK5_binding_moe_scaled_GP     0.919355       0.0       0.0         1.0  228
# NEK9_binding_mfp_ADASYN_GP      0.95053  0.333333  0.076923    0.992593  268
# NEK9_binding_mfp_SMOTE_GP       0.95053  0.333333  0.076923    0.992593  268
# NEK9_binding_mfp_UNDER_GP      0.954064       0.0       0.0         1.0  270
# NEK9_binding_mfp_scaled_GP     0.954064       0.0       0.0         1.0  270
# NEK9_binding_moe_ADASYN_GP     0.943463       0.2  0.076923    0.985185  266
# NEK9_binding_moe_SMOTE_GP      0.943463       0.2  0.076923    0.985185  266
# NEK9_binding_moe_UNDER_GP      0.628975  0.057692  0.461538    0.637037  172
# NEK9_binding_moe_scaled_GP     0.954064       0.0       0.0         1.0  270
# NEK9_inhibition_mfp_ADASYN_GP      0.95  0.857143  0.666667    0.985915   70
# NEK9_inhibition_mfp_SMOTE_GP       0.95  0.857143  0.666667    0.985915   70
# NEK9_inhibition_mfp_UNDER_GP     0.8875       0.0       0.0         1.0   71
# NEK9_inhibition_mfp_scaled_GP    0.9375  0.833333  0.555556    0.985915   70
# NEK9_inhibition_moe_ADASYN_GP      0.95  0.857143  0.666667    0.985915   70
# NEK9_inhibition_moe_SMOTE_GP       0.95  0.857143  0.666667    0.985915   70
# NEK9_inhibition_moe_UNDER_GP     0.1125    0.1125       1.0         0.0    0
# NEK9_inhibition_moe_scaled_GP     0.875       0.0       0.0    0.985915   70
#
#                                TP   ROC-AUC
# model
# NEK2_binding_mfp_ADASYN_GP      2  0.583333
# NEK2_binding_mfp_SMOTE_GP       2  0.583333
# NEK2_binding_mfp_UNDER_GP       0  0.498155
# NEK2_binding_mfp_scaled_GP      0       0.5
# NEK2_binding_moe_ADASYN_GP      4  0.661132
# NEK2_binding_moe_SMOTE_GP       4  0.664822
# NEK2_binding_moe_UNDER_GP       8  0.704182
# NEK2_binding_moe_scaled_GP      0       0.5
# NEK2_inhibition_mfp_ADASYN_GP  16   0.78309
# NEK2_inhibition_mfp_SMOTE_GP   17  0.800947
# NEK2_inhibition_mfp_UNDER_GP   27   0.50314
# NEK2_inhibition_mfp_scaled_GP   5  0.589286
# NEK2_inhibition_moe_ADASYN_GP  15  0.758671
# NEK2_inhibition_moe_SMOTE_GP   14  0.740814
# NEK2_inhibition_moe_UNDER_GP   22  0.828553
# NEK2_inhibition_moe_scaled_GP   0       0.5
# NEK3_binding_mfp_ADASYN_GP      5  0.639512
# NEK3_binding_mfp_SMOTE_GP       6  0.672697
# NEK3_binding_mfp_UNDER_GP      13  0.604994
# NEK3_binding_mfp_scaled_GP      0       0.5
# NEK3_binding_moe_ADASYN_GP      2  0.526748
# NEK3_binding_moe_SMOTE_GP       2  0.528635
# NEK3_binding_moe_UNDER_GP       0  0.496226
# NEK3_binding_moe_scaled_GP      0       0.5
# NEK5_binding_mfp_ADASYN_GP     10  0.745614
# NEK5_binding_mfp_SMOTE_GP      11  0.770614
# NEK5_binding_mfp_UNDER_GP      11  0.549123
# NEK5_binding_mfp_scaled_GP      1     0.525
# NEK5_binding_moe_ADASYN_GP     13  0.807456
# NEK5_binding_moe_SMOTE_GP      11  0.755263
# NEK5_binding_moe_UNDER_GP       0       0.5
# NEK5_binding_moe_scaled_GP      0       0.5
# NEK9_binding_mfp_ADASYN_GP      1  0.534758
# NEK9_binding_mfp_SMOTE_GP       1  0.534758
# NEK9_binding_mfp_UNDER_GP       0       0.5
# NEK9_binding_mfp_scaled_GP      0       0.5
# NEK9_binding_moe_ADASYN_GP      1  0.531054
# NEK9_binding_moe_SMOTE_GP       1  0.531054
# NEK9_binding_moe_UNDER_GP       6  0.549288
# NEK9_binding_moe_scaled_GP      0       0.5
# NEK9_inhibition_mfp_ADASYN_GP   6  0.826291
# NEK9_inhibition_mfp_SMOTE_GP    6  0.826291
# NEK9_inhibition_mfp_UNDER_GP    0       0.5
# NEK9_inhibition_mfp_scaled_GP   5  0.770736
# NEK9_inhibition_moe_ADASYN_GP   6  0.826291
# NEK9_inhibition_moe_SMOTE_GP    6  0.826291
# NEK9_inhibition_moe_UNDER_GP    9       0.5
# NEK9_inhibition_moe_scaled_GP   0  0.492958

# %%
min_cols = ['FN', 'FP']
min_rows = test_df.groupby('model')[min_cols].max()
min_rows
# Out:
#                                FN   FP
# model
# NEK2_binding_mfp_ADASYN_GP     10    0
# NEK2_binding_mfp_SMOTE_GP      10    0
# NEK2_binding_mfp_UNDER_GP      12    1
# NEK2_binding_mfp_scaled_GP     12    0
# NEK2_binding_moe_ADASYN_GP      8    3
# NEK2_binding_moe_SMOTE_GP       8    1
# NEK2_binding_moe_UNDER_GP       4   70
# NEK2_binding_moe_scaled_GP     12    0
# NEK2_inhibition_mfp_ADASYN_GP  12    2
# NEK2_inhibition_mfp_SMOTE_GP   11    2
# NEK2_inhibition_mfp_UNDER_GP    1  365
# NEK2_inhibition_mfp_scaled_GP  23    0
# NEK2_inhibition_moe_ADASYN_GP  13    7
# NEK2_inhibition_moe_SMOTE_GP   14    7
# NEK2_inhibition_moe_UNDER_GP    6   49
# NEK2_inhibition_moe_scaled_GP  28    0
# NEK3_binding_mfp_ADASYN_GP     12    4
# NEK3_binding_mfp_SMOTE_GP      11    2
# NEK3_binding_mfp_UNDER_GP       4  147
# NEK3_binding_mfp_scaled_GP     17    0
# NEK3_binding_moe_ADASYN_GP     15   17
# NEK3_binding_moe_SMOTE_GP      15   16
# NEK3_binding_moe_UNDER_GP      17    2
# NEK3_binding_moe_scaled_GP     17    0
# NEK5_binding_mfp_ADASYN_GP     10    2
# NEK5_binding_mfp_SMOTE_GP       9    2
# NEK5_binding_mfp_UNDER_GP       9  103
# NEK5_binding_mfp_scaled_GP     19    0
# NEK5_binding_moe_ADASYN_GP      7    8
# NEK5_binding_moe_SMOTE_GP       9    9
# NEK5_binding_moe_UNDER_GP      20    0
# NEK5_binding_moe_scaled_GP     20    0
# NEK9_binding_mfp_ADASYN_GP     12    2
# NEK9_binding_mfp_SMOTE_GP      12    2
# NEK9_binding_mfp_UNDER_GP      13    0
# NEK9_binding_mfp_scaled_GP     13    0
# NEK9_binding_moe_ADASYN_GP     12    4
# NEK9_binding_moe_SMOTE_GP      12    4
# NEK9_binding_moe_UNDER_GP       7   98
# NEK9_binding_moe_scaled_GP     13    0
# NEK9_inhibition_mfp_ADASYN_GP   3    1
# NEK9_inhibition_mfp_SMOTE_GP    3    1
# NEK9_inhibition_mfp_UNDER_GP    9    0
# NEK9_inhibition_mfp_scaled_GP   4    1
# NEK9_inhibition_moe_ADASYN_GP   3    1
# NEK9_inhibition_moe_SMOTE_GP    3    1
# NEK9_inhibition_moe_UNDER_GP    0   71
# NEK9_inhibition_moe_scaled_GP   9    1

# %% [markdown]
# # Displaying the max metric more clearly ?
# for all models together

# %%
for i, metric in enumerate(max_cols): 
    max_metric = test_df.loc[test_df[metric].idxmax()]
    print(f'{metric}:')
    display(max_metric)
    print()
print()
print('\nLowest FN and FP\n')
for i, metric in enumerate(min_cols): 
    min_metric = test_df.loc[test_df[metric].idxmax()]
    print(f'{metric}:')
    display(min_metric)
    print()
# Out:
# accuracy:
# model          NEK2_inhibition_mfp_SMOTE_GP
# accuracy                           0.968215
# precision                          0.894737
# recall                             0.607143
# specificity                        0.994751
# TN                                      379
# FN                                       11
# FP                                        2
# TP                                       17
# cm                         [379, 2, 11, 17]
# ROC-AUC                            0.800947
# Name: 14, dtype: object
# precision:
# model          NEK2_binding_mfp_SMOTE_GP
# accuracy                        0.964664
# precision                            1.0
# recall                          0.166667
# specificity                          1.0
# TN                                   271
# FN                                    10
# FP                                     0
# TP                                     2
# cm                       [271, 0, 10, 2]
# ROC-AUC                         0.583333
# Name: 6, dtype: object
# recall:
# model          NEK9_inhibition_moe_UNDER_GP
# accuracy                             0.1125
# precision                            0.1125
# recall                                  1.0
# specificity                             0.0
# TN                                        0
# FN                                        0
# FP                                       71
# TP                                        9
# cm                            [0, 71, 0, 9]
# ROC-AUC                                 0.5
# Name: 41, dtype: object
# specificity:
# model          NEK2_binding_moe_scaled_GP
# accuracy                         0.957597
# precision                             0.0
# recall                                0.0
# specificity                           1.0
# TN                                    271
# FN                                     12
# FP                                      0
# TP                                      0
# cm                        [271, 0, 12, 0]
# ROC-AUC                               0.5
# Name: 0, dtype: object
# TN:
# model          NEK2_inhibition_moe_scaled_GP
# accuracy                             0.93154
# precision                                0.0
# recall                                   0.0
# specificity                              1.0
# TN                                       381
# FN                                        28
# FP                                         0
# TP                                         0
# cm                           [381, 0, 28, 0]
# ROC-AUC                                  0.5
# Name: 8, dtype: object
# TP:
# model          NEK2_inhibition_mfp_UNDER_GP
# accuracy                           0.105134
# precision                          0.068878
# recall                             0.964286
# specificity                        0.041995
# TN                                       16
# FN                                        1
# FP                                      365
# TP                                       27
# cm                         [16, 365, 1, 27]
# ROC-AUC                             0.50314
# Name: 13, dtype: object
# ROC-AUC:
# model          NEK2_inhibition_moe_UNDER_GP
# accuracy                           0.865526
# precision                          0.309859
# recall                             0.785714
# specificity                        0.871391
# TN                                      332
# FN                                        6
# FP                                       49
# TP                                       22
# cm                         [332, 49, 6, 22]
# ROC-AUC                            0.828553
# Name: 9, dtype: object
# Lowest FN and FP
#
# FN:
# model          NEK2_inhibition_moe_scaled_GP
# accuracy                             0.93154
# precision                                0.0
# recall                                   0.0
# specificity                              1.0
# TN                                       381
# FN                                        28
# FP                                         0
# TP                                         0
# cm                           [381, 0, 28, 0]
# ROC-AUC                                  0.5
# Name: 8, dtype: object
# FP:
# model          NEK2_inhibition_mfp_UNDER_GP
# accuracy                           0.105134
# precision                          0.068878
# recall                             0.964286
# specificity                        0.041995
# TN                                       16
# FN                                        1
# FP                                      365
# TP                                       27
# cm                         [16, 365, 1, 27]
# ROC-AUC                             0.50314
# Name: 13, dtype: object

# %% [markdown]
# # Adding a 'NEK#' column
# so it's easier to compare across one type of nek

# %%
new_test = test_df
new_test['NEK'] = new_test['model'].str[0:4]
new_test
# Out:
#                             model  accuracy precision    recall specificity  \
# 0      NEK2_binding_moe_scaled_GP  0.957597       0.0       0.0         1.0
# 1       NEK2_binding_moe_UNDER_GP  0.738516  0.102564  0.666667    0.741697
# 2       NEK2_binding_moe_SMOTE_GP  0.968198       0.8  0.333333     0.99631
# 3      NEK2_binding_moe_ADASYN_GP  0.961131  0.571429  0.333333     0.98893
# 4      NEK2_binding_mfp_scaled_GP  0.957597       0.0       0.0         1.0
# 5       NEK2_binding_mfp_UNDER_GP  0.954064       0.0       0.0     0.99631
# 6       NEK2_binding_mfp_SMOTE_GP  0.964664       1.0  0.166667         1.0
# 7      NEK2_binding_mfp_ADASYN_GP  0.964664       1.0  0.166667         1.0
# 8   NEK2_inhibition_moe_scaled_GP   0.93154       0.0       0.0         1.0
# 9    NEK2_inhibition_moe_UNDER_GP  0.865526  0.309859  0.785714    0.871391
# 10   NEK2_inhibition_moe_SMOTE_GP  0.948655  0.666667       0.5    0.981627
# 11  NEK2_inhibition_moe_ADASYN_GP    0.9511  0.681818  0.535714    0.981627
# 12  NEK2_inhibition_mfp_scaled_GP  0.943765       1.0  0.178571         1.0
# 13   NEK2_inhibition_mfp_UNDER_GP  0.105134  0.068878  0.964286    0.041995
# 14   NEK2_inhibition_mfp_SMOTE_GP  0.968215  0.894737  0.607143    0.994751
# 15  NEK2_inhibition_mfp_ADASYN_GP   0.96577  0.888889  0.571429    0.994751
# 16     NEK3_binding_moe_scaled_GP  0.939716       0.0       0.0         1.0
# 17      NEK3_binding_moe_UNDER_GP  0.932624       0.0       0.0    0.992453
# 18      NEK3_binding_moe_SMOTE_GP  0.890071  0.111111  0.117647    0.939623
# 19     NEK3_binding_moe_ADASYN_GP  0.886525  0.105263  0.117647    0.935849
# 20     NEK3_binding_mfp_scaled_GP  0.939716       0.0       0.0         1.0
# 21      NEK3_binding_mfp_UNDER_GP  0.464539   0.08125  0.764706    0.445283
# 22      NEK3_binding_mfp_SMOTE_GP  0.953901      0.75  0.352941    0.992453
# 23     NEK3_binding_mfp_ADASYN_GP  0.943262  0.555556  0.294118    0.984906
# 24     NEK5_binding_moe_scaled_GP  0.919355       0.0       0.0         1.0
# 25      NEK5_binding_moe_UNDER_GP  0.919355       0.0       0.0         1.0
# 26      NEK5_binding_moe_SMOTE_GP  0.927419      0.55      0.55    0.960526
# 27     NEK5_binding_moe_ADASYN_GP  0.939516  0.619048      0.65    0.964912
# 28     NEK5_binding_mfp_scaled_GP  0.923387       1.0      0.05         1.0
# 29      NEK5_binding_mfp_UNDER_GP  0.548387  0.096491      0.55    0.548246
# 30      NEK5_binding_mfp_SMOTE_GP  0.955645  0.846154      0.55    0.991228
# 31     NEK5_binding_mfp_ADASYN_GP  0.951613  0.833333       0.5    0.991228
# 32     NEK9_binding_moe_scaled_GP  0.954064       0.0       0.0         1.0
# 33      NEK9_binding_moe_UNDER_GP  0.628975  0.057692  0.461538    0.637037
# 34      NEK9_binding_moe_SMOTE_GP  0.943463       0.2  0.076923    0.985185
# 35     NEK9_binding_moe_ADASYN_GP  0.943463       0.2  0.076923    0.985185
# 36     NEK9_binding_mfp_scaled_GP  0.954064       0.0       0.0         1.0
# 37      NEK9_binding_mfp_UNDER_GP  0.954064       0.0       0.0         1.0
# 38      NEK9_binding_mfp_SMOTE_GP   0.95053  0.333333  0.076923    0.992593
# 39     NEK9_binding_mfp_ADASYN_GP   0.95053  0.333333  0.076923    0.992593
# 40  NEK9_inhibition_moe_scaled_GP     0.875       0.0       0.0    0.985915
# 41   NEK9_inhibition_moe_UNDER_GP    0.1125    0.1125       1.0         0.0
# 42   NEK9_inhibition_moe_SMOTE_GP      0.95  0.857143  0.666667    0.985915
# 43  NEK9_inhibition_moe_ADASYN_GP      0.95  0.857143  0.666667    0.985915
# 44  NEK9_inhibition_mfp_scaled_GP    0.9375  0.833333  0.555556    0.985915
# 45   NEK9_inhibition_mfp_UNDER_GP    0.8875       0.0       0.0         1.0
# 46   NEK9_inhibition_mfp_SMOTE_GP      0.95  0.857143  0.666667    0.985915
# 47  NEK9_inhibition_mfp_ADASYN_GP      0.95  0.857143  0.666667    0.985915
#
#      TN  FN   FP  TP                 cm   ROC-AUC   NEK
# 0   271  12    0   0    [271, 0, 12, 0]       0.5  NEK2
# 1   201   4   70   8    [201, 70, 4, 8]  0.704182  NEK2
# 2   270   8    1   4     [270, 1, 8, 4]  0.664822  NEK2
# 3   268   8    3   4     [268, 3, 8, 4]  0.661132  NEK2
# 4   271  12    0   0    [271, 0, 12, 0]       0.5  NEK2
# 5   270  12    1   0    [270, 1, 12, 0]  0.498155  NEK2
# 6   271  10    0   2    [271, 0, 10, 2]  0.583333  NEK2
# 7   271  10    0   2    [271, 0, 10, 2]  0.583333  NEK2
# 8   381  28    0   0    [381, 0, 28, 0]       0.5  NEK2
# 9   332   6   49  22   [332, 49, 6, 22]  0.828553  NEK2
# 10  374  14    7  14   [374, 7, 14, 14]  0.740814  NEK2
# 11  374  13    7  15   [374, 7, 13, 15]  0.758671  NEK2
# 12  381  23    0   5    [381, 0, 23, 5]  0.589286  NEK2
# 13   16   1  365  27   [16, 365, 1, 27]   0.50314  NEK2
# 14  379  11    2  17   [379, 2, 11, 17]  0.800947  NEK2
# 15  379  12    2  16   [379, 2, 12, 16]   0.78309  NEK2
# 16  265  17    0   0    [265, 0, 17, 0]       0.5  NEK3
# 17  263  17    2   0    [263, 2, 17, 0]  0.496226  NEK3
# 18  249  15   16   2   [249, 16, 15, 2]  0.528635  NEK3
# 19  248  15   17   2   [248, 17, 15, 2]  0.526748  NEK3
# 20  265  17    0   0    [265, 0, 17, 0]       0.5  NEK3
# 21  118   4  147  13  [118, 147, 4, 13]  0.604994  NEK3
# 22  263  11    2   6    [263, 2, 11, 6]  0.672697  NEK3
# 23  261  12    4   5    [261, 4, 12, 5]  0.639512  NEK3
# 24  228  20    0   0    [228, 0, 20, 0]       0.5  NEK5
# 25  228  20    0   0    [228, 0, 20, 0]       0.5  NEK5
# 26  219   9    9  11    [219, 9, 9, 11]  0.755263  NEK5
# 27  220   7    8  13    [220, 8, 7, 13]  0.807456  NEK5
# 28  228  19    0   1    [228, 0, 19, 1]     0.525  NEK5
# 29  125   9  103  11  [125, 103, 9, 11]  0.549123  NEK5
# 30  226   9    2  11    [226, 2, 9, 11]  0.770614  NEK5
# 31  226  10    2  10   [226, 2, 10, 10]  0.745614  NEK5
# 32  270  13    0   0    [270, 0, 13, 0]       0.5  NEK9
# 33  172   7   98   6    [172, 98, 7, 6]  0.549288  NEK9
# 34  266  12    4   1    [266, 4, 12, 1]  0.531054  NEK9
# 35  266  12    4   1    [266, 4, 12, 1]  0.531054  NEK9
# 36  270  13    0   0    [270, 0, 13, 0]       0.5  NEK9
# 37  270  13    0   0    [270, 0, 13, 0]       0.5  NEK9
# 38  268  12    2   1    [268, 2, 12, 1]  0.534758  NEK9
# 39  268  12    2   1    [268, 2, 12, 1]  0.534758  NEK9
# 40   70   9    1   0      [70, 1, 9, 0]  0.492958  NEK9
# 41    0   0   71   9      [0, 71, 0, 9]       0.5  NEK9
# 42   70   3    1   6      [70, 1, 3, 6]  0.826291  NEK9
# 43   70   3    1   6      [70, 1, 3, 6]  0.826291  NEK9
# 44   70   4    1   5      [70, 1, 4, 5]  0.770736  NEK9
# 45   71   9    0   0      [71, 0, 9, 0]       0.5  NEK9
# 46   70   3    1   6      [70, 1, 3, 6]  0.826291  NEK9
# 47   70   3    1   6      [70, 1, 3, 6]  0.826291  NEK9

# %%
testing =new_test[new_test['NEK'] =='NEK2']
testing
# Out:
#                             model  accuracy precision    recall specificity  \
# 0      NEK2_binding_moe_scaled_GP  0.957597       0.0       0.0         1.0
# 1       NEK2_binding_moe_UNDER_GP  0.738516  0.102564  0.666667    0.741697
# 2       NEK2_binding_moe_SMOTE_GP  0.968198       0.8  0.333333     0.99631
# 3      NEK2_binding_moe_ADASYN_GP  0.961131  0.571429  0.333333     0.98893
# 4      NEK2_binding_mfp_scaled_GP  0.957597       0.0       0.0         1.0
# 5       NEK2_binding_mfp_UNDER_GP  0.954064       0.0       0.0     0.99631
# 6       NEK2_binding_mfp_SMOTE_GP  0.964664       1.0  0.166667         1.0
# 7      NEK2_binding_mfp_ADASYN_GP  0.964664       1.0  0.166667         1.0
# 8   NEK2_inhibition_moe_scaled_GP   0.93154       0.0       0.0         1.0
# 9    NEK2_inhibition_moe_UNDER_GP  0.865526  0.309859  0.785714    0.871391
# 10   NEK2_inhibition_moe_SMOTE_GP  0.948655  0.666667       0.5    0.981627
# 11  NEK2_inhibition_moe_ADASYN_GP    0.9511  0.681818  0.535714    0.981627
# 12  NEK2_inhibition_mfp_scaled_GP  0.943765       1.0  0.178571         1.0
# 13   NEK2_inhibition_mfp_UNDER_GP  0.105134  0.068878  0.964286    0.041995
# 14   NEK2_inhibition_mfp_SMOTE_GP  0.968215  0.894737  0.607143    0.994751
# 15  NEK2_inhibition_mfp_ADASYN_GP   0.96577  0.888889  0.571429    0.994751
#
#      TN  FN   FP  TP                cm   ROC-AUC   NEK
# 0   271  12    0   0   [271, 0, 12, 0]       0.5  NEK2
# 1   201   4   70   8   [201, 70, 4, 8]  0.704182  NEK2
# 2   270   8    1   4    [270, 1, 8, 4]  0.664822  NEK2
# 3   268   8    3   4    [268, 3, 8, 4]  0.661132  NEK2
# 4   271  12    0   0   [271, 0, 12, 0]       0.5  NEK2
# 5   270  12    1   0   [270, 1, 12, 0]  0.498155  NEK2
# 6   271  10    0   2   [271, 0, 10, 2]  0.583333  NEK2
# 7   271  10    0   2   [271, 0, 10, 2]  0.583333  NEK2
# 8   381  28    0   0   [381, 0, 28, 0]       0.5  NEK2
# 9   332   6   49  22  [332, 49, 6, 22]  0.828553  NEK2
# 10  374  14    7  14  [374, 7, 14, 14]  0.740814  NEK2
# 11  374  13    7  15  [374, 7, 13, 15]  0.758671  NEK2
# 12  381  23    0   5   [381, 0, 23, 5]  0.589286  NEK2
# 13   16   1  365  27  [16, 365, 1, 27]   0.50314  NEK2
# 14  379  11    2  17  [379, 2, 11, 17]  0.800947  NEK2
# 15  379  12    2  16  [379, 2, 12, 16]   0.78309  NEK2

# %%
neks = ['NEK2', 'NEK3', 'NEK5', 'NEK9']
for n, nek in enumerate(neks): 
    nek_df = new_test[new_test['NEK'] ==nek]
    print(nek)
    for i, metric in enumerate(max_cols): 
        max_metric = new_test.loc[new_test[metric].idxmax()]
        max_model_name = max_metric['model'] 
        print(f'{metric}:')
        # display(max_metric)
        print()
    print()
    print('\nLowest FN and FP\n')
    for j, metric in enumerate(min_cols): 
        min_metric = new_test.loc[new_test[metric].idxmax()]
        print(f'{metric}:')
        display(min_metric)
        print()
# Out:
# NEK2
# accuracy:
# model          NEK2_inhibition_mfp_SMOTE_GP
# accuracy                           0.968215
# precision                          0.894737
# recall                             0.607143
# specificity                        0.994751
# TN                                      379
# FN                                       11
# FP                                        2
# TP                                       17
# cm                         [379, 2, 11, 17]
# ROC-AUC                            0.800947
# NEK                                    NEK2
# Name: 14, dtype: object
# precision:
# model          NEK2_binding_mfp_SMOTE_GP
# accuracy                        0.964664
# precision                            1.0
# recall                          0.166667
# specificity                          1.0
# TN                                   271
# FN                                    10
# FP                                     0
# TP                                     2
# cm                       [271, 0, 10, 2]
# ROC-AUC                         0.583333
# NEK                                 NEK2
# Name: 6, dtype: object
# recall:
# model          NEK9_inhibition_moe_UNDER_GP
# accuracy                             0.1125
# precision                            0.1125
# recall                                  1.0
# specificity                             0.0
# TN                                        0
# FN                                        0
# FP                                       71
# TP                                        9
# cm                            [0, 71, 0, 9]
# ROC-AUC                                 0.5
# NEK                                    NEK9
# Name: 41, dtype: object
# specificity:
# model          NEK2_binding_moe_scaled_GP
# accuracy                         0.957597
# precision                             0.0
# recall                                0.0
# specificity                           1.0
# TN                                    271
# FN                                     12
# FP                                      0
# TP                                      0
# cm                        [271, 0, 12, 0]
# ROC-AUC                               0.5
# NEK                                  NEK2
# Name: 0, dtype: object
# TN:
# model          NEK2_inhibition_moe_scaled_GP
# accuracy                             0.93154
# precision                                0.0
# recall                                   0.0
# specificity                              1.0
# TN                                       381
# FN                                        28
# FP                                         0
# TP                                         0
# cm                           [381, 0, 28, 0]
# ROC-AUC                                  0.5
# NEK                                     NEK2
# Name: 8, dtype: object
# TP:
# model          NEK2_inhibition_mfp_UNDER_GP
# accuracy                           0.105134
# precision                          0.068878
# recall                             0.964286
# specificity                        0.041995
# TN                                       16
# FN                                        1
# FP                                      365
# TP                                       27
# cm                         [16, 365, 1, 27]
# ROC-AUC                             0.50314
# NEK                                    NEK2
# Name: 13, dtype: object
# ROC-AUC:
# model          NEK2_inhibition_moe_UNDER_GP
# accuracy                           0.865526
# precision                          0.309859
# recall                             0.785714
# specificity                        0.871391
# TN                                      332
# FN                                        6
# FP                                       49
# TP                                       22
# cm                         [332, 49, 6, 22]
# ROC-AUC                            0.828553
# NEK                                    NEK2
# Name: 9, dtype: object
# Lowest FN and FP
#
# FN:
# model          NEK2_inhibition_moe_scaled_GP
# accuracy                             0.93154
# precision                                0.0
# recall                                   0.0
# specificity                              1.0
# TN                                       381
# FN                                        28
# FP                                         0
# TP                                         0
# cm                           [381, 0, 28, 0]
# ROC-AUC                                  0.5
# NEK                                     NEK2
# Name: 8, dtype: object
# FP:
# model          NEK2_inhibition_mfp_UNDER_GP
# accuracy                           0.105134
# precision                          0.068878
# recall                             0.964286
# specificity                        0.041995
# TN                                       16
# FN                                        1
# FP                                      365
# TP                                       27
# cm                         [16, 365, 1, 27]
# ROC-AUC                             0.50314
# NEK                                    NEK2
# Name: 13, dtype: object
# NEK3
# accuracy:
# model          NEK2_inhibition_mfp_SMOTE_GP
# accuracy                           0.968215
# precision                          0.894737
# recall                             0.607143
# specificity                        0.994751
# TN                                      379
# FN                                       11
# FP                                        2
# TP                                       17
# cm                         [379, 2, 11, 17]
# ROC-AUC                            0.800947
# NEK                                    NEK2
# Name: 14, dtype: object
# precision:
# model          NEK2_binding_mfp_SMOTE_GP
# accuracy                        0.964664
# precision                            1.0
# recall                          0.166667
# specificity                          1.0
# TN                                   271
# FN                                    10
# FP                                     0
# TP                                     2
# cm                       [271, 0, 10, 2]
# ROC-AUC                         0.583333
# NEK                                 NEK2
# Name: 6, dtype: object
# recall:
# model          NEK9_inhibition_moe_UNDER_GP
# accuracy                             0.1125
# precision                            0.1125
# recall                                  1.0
# specificity                             0.0
# TN                                        0
# FN                                        0
# FP                                       71
# TP                                        9
# cm                            [0, 71, 0, 9]
# ROC-AUC                                 0.5
# NEK                                    NEK9
# Name: 41, dtype: object
# specificity:
# model          NEK2_binding_moe_scaled_GP
# accuracy                         0.957597
# precision                             0.0
# recall                                0.0
# specificity                           1.0
# TN                                    271
# FN                                     12
# FP                                      0
# TP                                      0
# cm                        [271, 0, 12, 0]
# ROC-AUC                               0.5
# NEK                                  NEK2
# Name: 0, dtype: object
# TN:
# model          NEK2_inhibition_moe_scaled_GP
# accuracy                             0.93154
# precision                                0.0
# recall                                   0.0
# specificity                              1.0
# TN                                       381
# FN                                        28
# FP                                         0
# TP                                         0
# cm                           [381, 0, 28, 0]
# ROC-AUC                                  0.5
# NEK                                     NEK2
# Name: 8, dtype: object
# TP:
# model          NEK2_inhibition_mfp_UNDER_GP
# accuracy                           0.105134
# precision                          0.068878
# recall                             0.964286
# specificity                        0.041995
# TN                                       16
# FN                                        1
# FP                                      365
# TP                                       27
# cm                         [16, 365, 1, 27]
# ROC-AUC                             0.50314
# NEK                                    NEK2
# Name: 13, dtype: object
# ROC-AUC:
# model          NEK2_inhibition_moe_UNDER_GP
# accuracy                           0.865526
# precision                          0.309859
# recall                             0.785714
# specificity                        0.871391
# TN                                      332
# FN                                        6
# FP                                       49
# TP                                       22
# cm                         [332, 49, 6, 22]
# ROC-AUC                            0.828553
# NEK                                    NEK2
# Name: 9, dtype: object
# Lowest FN and FP
#
# FN:
# model          NEK2_inhibition_moe_scaled_GP
# accuracy                             0.93154
# precision                                0.0
# recall                                   0.0
# specificity                              1.0
# TN                                       381
# FN                                        28
# FP                                         0
# TP                                         0
# cm                           [381, 0, 28, 0]
# ROC-AUC                                  0.5
# NEK                                     NEK2
# Name: 8, dtype: object
# FP:
# model          NEK2_inhibition_mfp_UNDER_GP
# accuracy                           0.105134
# precision                          0.068878
# recall                             0.964286
# specificity                        0.041995
# TN                                       16
# FN                                        1
# FP                                      365
# TP                                       27
# cm                         [16, 365, 1, 27]
# ROC-AUC                             0.50314
# NEK                                    NEK2
# Name: 13, dtype: object
# NEK5
# accuracy:
# model          NEK2_inhibition_mfp_SMOTE_GP
# accuracy                           0.968215
# precision                          0.894737
# recall                             0.607143
# specificity                        0.994751
# TN                                      379
# FN                                       11
# FP                                        2
# TP                                       17
# cm                         [379, 2, 11, 17]
# ROC-AUC                            0.800947
# NEK                                    NEK2
# Name: 14, dtype: object
# precision:
# model          NEK2_binding_mfp_SMOTE_GP
# accuracy                        0.964664
# precision                            1.0
# recall                          0.166667
# specificity                          1.0
# TN                                   271
# FN                                    10
# FP                                     0
# TP                                     2
# cm                       [271, 0, 10, 2]
# ROC-AUC                         0.583333
# NEK                                 NEK2
# Name: 6, dtype: object
# recall:
# model          NEK9_inhibition_moe_UNDER_GP
# accuracy                             0.1125
# precision                            0.1125
# recall                                  1.0
# specificity                             0.0
# TN                                        0
# FN                                        0
# FP                                       71
# TP                                        9
# cm                            [0, 71, 0, 9]
# ROC-AUC                                 0.5
# NEK                                    NEK9
# Name: 41, dtype: object
# specificity:
# model          NEK2_binding_moe_scaled_GP
# accuracy                         0.957597
# precision                             0.0
# recall                                0.0
# specificity                           1.0
# TN                                    271
# FN                                     12
# FP                                      0
# TP                                      0
# cm                        [271, 0, 12, 0]
# ROC-AUC                               0.5
# NEK                                  NEK2
# Name: 0, dtype: object
# TN:
# model          NEK2_inhibition_moe_scaled_GP
# accuracy                             0.93154
# precision                                0.0
# recall                                   0.0
# specificity                              1.0
# TN                                       381
# FN                                        28
# FP                                         0
# TP                                         0
# cm                           [381, 0, 28, 0]
# ROC-AUC                                  0.5
# NEK                                     NEK2
# Name: 8, dtype: object
# TP:
# model          NEK2_inhibition_mfp_UNDER_GP
# accuracy                           0.105134
# precision                          0.068878
# recall                             0.964286
# specificity                        0.041995
# TN                                       16
# FN                                        1
# FP                                      365
# TP                                       27
# cm                         [16, 365, 1, 27]
# ROC-AUC                             0.50314
# NEK                                    NEK2
# Name: 13, dtype: object
# ROC-AUC:
# model          NEK2_inhibition_moe_UNDER_GP
# accuracy                           0.865526
# precision                          0.309859
# recall                             0.785714
# specificity                        0.871391
# TN                                      332
# FN                                        6
# FP                                       49
# TP                                       22
# cm                         [332, 49, 6, 22]
# ROC-AUC                            0.828553
# NEK                                    NEK2
# Name: 9, dtype: object
# Lowest FN and FP
#
# FN:
# model          NEK2_inhibition_moe_scaled_GP
# accuracy                             0.93154
# precision                                0.0
# recall                                   0.0
# specificity                              1.0
# TN                                       381
# FN                                        28
# FP                                         0
# TP                                         0
# cm                           [381, 0, 28, 0]
# ROC-AUC                                  0.5
# NEK                                     NEK2
# Name: 8, dtype: object
# FP:
# model          NEK2_inhibition_mfp_UNDER_GP
# accuracy                           0.105134
# precision                          0.068878
# recall                             0.964286
# specificity                        0.041995
# TN                                       16
# FN                                        1
# FP                                      365
# TP                                       27
# cm                         [16, 365, 1, 27]
# ROC-AUC                             0.50314
# NEK                                    NEK2
# Name: 13, dtype: object
# NEK9
# accuracy:
# model          NEK2_inhibition_mfp_SMOTE_GP
# accuracy                           0.968215
# precision                          0.894737
# recall                             0.607143
# specificity                        0.994751
# TN                                      379
# FN                                       11
# FP                                        2
# TP                                       17
# cm                         [379, 2, 11, 17]
# ROC-AUC                            0.800947
# NEK                                    NEK2
# Name: 14, dtype: object
# precision:
# model          NEK2_binding_mfp_SMOTE_GP
# accuracy                        0.964664
# precision                            1.0
# recall                          0.166667
# specificity                          1.0
# TN                                   271
# FN                                    10
# FP                                     0
# TP                                     2
# cm                       [271, 0, 10, 2]
# ROC-AUC                         0.583333
# NEK                                 NEK2
# Name: 6, dtype: object
# recall:
# model          NEK9_inhibition_moe_UNDER_GP
# accuracy                             0.1125
# precision                            0.1125
# recall                                  1.0
# specificity                             0.0
# TN                                        0
# FN                                        0
# FP                                       71
# TP                                        9
# cm                            [0, 71, 0, 9]
# ROC-AUC                                 0.5
# NEK                                    NEK9
# Name: 41, dtype: object
# specificity:
# model          NEK2_binding_moe_scaled_GP
# accuracy                         0.957597
# precision                             0.0
# recall                                0.0
# specificity                           1.0
# TN                                    271
# FN                                     12
# FP                                      0
# TP                                      0
# cm                        [271, 0, 12, 0]
# ROC-AUC                               0.5
# NEK                                  NEK2
# Name: 0, dtype: object
# TN:
# model          NEK2_inhibition_moe_scaled_GP
# accuracy                             0.93154
# precision                                0.0
# recall                                   0.0
# specificity                              1.0
# TN                                       381
# FN                                        28
# FP                                         0
# TP                                         0
# cm                           [381, 0, 28, 0]
# ROC-AUC                                  0.5
# NEK                                     NEK2
# Name: 8, dtype: object
# TP:
# model          NEK2_inhibition_mfp_UNDER_GP
# accuracy                           0.105134
# precision                          0.068878
# recall                             0.964286
# specificity                        0.041995
# TN                                       16
# FN                                        1
# FP                                      365
# TP                                       27
# cm                         [16, 365, 1, 27]
# ROC-AUC                             0.50314
# NEK                                    NEK2
# Name: 13, dtype: object
# ROC-AUC:
# model          NEK2_inhibition_moe_UNDER_GP
# accuracy                           0.865526
# precision                          0.309859
# recall                             0.785714
# specificity                        0.871391
# TN                                      332
# FN                                        6
# FP                                       49
# TP                                       22
# cm                         [332, 49, 6, 22]
# ROC-AUC                            0.828553
# NEK                                    NEK2
# Name: 9, dtype: object
# Lowest FN and FP
#
# FN:
# model          NEK2_inhibition_moe_scaled_GP
# accuracy                             0.93154
# precision                                0.0
# recall                                   0.0
# specificity                              1.0
# TN                                       381
# FN                                        28
# FP                                         0
# TP                                         0
# cm                           [381, 0, 28, 0]
# ROC-AUC                                  0.5
# NEK                                     NEK2
# Name: 8, dtype: object
# FP:
# model          NEK2_inhibition_mfp_UNDER_GP
# accuracy                           0.105134
# precision                          0.068878
# recall                             0.964286
# specificity                        0.041995
# TN                                       16
# FN                                        1
# FP                                      365
# TP                                       27
# cm                         [16, 365, 1, 27]
# ROC-AUC                             0.50314
# NEK                                    NEK2
# Name: 13, dtype: object

# %%
# df.columns

# %%
# def add_cm(filepath, filename): 
#     # print(filepath)
#     # print(filename)
#     df = pd.read_csv(filepath+filename)
    
#     true_labels = df['y'] 
#     predictions = df['y_pred']
#     cm = confusion_matrix(true_labels, predictions )
#     cm_flattened = cm.flatten().tolist()
#     df['cm'] = [cm_flattened]* len(df)
#     df['prediction_type'] = df.apply(lambda x: prediction_type(x['y'], x['y_pred']), axis=1)
#     return df

# %%
# df = pd.read_csv(result_path+ 'NEK2_binding_moe_scaled_test_GP.csv')
# true_labels = df['y'] 
# predictions = df['y_pred']
# cm = confusion_matrix(true_labels, predictions )
# df_copy = df.copy()
# cm_flattened = cm.flatten().tolist()
# cm_flattened
# # df_copy['cm'] =[(x,) for x in list(cm)]
# df_copy['cm'] = [cm_flattened]* len(df_copy)
# df_copy['prediction_type'] = df.apply(lambda x: prediction_type(x['y'], x['y_pred']), axis=1)

# %%
# data_dir = '/Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/'
# gp_result_path = '/Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/'
# # capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/NEK2_binding_mfp_ADASYN_test_GP.csv
# nek_nums = [2,3,5,9]
# samplings = ['scaled', 'UNDER', 'SMOTE', 'ADASYN'] 
# features = ['moe', 'mfp']
# NEK= 'NEK'
# for i, n in enumerate(nek_nums):
#     nek = str(n)
#     print(f'NEK{nek}')
#     nek_path= f'{data_dir}NEK{nek}/bind/'
    
#     for k, feat in enumerate(features): 
#         print()
#         for j, samp in enumerate(samplings): 
        
#             print(f'NEK{nek} {feat} {samp}')
#             file_root = f'NEK{nek}_binding_{feat}_{samp}'
#             train_file = f'{file_root}_train_GP.csv'
#             test_file = f'{file_root}_test_GP.csv'

#             train_df = add_cm(gp_result_path,train_file)
#             test_df = add_cm(gp_result_path,test_file)
#             train_df.to_csv(f'{gp_result_path}{file_root}_train_GP.csv',index=False) 
#             test_df.to_csv(f'{gp_result_path}{file_root}_test_GP.csv',index=False) 
            
#             print()
            
            
#     print()
    
#     if n == 2 or n == 9:

#         nek_path= f'{data_dir}NEK{nek}/inhib/'
#         for k, feat in enumerate(features): 
#             print()
#             for j, samp in enumerate(samplings): 
#                 file_root = f'NEK{nek}_inhibition_{feat}_{samp}'
#                 print(f'NEK{nek} {feat} {samp}')
#                 print(f'NEK{nek} {feat} {samp}')
#                 file_root = f'NEK{nek}_inhibition_{feat}_{samp}'
#                 train_file = f'{file_root}_train_GP.csv'
#                 test_file = f'{file_root}_test_GP.csv'
    
#                 train_df = add_cm(gp_result_path,train_file)
#                 test_df = add_cm(gp_result_path,test_file)
#                 train_df.to_csv(f'{gp_result_path}{file_root}_train_GP.csv',index=False) 
#                 test_df.to_csv(f'{gp_result_path}{file_root}_test_GP.csv',index=False) 
#                 print()
        
            
#     print()
# Out:
# NEK2
#
# NEK2 moe scaled
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK2_binding_moe_scaled_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK2_binding_moe_scaled_test_GP.csv
#
# NEK2 moe UNDER
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK2_binding_moe_UNDER_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK2_binding_moe_UNDER_test_GP.csv
#
# NEK2 moe SMOTE
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK2_binding_moe_SMOTE_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK2_binding_moe_SMOTE_test_GP.csv
#
# NEK2 moe ADASYN
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK2_binding_moe_ADASYN_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK2_binding_moe_ADASYN_test_GP.csv
#
#
# NEK2 mfp scaled
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK2_binding_mfp_scaled_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK2_binding_mfp_scaled_test_GP.csv
#
# NEK2 mfp UNDER
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK2_binding_mfp_UNDER_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK2_binding_mfp_UNDER_test_GP.csv
#
# NEK2 mfp SMOTE
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK2_binding_mfp_SMOTE_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK2_binding_mfp_SMOTE_test_GP.csv
#
# NEK2 mfp ADASYN
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK2_binding_mfp_ADASYN_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK2_binding_mfp_ADASYN_test_GP.csv
#
#
#
# NEK2 moe scaled
# NEK2 moe scaled
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK2_inhibition_moe_scaled_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK2_inhibition_moe_scaled_test_GP.csv
#
# NEK2 moe UNDER
# NEK2 moe UNDER
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK2_inhibition_moe_UNDER_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK2_inhibition_moe_UNDER_test_GP.csv
#
# NEK2 moe SMOTE
# NEK2 moe SMOTE
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK2_inhibition_moe_SMOTE_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK2_inhibition_moe_SMOTE_test_GP.csv
#
# NEK2 moe ADASYN
# NEK2 moe ADASYN
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK2_inhibition_moe_ADASYN_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK2_inhibition_moe_ADASYN_test_GP.csv
#
#
# NEK2 mfp scaled
# NEK2 mfp scaled
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK2_inhibition_mfp_scaled_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK2_inhibition_mfp_scaled_test_GP.csv
#
# NEK2 mfp UNDER
# NEK2 mfp UNDER
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK2_inhibition_mfp_UNDER_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK2_inhibition_mfp_UNDER_test_GP.csv
#
# NEK2 mfp SMOTE
# NEK2 mfp SMOTE
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK2_inhibition_mfp_SMOTE_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK2_inhibition_mfp_SMOTE_test_GP.csv
#
# NEK2 mfp ADASYN
# NEK2 mfp ADASYN
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK2_inhibition_mfp_ADASYN_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK2_inhibition_mfp_ADASYN_test_GP.csv
#
#
# NEK3
#
# NEK3 moe scaled
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK3_binding_moe_scaled_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK3_binding_moe_scaled_test_GP.csv
#
# NEK3 moe UNDER
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK3_binding_moe_UNDER_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK3_binding_moe_UNDER_test_GP.csv
#
# NEK3 moe SMOTE
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK3_binding_moe_SMOTE_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK3_binding_moe_SMOTE_test_GP.csv
#
# NEK3 moe ADASYN
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK3_binding_moe_ADASYN_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK3_binding_moe_ADASYN_test_GP.csv
#
#
# NEK3 mfp scaled
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK3_binding_mfp_scaled_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK3_binding_mfp_scaled_test_GP.csv
#
# NEK3 mfp UNDER
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK3_binding_mfp_UNDER_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK3_binding_mfp_UNDER_test_GP.csv
#
# NEK3 mfp SMOTE
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK3_binding_mfp_SMOTE_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK3_binding_mfp_SMOTE_test_GP.csv
#
# NEK3 mfp ADASYN
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK3_binding_mfp_ADASYN_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK3_binding_mfp_ADASYN_test_GP.csv
#
#
#
# NEK5
#
# NEK5 moe scaled
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK5_binding_moe_scaled_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK5_binding_moe_scaled_test_GP.csv
#
# NEK5 moe UNDER
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK5_binding_moe_UNDER_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK5_binding_moe_UNDER_test_GP.csv
#
# NEK5 moe SMOTE
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK5_binding_moe_SMOTE_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK5_binding_moe_SMOTE_test_GP.csv
#
# NEK5 moe ADASYN
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK5_binding_moe_ADASYN_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK5_binding_moe_ADASYN_test_GP.csv
#
#
# NEK5 mfp scaled
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK5_binding_mfp_scaled_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK5_binding_mfp_scaled_test_GP.csv
#
# NEK5 mfp UNDER
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK5_binding_mfp_UNDER_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK5_binding_mfp_UNDER_test_GP.csv
#
# NEK5 mfp SMOTE
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK5_binding_mfp_SMOTE_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK5_binding_mfp_SMOTE_test_GP.csv
#
# NEK5 mfp ADASYN
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK5_binding_mfp_ADASYN_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK5_binding_mfp_ADASYN_test_GP.csv
#
#
#
# NEK9
#
# NEK9 moe scaled
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK9_binding_moe_scaled_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK9_binding_moe_scaled_test_GP.csv
#
# NEK9 moe UNDER
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK9_binding_moe_UNDER_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK9_binding_moe_UNDER_test_GP.csv
#
# NEK9 moe SMOTE
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK9_binding_moe_SMOTE_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK9_binding_moe_SMOTE_test_GP.csv
#
# NEK9 moe ADASYN
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK9_binding_moe_ADASYN_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK9_binding_moe_ADASYN_test_GP.csv
#
#
# NEK9 mfp scaled
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK9_binding_mfp_scaled_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK9_binding_mfp_scaled_test_GP.csv
#
# NEK9 mfp UNDER
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK9_binding_mfp_UNDER_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK9_binding_mfp_UNDER_test_GP.csv
#
# NEK9 mfp SMOTE
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK9_binding_mfp_SMOTE_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK9_binding_mfp_SMOTE_test_GP.csv
#
# NEK9 mfp ADASYN
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK9_binding_mfp_ADASYN_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK9_binding_mfp_ADASYN_test_GP.csv
#
#
#
# NEK9 moe scaled
# NEK9 moe scaled
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK9_inhibition_moe_scaled_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK9_inhibition_moe_scaled_test_GP.csv
#
# NEK9 moe UNDER
# NEK9 moe UNDER
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK9_inhibition_moe_UNDER_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK9_inhibition_moe_UNDER_test_GP.csv
#
# NEK9 moe SMOTE
# NEK9 moe SMOTE
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK9_inhibition_moe_SMOTE_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK9_inhibition_moe_SMOTE_test_GP.csv
#
# NEK9 moe ADASYN
# NEK9 moe ADASYN
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK9_inhibition_moe_ADASYN_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK9_inhibition_moe_ADASYN_test_GP.csv
#
#
# NEK9 mfp scaled
# NEK9 mfp scaled
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK9_inhibition_mfp_scaled_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK9_inhibition_mfp_scaled_test_GP.csv
#
# NEK9 mfp UNDER
# NEK9 mfp UNDER
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK9_inhibition_mfp_UNDER_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK9_inhibition_mfp_UNDER_test_GP.csv
#
# NEK9 mfp SMOTE
# NEK9 mfp SMOTE
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK9_inhibition_mfp_SMOTE_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK9_inhibition_mfp_SMOTE_test_GP.csv
#
# NEK9 mfp ADASYN
# NEK9 mfp ADASYN
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK9_inhibition_mfp_ADASYN_train_GP.csv
# /Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/
# NEK9_inhibition_mfp_ADASYN_test_GP.csv

# %%
# test = pd.read_csv('/Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/GP/GP_results/NEK9_binding_mfp_ADASYN_test_GP.csv')
