# %%
import math
import torch
import numpy as np
import pandas as pd
import seaborn as sns
import os
import pickle
import matplotlib 
matplotlib.use('Agg')
from matplotlib import pyplot as plt
import sklearn
from sklearn.model_selection import KFold

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
import imblearn as imb

from sklearn.metrics import confusion_matrix
import itertools

from scipy.stats import randint
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import accuracy_score, precision_score, f1_score, roc_auc_score, roc_curve, precision_recall_curve, auc, recall_score, confusion_matrix

from sklearn.ensemble import RandomForestClassifier
from imblearn.ensemble import BalancedRandomForestClassifier

import sys
sys.path.append('../../')
# import utils
from sklearn.model_selection import GridSearchCV

from split_data import *

from RF_atomver import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def get_arrays(file_path, df_filename, filename_type=None, save=False):
    """use dataframes to get trainX, trainy, testX, testy out. Optional: save those files to csv
    file_path: directory
    df_filename: dataframe NEK#_binding_moe_{sampling}_df.csv (sampling: scaled, UNDER, SMOTE, ADASYN)
    split dataframe to train and test, and x and y
    save: bool, option to save splits to separate csv files (train X, train y, test X, test y) 
    returns: numpy arrays train X, train y, testX, test y"""
    df = pd.read_csv(file_path+df_filename)
    train_df= df[df['subset']=='train']
    test_df = df[df['subset']=='test']
    train_y = train_df['active'].to_numpy().reshape(-1)
    test_y=test_df['active'].to_numpy().reshape(-1)
    train_x_df = train_df.drop(columns='active')

  
    test_x_df = test_df.drop(columns='active')
    
    train_x_df = train_df.drop(columns='active')
    test_x_df = test_df.drop(columns='active')
    trainX = train_x_df.select_dtypes(include='number').to_numpy()
    testX = test_x_df.select_dtypes(include='number').to_numpy()
    
    print(f'train X shape: {trainX.shape}, y: {train_y.shape}, test X: {testX.shape}, y:{test_y.shape}')
    if (save and filename_type is not None): 
        trainxdf = pd.DataFrame(trainX)
        trainxdf.to_csv(file_path+filename_type+'_trainX.csv', index=False)
        # train_x_df.to_csv(filename_type+'_trainX.csv', index=False)
        trainy_df = pd.DataFrame(train_y)
        trainy_df.to_csv(file_path+filename_type+'_train_y.csv', index=False) 
        # test_x_df.to_csv(filename_type+'_testX.csv', index=False)
        testxdf = pd.DataFrame(testX)
        testxdf.to_csv(file_path+filename_type+'_testX.csv', index=False)
        testy_df = pd.DataFrame(test_y)
        testy_df.to_csv(file_path+filename_type+'_test_y.csv', index=False) 
        
    return trainX, train_y, testX, test_y

# %%
trainX, trainy, testX, testy = get_arrays('/Users/radhi/Desktop/CAPSTONE_DATA/NEK/NEK3/bind/', 'NEK3_binding_moe_scaled_df.csv')
# Out:
# train X shape: (1122, 306), y: (1122,), test X: (282, 306), y:(282,)

# %%
parameters = {}
param_dist = {
    'n_estimators': np.linspace(100, 2000, 5, dtype = int),
    'max_depth': [20, 100, 200, 220],
    'min_samples_split': [2, 3,4,5 ],
    'min_samples_leaf': [2, 3, 4, 5],
    'criterion': ['gini','entropy']
}

# %%
scaled_moe_bind = find_best_models(trainX, trainy, testX, testy, 'RF', parameters, param_dist,  verbose_val=2) # start June 12 2:14 pm
# Out:
# Fitting 5 folds for each of 640 candidates, totalling 3200 fits
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.7s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.7s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=575; total time=   3.5s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=575; total time=   3.5s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=575; total time=   3.5s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=575; total time=   3.5s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=575; total time=   3.6s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=1050; total time=   5.9s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=1050; total time=   6.2s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=1050; total time=   6.3s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=1050; total time=   6.1s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=1050; total time=   6.4s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=1525; total time=   9.1s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=1525; total time=   8.7s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=1525; total time=   9.0s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   0.6s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   0.6s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   0.7s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators
8s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=3, n_estimators=1050; total time=   4.7s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=3, n_estimators=1050; total time=   4.9s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=2, n_estimators=2000; total time=   9.1s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=3, n_estimators=1050; total time=   5.0s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=3, n_estimators=1050; total time=   4.7s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=3, n_estimators=1525; total time=   7.2s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=3, n_estimators=1525; total time=   7.1s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=3, n_estimators=1525; total time=   7.1s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=3, n_estimators=1525; total time=   7.0s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=3, n_estimators=1525; total time=   7.4s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=4, n_estimators=100; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=4, n_estimators=100; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=4, n_estimators=100; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=4, n_estimators=100; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=4, n_estimators=100; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=3, n_estimators=2000; total time=   9.2s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=3, n_estimators=2000; total time=   9.1s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=4, n_estimators=575; total time=   2.7s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=4, n_estimators=575; total time=   2.5s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=4, n_estimators=575; total time=   2.6s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=3, n_estimators=2000; total time=   9.4s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=4, n_estimators=575; total time=   2.7s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=4, n_estimators=575; total time=   2.8s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=3, n_estimators=2000; total time=   9.5s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=3, n_estimators=2000; total time=   9.1s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=4, n_estimators=1050; total time=   4.7s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=4, n_estimators=1050; total time=   4.7s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=4, n_estimators=1050; total time=   4.8s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=4, n_estimators=1050; total time=   4.9s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=4, n_estimators=1050; total time=   4.8s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=4, n_estimators=1525; total time=   7.0s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=4, n_estimators=1525; total time=   6.8s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=4, n_estimators=1525; total time=   7.0s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=4, n_estimators=1525; total time=   6.9s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=4, n_estimators=1525; total time=   7.2s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=4, n_estimators=2000; total time=   9.0s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=4, n_estimators=2000; total time=   8.9s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=575; total time=   2.6s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=575; total time=   2.6s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=575; total time=   2.6s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=4, n_estimators=2000; total time=   9.2s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=575; total time=   2.7s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=575; total time=   2.7s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=4, n_estimators=2000; total time=   9.5s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=4, n_estimators=2000; total time=   9.0s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=1050; total time=   4.6s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=1050; total time=   4.8s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=1050; total time=   4.8s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=1050; total time=   5.0s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=1050; total time=   4.8s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=1525; total time=   7.0s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=1525; total time=   6.9s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=1525; total time=   7.1s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=1525; total time=   7.1s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=1525; total time=   7.2s
# [CV] END criterion=gini, max_depth=100, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END criterion=gini, max_depth=100, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END criterion=gini, max_depth=100, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END criterion=gini, max_depth=100, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END criterion=gini, max_depth=100, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=2000; total time=   9.2s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=2000; total time=   9.0s
# [CV] END criterion=gini, max_depth=100, min_samples_leaf=2, min_samples_split=2, n_estimators=575; total time=   3.2s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=2000; total time=   9.2s
# [CV] END criterion=gini, max_depth=100, min_samples_leaf=2, min_samples_split=2, n_estimators=575; total time=   3.3s
# [CV] END criterion=gini, max_depth=100, min_samples_leaf=2, min_samples_split=2, n_estimators=575; total time=   3.3s
# [CV] END criterion=gini, max_depth=100, min_samples_leaf=2, min_samples_split=2, n_estimators=575; total time=   3.5s
# ...
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=4, min_samples_split=4, n_estimators=2000; total time=   8.7s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=4, min_samples_split=4, n_estimators=2000; total time=   8.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=4, min_samples_split=5, n_estimators=575; total time=   2.5s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=4, min_samples_split=5, n_estimators=575; total time=   2.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=4, min_samples_split=5, n_estimators=575; total time=   2.5s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=4, min_samples_split=4, n_estimators=2000; total time=   8.9s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=4, min_samples_split=5, n_estimators=575; total time=   2.5s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=4, min_samples_split=5, n_estimators=575; total time=   2.5s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=4, min_samples_split=4, n_estimators=2000; total time=   8.7s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=4, min_samples_split=5, n_estimators=1050; total time=   4.3s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=4, min_samples_split=4, n_estimators=2000; total time=   8.5s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=4, min_samples_split=5, n_estimators=1050; total time=   4.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=4, min_samples_split=5, n_estimators=1050; total time=   4.5s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=4, min_samples_split=5, n_estimators=1050; total time=   4.6s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=4, min_samples_split=5, n_estimators=1050; total time=   4.5s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=4, min_samples_split=5, n_estimators=1525; total time=   6.5s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=4, min_samples_split=5, n_estimators=1525; total time=   6.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=4, min_samples_split=5, n_estimators=1525; total time=   6.5s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=4, min_samples_split=5, n_estimators=1525; total time=   6.7s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=4, min_samples_split=5, n_estimators=1525; total time=   6.6s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=4, min_samples_split=5, n_estimators=2000; total time=   8.3s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=4, min_samples_split=5, n_estimators=2000; total time=   8.5s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=2, n_estimators=575; total time=   2.5s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=2, n_estimators=575; total time=   2.5s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=2, n_estimators=575; total time=   2.6s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=4, min_samples_split=5, n_estimators=2000; total time=   8.6s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=2, n_estimators=575; total time=   2.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=2, n_estimators=575; total time=   2.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=4, min_samples_split=5, n_estimators=2000; total time=   8.6s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=4, min_samples_split=5, n_estimators=2000; total time=   8.5s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=2, n_estimators=1050; total time=   4.3s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=2, n_estimators=1050; total time=   4.5s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=2, n_estimators=1050; total time=   4.5s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=2, n_estimators=1050; total time=   4.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=2, n_estimators=1050; total time=   4.3s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=2, n_estimators=1525; total time=   6.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=2, n_estimators=1525; total time=   6.3s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=2, n_estimators=1525; total time=   6.6s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=3, n_estimators=100; total time=   0.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=2, n_estimators=1525; total time=   6.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=3, n_estimators=100; total time=   0.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=2, n_estimators=1525; total time=   6.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=3, n_estimators=100; total time=   0.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=3, n_estimators=100; total time=   0.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=3, n_estimators=100; total time=   0.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=2, n_estimators=2000; total time=   8.2s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=3, n_estimators=575; total time=   2.2s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=2, n_estimators=2000; total time=   8.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=3, n_estimators=575; total time=   2.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=3, n_estimators=575; total time=   2.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=2, n_estimators=2000; total time=   8.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=3, n_estimators=575; total time=   2.5s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=3, n_estimators=575; total time=   2.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=2, n_estimators=2000; total time=   8.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=2, n_estimators=2000; total time=   8.5s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=3, n_estimators=1050; total time=   4.3s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=3, n_estimators=1050; total time=   4.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=3, n_estimators=1050; total time=   4.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=3, n_estimators=1050; total time=   4.6s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=3, n_estimators=1050; total time=   4.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=3, n_estimators=1525; total time=   6.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=3, n_estimators=1525; total time=   6.2s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=3, n_estimators=1525; total time=   6.3s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=4, n_estimators=100; total time=   0.5s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=3, n_estimators=1525; total time=   6.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=3, n_estimators=1525; total time=   6.6s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=4, n_estimators=100; total time=   0.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=4, n_estimators=100; total time=   0.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=4, n_estimators=100; total time=   0.5s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=4, n_estimators=100; total time=   0.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=3, n_estimators=2000; total time=   8.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=3, n_estimators=2000; total time=   8.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=4, n_estimators=575; total time=   2.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=4, n_estimators=575; total time=   2.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=4, n_estimators=575; total time=   2.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=3, n_estimators=2000; total time=   8.3s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=4, n_estimators=575; total time=   2.3s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=4, n_estimators=575; total time=   2.7s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=3, n_estimators=2000; total time=   8.6s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=3, n_estimators=2000; total time=   8.6s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=4, n_estimators=1050; total time=   4.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=4, n_estimators=1050; total time=   4.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=4, n_estimators=1050; total time=   4.3s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=4, n_estimators=1050; total time=   4.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=4, n_estimators=1050; total time=   4.5s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=4, n_estimators=1525; total time=   6.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=4, n_estimators=1525; total time=   6.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=4, n_estimators=1525; total time=   6.6s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=4, n_estimators=1525; total time=   6.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=4, n_estimators=1525; total time=   6.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.7s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.7s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.6s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=4, n_estimators=2000; total time=   8.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=5, n_estimators=575; total time=   2.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=4, n_estimators=2000; total time=   8.7s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=5, n_estimators=575; total time=   2.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=5, n_estimators=575; total time=   2.5s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=4, n_estimators=2000; total time=   8.7s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=5, n_estimators=575; total time=   2.5s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=5, n_estimators=575; total time=   2.5s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=4, n_estimators=2000; total time=   8.9s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=5, n_estimators=1050; total time=   4.3s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=5, n_estimators=1050; total time=   4.5s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=4, n_estimators=2000; total time=   8.7s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=5, n_estimators=1050; total time=   4.5s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=5, n_estimators=1050; total time=   4.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=5, n_estimators=1050; total time=   4.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=5, n_estimators=1525; total time=   6.3s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=5, n_estimators=1525; total time=   6.4s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=5, n_estimators=1525; total time=   6.5s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=5, n_estimators=1525; total time=   6.5s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=5, n_estimators=1525; total time=   6.5s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=5, n_estimators=2000; total time=   8.0s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=5, n_estimators=2000; total time=   7.8s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=5, n_estimators=2000; total time=   7.9s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=5, n_estimators=2000; total time=   7.3s
# [CV] END criterion=entropy, max_depth=220, min_samples_leaf=5, min_samples_split=5, n_estimators=2000; total time=   6.9s
# /Users/radhi/miniconda3/envs/atom2024/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
trainX_mfp, trainy_mfp, testX_mfp, testy_mfp = get_arrays('/Users/radhi/Desktop/CAPSTONE_DATA/NEK/NEK3/bind/', 'NEK3_binding_mfp_scaled_df.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 trainX_mfp, trainy_mfp, testX_mfp, testy_mfp = get_arrays('/Users/radhi/Desktop/CAPSTONE_DATA/NEK/NEK3/bind/', 'NEK3_binding_mfp_scaled_df.csv')
#
# Cell In[14], line 14, in get_arrays(file_path, df_filename, filename_type, save)
#      11 train_df = df[df['subset']=='train']
#      12 test_df = df[df['subset']=='test']
# ---> 14 trainX = train_df.drop(columns=['subset', 'target']).values
#      15 trainy = train_df['target'].values
#      16 testX = test_df.drop(columns=['subset', 'target']).values
#
# File ~/miniconda3/envs/atom2024/lib/python3.9/site-packages/pandas/core/frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File ~/miniconda3/envs/atom2024/lib/python3.9/site-packages/pandas/core/generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File ~/miniconda3/envs/atom2024/lib/python3.9/site-packages/pandas/core/generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File ~/miniconda3/envs/atom2024/lib/python3.9/site-packages/pandas/core/indexes/base.py:6699, in Index.drop(self, labels, errors)
#    6697 if mask.any():
#    6698     if errors != "ignore":
# -> 6699         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700     indexer = indexer[~mask]
#    6701 return self.delete(indexer)
#
# KeyError: "['target'] not found in axis"

# %%
trainX_mfp, trainy_mfp, testX_mfp, testy_mfp = get_arrays('/Users/radhi/Desktop/CAPSTONE_DATA/NEK/NEK3/bind/', 'NEK3_binding_mfp_scaled_df.csv')

def get_arrays(file_path, df_filename, filename_type=None, save=False):
    """use dataframes to get trainX, trainy, testX, testy out. Optional: save those files to csv
    file_path: directory
    df_filename: dataframe NEK#_binding_moe_{sampling}_df.csv (sampling: scaled, UNDER, SMOTE, ADASYN)
    split dataframe to train and test, and x and y
    save: bool, option to save splits to separate csv files (train X, train y, test X, test y) 
    returns: numpy arrays train X, train y, testX, test y"""
    df = pd.read_csv(file_path + '/' + df_filename)
    train_df = df[df['subset']=='train']
    test_df = df[df['subset']=='test']
    
    trainX = train_df.drop(columns=['subset', 'target']).values
    trainy = train_df['target'].values
    testX = test_df.drop(columns=['subset', 'target']).values
    testy = test_df['target'].values
    
    if save:
        np.savetxt(file_path + 'trainX.csv', trainX, delimiter=',')
        np.savetxt(file_path + 'trainy.csv', trainy, delimiter=',')
        np.savetxt(file_path + 'testX.csv', testX, delimiter=',')
        np.savetxt(file_path + 'testy.csv', testy, delimiter=',')
    
    return trainX, trainy, testX, testy
# Out:
# train X shape: (1122, 2048), y: (1122,), test X: (282, 2048), y:(282,)
