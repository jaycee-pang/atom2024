# %%
import os

data_dir = '/Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/'
nek_nums = [2, 3, 5, 9]

NEK = 'NEK'

html_content = """
<!DOCTYPE html>
<html>
<head>
<style>
img {
    max-width: 100%;
    height: auto;
}
</style>
</head>
<body>

<h2>NEK GP Model Performance Metric Plots</h2>

"""

for n in nek_nums:
    nek = str(n)
    nek_path = '/Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/plots/figures/'
    html_content += f'<h3>NEK{nek}</h3>'
    
    if os.path.exists(nek_path):
        for file in os.listdir(nek_path):
            if file.startswith('GP_NEK' + nek):
                img_path = os.path.join(nek_path, file)
                html_content += f'<img src="{img_path}" alt="{file}">\n'
    
    html_content += '<br>\n'

html_content += """
</body>
</html>
"""

print(html_content)

with open('GP_all_metric_plots.html', 'w') as f:
    f.write(html_content)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <style>
# img {
#     max-width: 100%;
#     height: auto;
# }
# </style>
# </head>
# <body>
#
# <h2>NEK GP Model Performance Metric Plots</h2>
#
# <h3>NEK2</h3><img src="/Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/plots/figures/GP_NEK2_inhibition_metrics_catplot_xfeat.png" alt="GP_NEK2_inhibition_metrics_catplot_xfeat.png">
# <img src="/Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/plots/figures/GP_NEK2_inhibition_recall_scores_individ.png" alt="GP_NEK2_inhibition_recall_scores_individ.png">
# <img src="/Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/plots/figures/GP_NEK2_binding_metrics_catplot_xsamp.png" alt="GP_NEK2_binding_metrics_catplot_xsamp.png">
# <img src="/Users/jayceepang/msse/capstone/atom2024/atom2024/notebooks/NEK/plots/figures/GP_NEK2_inhibition_metrics_catplot_splitmoemfp.png" alt="GP_NEK2_inhibition_metrics_catplot_splitmoemfp.png">
# ...
