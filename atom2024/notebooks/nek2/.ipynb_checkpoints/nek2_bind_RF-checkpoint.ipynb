# %%
import math
import torch
import numpy as np
import gpytorch
import pandas as pd
import seaborn as sns
import os
import pickle
import matplotlib 
matplotlib.use('Agg')
from matplotlib import pyplot as plt
import sklearn
from sklearn.model_selection import KFold

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import imblearn as imb
# print("imblearn version: ",imblearn.__version__)
from imblearn.over_sampling import SMOTE

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

from sklearn.metrics import confusion_matrix
import itertools

from scipy.stats import randint
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import accuracy_score, precision_score, f1_score, roc_auc_score, roc_curve, precision_recall_curve, auc, recall_score

from sklearn.ensemble import RandomForestClassifier
from imblearn.ensemble import BalancedRandomForestClassifier
from rdkit import Chem
from rdkit.Chem import Draw
import sys
sys.path.append('../')
# import utils
from sklearn.model_selection import GridSearchCV
from VisUtils import *

from sklearn.tree import export_graphviz
from IPython.display import Image
import graphviz
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from functools import wraps
from time import time

def timing(f):
    @wraps(f)
    def wrap(*args, **kw):
        ts = time()
        result = f(*args, **kw)
        te = time()
        print('func:%r  took: %2.4f sec' % (f.__name__,  te-ts))
        return result
    return wrap

# %%
split_path = '../../../../data/NEK_data_4Berkeley/NEK2/'
train_x_df = pd.read_csv(split_path+"/NEK2_binding_random_fold1_trainX.csv")
train_y_df= pd.read_csv(split_path+"/NEK2_binding_random_fold1_trainY.csv")
test_x_df= pd.read_csv(split_path+"/NEK2_binding_random_fold1_testX.csv")
test_y_df= pd.read_csv(split_path+"/NEK2_binding_random_fold1_testY.csv")
train_x = torch.from_numpy(train_x_df.to_numpy())
train_y = torch.from_numpy(train_y_df.to_numpy().reshape(-1))
test_x = torch.from_numpy(test_x_df.to_numpy())
test_y = torch.from_numpy(test_y_df.to_numpy().reshape(-1))

# %%
# Scale data
x_df = pd.concat([train_x_df, test_x_df])

scaling=StandardScaler()
 
# Use fit and transform method 
scaling.fit(x_df)
Scaled_data=scaling.transform(x_df)
train_x = scaling.transform(train_x_df)
test_x = scaling.transform(test_x_df) 

train_y = train_y_df.to_numpy().flatten()
test_y = test_y_df.to_numpy().flatten()

# %%
def rf_results(model, train_x, train_y, test_x, test_y): 
    """Make predictions adn get probabilities
    @params
    model: fitted model (fitted to train set)
    train_x, train_y, test_x, test_y: train and test set inputs (np arrays)
    @returns
    train/test predictions
    train/test accuracies 
    train/test probabilities"""
    train_pred = model.predict(train_x) 
    test_pred = model.predict(test_x)
    train_acc = accuracy_score(train_y, train_pred) 
    test_acc = accuracy_score(test_y, test_pred) 
    print(f'train accuracy: {train_acc}')
    print(f'test accuracy: {test_acc}')
    train_prob = model.predict_proba(train_x) 
    test_prob = model.predict_proba(test_x) 
    return train_pred, test_pred, train_acc, test_acc, train_prob, test_prob

# %%
def rf_models(train_x, train_y, test_x, test_y, rf_type, parameters, dataset_type):
    """Fit a RF model, make predictions, get probabilities
    @params: 
    train_x, train_y, test_x, test_y: train and test set inputs (np arrays) 
    rf_type: model type: RandomForestClassifier, RandomForestClassifier with class_weight:'balanced', or BalancedRandomForestClassifier
        default is RFC 
    parameters: dict for model params 
    dataset_type: binding or inhibition
    @returns: dict with model, train/test prections and probabilities
    """
    n_estimators = parameters.get('n_estimators', 100)
    random_state = parameters.get('random_state', 42) 
    criterion = parameters.get('criterion', 'gini')
    max_depth = parameters.get('max_depth', 100)
    min_samples_split = parameters.get('min_samples_split', 2) 
    min_samples_leaf = parameters.get('min_samples_leaf', 1) 
    bootstrap = parameters.get('bootstrap', False) 
    max_features = parameters.get('max_features', None) 
    class_weight = parameters.get('class_weight', None)
    
    if (rf_type == 'balanced class_weight'): 
        model = RandomForestClassifier(n_estimators=n_estimators, criterion=criterion, max_depth=max_depth, min_samples_split=min_samples_split
                                , min_samples_leaf=min_samples_leaf, bootstrap=bootstrap, max_features=max_features, class_weight='balanced')
    elif (rf_type == 'balanced RF'):
        model = BalancedRandomForestClassifier(n_estimators=n_estimators, criterion=criterion, max_depth=max_depth, min_samples_split=min_samples_split
                                , min_samples_leaf=min_samples_leaf, bootstrap=bootstrap, max_features=max_features, class_weight=class_weight)
    else:
        model = RandomForestClassifier(n_estimators=n_estimators, criterion=criterion, max_depth=max_depth, min_samples_split=min_samples_split
                                , min_samples_leaf=min_samples_leaf, bootstrap=bootstrap, max_features=max_features, class_weight=class_weight)
        
    model.fit(train_x, train_y)
    train_pred, test_pred, train_acc, test_acc, train_prob, test_prob = rf_results(model, train_x, train_y, test_x, test_y)
    classes = ['0','1']
    plot_confusion_matrix(train_y, train_pred, classes, title=f"NEK2 {dataset_type} Train: {rf_type}")
    plot_confusion_matrix(test_y, test_pred, classes, title=f"NEK2 {dataset_type} Test: {rf_type}")
    
    return {'model': model, 'train_pred':train_pred, 'test_pred': test_pred, 'train_prob':train_prob, 'test_prob': test_prob}

# %%
@timing
def find_best_models(train_x, train_y, test_x, test_y, rf_type, parameters, param_dist, dataset_type, verbose_val=None):
    """uses GridSearchCV not random grid search
    Grid search to find the best model, make predictions (train and test), get probability (train and test), and plot CM 
    Save best model to pickle file 
    @params:
    train_x, train_y, test_x, test_y: train and test set inputs (np arrays) 
    rf_type: model type: RandomForestClassifier, RandomForestClassifier with class_weight:'balanced', or BalancedRandomForestClassifier
        default is RFC 
    parameters: dict for model params 
    param_dist: parameters for grid search
    dataset_type: binding or inhibition
    @returns: dict with model, train/test prections and probabilities
    """
    n_estimators = parameters.get('n_estimators', 100)
    random_state = parameters.get('random_state', 42) 
    criterion = parameters.get('criterion', 'gini')
    max_depth = parameters.get('max_depth', 100)
    min_samples_split = parameters.get('min_samples_split', 2) 
    min_samples_leaf = parameters.get('min_samples_leaf', 1) 
    bootstrap = parameters.get('bootstrap', False) 
    max_features = parameters.get('max_features', None) 
    class_weight = parameters.get('class_weight', None)
    bootstrap = parameters.get('bootstrap', False)
    if (verbose_val==None): 
        verbose_val = 0
    if (rf_type == 'balanced class_weight'): 
        model = RandomForestClassifier(n_estimators=n_estimators, criterion=criterion, max_depth=max_depth, min_samples_split=min_samples_split
                                , min_samples_leaf=min_samples_leaf, bootstrap=bootstrap, max_features=max_features, class_weight='balanced')
    elif (rf_type == 'balanced RF'):
        model = BalancedRandomForestClassifier(n_estimators=n_estimators, criterion=criterion, max_depth=max_depth, min_samples_split=min_samples_split
                                , min_samples_leaf=min_samples_leaf, bootstrap=bootstrap, max_features=max_features)
    else:
        model = RandomForestClassifier(n_estimators=n_estimators, criterion=criterion, max_depth=max_depth, min_samples_split=min_samples_split
                                , min_samples_leaf=min_samples_leaf, bootstrap=bootstrap, max_features=max_features, class_weight=class_weight)

    rand_search = GridSearchCV(estimator =model, param_grid = param_dist,cv=5, n_jobs=8, verbose=verbose_val)
    rand_search.fit(train_x, train_y) 
    best_rf = rand_search.best_estimator_
    
    return {'best_model': best_rf, 'train_pred':train_pred, 'test_pred': test_pred, 'train_prob':train_prob, 'test_prob': test_prob}

# %%
result1 = rf_models(train_x, train_y, test_x, test_y, 'Basic RF', {}, 'Binding')
# Out:
# train accuracy: 1.0
# test accuracy: 0.9081272084805654

# %%
param_grid = {
    'n_estimators': np.linspace(100, 2000, 5, dtype = int),
    'max_depth': [20, 40, 60, 80, 100, 150, 200, 220],
    'min_samples_split': [2, 3, 4],
    'min_samples_leaf': [2, 3, 4, 5],
    'criterion': ['gini','entropy']
}

# %%
result1_best = find_best_models(train_x, train_y, test_x, test_y, 'Basic RF', {}, 
                                param_grid, 'Binding', verbose_val=2)
# result1_best = find_best_models(train_x, train_y, test_x, test_y, 'Basic RF', {'bootstrap':True, 'class_weight':'balanced'}, 
#                                 param_grid, 'Binding', 'NEK2bind_gridsearch_basic_best', verbose_val=2)
# Out:
# Fitting 5 folds for each of 960 candidates, totalling 4800 fits
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=575; total time= 1.7min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=1525; total time= 6.0min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=2000; total time= 9.9min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=3, n_estimators=1525; total time= 6.9min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=  30.1s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=  22.6s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=4, n_estimators=575; total time= 2.9min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=4, n_estimators=575; total time= 2.3min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=4, n_estimators=1050; total time= 5.2min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=4, n_estimators=2000; total time= 9.1min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=3, min_samples_split=2, n_estimators=1050; total time= 4.0min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=3, min_samples_split=2, n_estimators=2000; total time= 7.4min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=3, min_samples_split=3, n_estimators=575; total time= 2.2min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=3, min_samples_split=3, n_estimators=1050; total time= 4.8min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=3, min_samples_split=3, n_estimators=2000; total time= 7.5min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=3, min_samples_split=4, n_estimators=1050; total time= 3.9min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=3, min_samples_split=4, n_estimators=1525; total time= 5.5min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  22.6s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  18.6s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  14.9s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  18.9s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=575; total time= 2.0min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=575; total time= 1.8min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=1525; total time= 6.2min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=2000; total time= 5.5min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=3, n_estimators=1525; total time= 6.3min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=  23.5s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=  19.8s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=  20.5s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=4, n_estimators=575; total time= 2.1min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=4, n_estimators=575; total time= 1.9min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=4, n_estimators=1525; total time= 5.0min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=4, n_estimators=2000; total time= 5.3min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=2, n_estimators=1050; total time= 2.8min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=2, n_estimators=1525; total time= 4.6min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=3, n_estimators=100; total time=  16.7s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=3, n_estimators=575; total time= 1.8min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=3, n_estimators=1050; total time= 3.5min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=3, n_estimators=1525; total time= 5.2min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=4, n_estimators=575; total time= 3.1min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=4, n_estimators=575; total time= 2.8min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=4, n_estimators=1525; total time= 7.0min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=4, n_estimators=2000; total time= 7.2min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=1050; total time= 7.3min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=2000; total time=13.3min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=3, n_estimators=1050; total time= 7.7min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=3, n_estimators=1525; total time=10.7min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=4, n_estimators=575; total time= 3.7min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=4, n_estimators=1050; total time= 7.6min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=4, n_estimators=2000; total time=14.1min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=3, min_samples_split=2, n_estimators=1050; total time= 5.7min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=3, min_samples_split=2, n_estimators=1525; total time= 8.6min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=  30.2s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=  38.6s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=3, min_samples_split=3, n_estimators=575; total time= 3.1min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=3, min_samples_split=3, n_estimators=575; total time= 3.7min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=3, min_samples_split=3, n_estimators=1525; total time=10.0min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=3, min_samples_split=3, n_estimators=2000; total time=14.2min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=3, min_samples_split=4, n_estimators=2000; total time=11.0min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=4, min_samples_split=2, n_estimators=575; total time= 2.4min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=4, min_samples_split=2, n_estimators=1050; total time= 4.1min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=4, min_samples_split=2, n_estimators=1525; total time= 7.0min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=4, min_samples_split=3, n_estimators=100; total time=  34.5s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=4, min_samples_split=3, n_estimators=100; total time=  21.7s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=4, min_samples_split=3, n_estimators=575; total time= 2.6min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=4, min_samples_split=3, n_estimators=575; total time= 2.5min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=4, min_samples_split=3, n_estimators=1525; total time= 7.2min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=4, min_samples_split=3, n_estimators=2000; total time= 7.5min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=4, min_samples_split=4, n_estimators=1050; total time= 3.9min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=4, min_samples_split=4, n_estimators=1525; total time= 6.9min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=5, min_samples_split=2, n_estimators=575; total time= 2.6min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=5, min_samples_split=2, n_estimators=575; total time= 2.1min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=5, min_samples_split=2, n_estimators=1525; total time= 7.6min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=5, min_samples_split=2, n_estimators=2000; total time= 8.6min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=5, min_samples_split=3, n_estimators=1525; total time= 7.1min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=5, min_samples_split=4, n_estimators=100; total time=  28.3s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=5, min_samples_split=4, n_estimators=100; total time=  25.5s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=5, min_samples_split=4, n_estimators=575; total time= 3.0min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=5, min_samples_split=4, n_estimators=575; total time= 2.2min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=5, min_samples_split=4, n_estimators=1050; total time= 4.7min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=5, min_samples_split=4, n_estimators=2000; total time= 9.5min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=2, min_samples_split=2, n_estimators=1050; total time=23.6min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=2, min_samples_split=2, n_estimators=2000; total time=15.0min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=2, min_samples_split=3, n_estimators=1050; total time= 5.8min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=2, min_samples_split=3, n_estimators=1525; total time=17.9min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=  42.7s
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=  41.9s
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=  34.1s
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=2, min_samples_split=4, n_estimators=575; total time= 4.1min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=2, min_samples_split=4, n_estimators=575; total time= 3.2min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=2, min_samples_split=4, n_estimators=1050; total time= 7.4min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=2, min_samples_split=4, n_estimators=2000; total time=12.9min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=3, min_samples_split=2, n_estimators=1050; total time= 5.8min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=3, min_samples_split=2, n_estimators=2000; total time=10.7min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=3, min_samples_split=3, n_estimators=575; total time= 3.2min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=3, min_samples_split=3, n_estimators=1050; total time= 6.2min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=3, min_samples_split=3, n_estimators=2000; total time= 6.9min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=3, min_samples_split=4, n_estimators=1050; total time= 3.8min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=3, min_samples_split=4, n_estimators=1525; total time= 5.6min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  19.9s
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  17.5s
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=4, min_samples_split=2, n_estimators=575; total time= 1.7min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=4, min_samples_split=2, n_estimators=575; total time= 1.7min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=4, min_samples_split=2, n_estimators=1525; total time= 5.7min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=4, min_samples_split=2, n_estimators=2000; total time= 4.7min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=4, min_samples_split=3, n_estimators=1525; total time= 5.6min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=4, min_samples_split=3, n_estimators=2000; total time= 5.8min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=4, min_samples_split=4, n_estimators=1525; total time= 4.7min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=  19.0s
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=  16.7s
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=5, min_samples_split=2, n_estimators=575; total time= 1.8min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=5, min_samples_split=2, n_estimators=1050; total time= 3.1min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=5, min_samples_split=2, n_estimators=1525; total time= 3.6min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=5, min_samples_split=3, n_estimators=100; total time=  19.9s
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=5, min_samples_split=3, n_estimators=100; total time=  17.8s
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=5, min_samples_split=3, n_estimators=100; total time=  19.1s
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=5, min_samples_split=3, n_estimators=100; total time=  16.6s
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=5, min_samples_split=3, n_estimators=575; total time= 1.8min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=5, min_samples_split=3, n_estimators=1050; total time= 3.1min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=5, min_samples_split=3, n_estimators=1525; total time= 4.2min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=5, min_samples_split=4, n_estimators=575; total time= 1.7min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=5, min_samples_split=4, n_estimators=575; total time= 1.4min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=5, min_samples_split=4, n_estimators=1050; total time= 2.9min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=5, min_samples_split=4, n_estimators=2000; total time= 6.3min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=2, min_samples_split=2, n_estimators=1050; total time= 5.0min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=2, min_samples_split=2, n_estimators=2000; total time= 9.6min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=2, min_samples_split=3, n_estimators=1050; total time= 3.9min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=2, min_samples_split=3, n_estimators=1525; total time= 5.7min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=  28.6s
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=  28.1s
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=  22.3s
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=2, min_samples_split=4, n_estimators=575; total time= 2.8min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=2, min_samples_split=4, n_estimators=575; total time= 2.1min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=2, min_samples_split=4, n_estimators=1050; total time= 4.9min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=2, min_samples_split=4, n_estimators=2000; total time= 8.6min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=3, min_samples_split=2, n_estimators=1050; total time= 4.1min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=3, min_samples_split=2, n_estimators=2000; total time= 7.4min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=3, min_samples_split=3, n_estimators=575; total time= 2.2min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  18.2s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=1050; total time= 2.9min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=1525; total time= 5.5min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=  28.0s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=  29.7s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=3, n_estimators=575; total time= 2.8min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=3, n_estimators=575; total time= 2.8min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=3, n_estimators=1525; total time= 7.6min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=3, n_estimators=2000; total time= 9.9min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=4, n_estimators=1525; total time= 7.0min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=  23.6s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=3, min_samples_split=2, n_estimators=575; total time= 2.7min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=3, min_samples_split=2, n_estimators=575; total time= 2.5min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=3, min_samples_split=2, n_estimators=1525; total time= 6.9min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=3, min_samples_split=2, n_estimators=2000; total time= 9.0min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=3, min_samples_split=3, n_estimators=1525; total time= 7.2min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=3, min_samples_split=4, n_estimators=575; total time= 2.1min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=3, min_samples_split=4, n_estimators=1050; total time= 4.1min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=3, min_samples_split=4, n_estimators=1525; total time= 6.0min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  20.8s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=575; total time= 2.3min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=1050; total time= 4.3min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=1525; total time= 5.0min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=3, n_estimators=100; total time=  24.8s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=3, n_estimators=575; total time= 2.4min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=3, n_estimators=1050; total time= 3.5min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=3, n_estimators=1525; total time= 4.0min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=3, n_estimators=2000; total time= 6.6min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=4, n_estimators=1525; total time= 5.2min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=  19.2s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=2, n_estimators=575; total time= 2.1min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=2, n_estimators=575; total time= 1.8min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=2, n_estimators=1525; total time= 4.9min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=2, n_estimators=2000; total time= 5.2min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=3, n_estimators=1050; total time= 3.2min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=3, n_estimators=2000; total time= 9.0min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=4, n_estimators=1050; total time= 4.0min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=4, n_estimators=2000; total time=10.3min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=575; total time= 4.0min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=1525; total time=10.1min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=  44.5s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=  43.2s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=  33.2s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=  42.5s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=3, n_estimators=575; total time= 4.1min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=3, n_estimators=575; total time= 4.1min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=3, n_estimators=1525; total time=11.1min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=3, n_estimators=2000; total time=14.0min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=4, n_estimators=1525; total time= 8.6min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=  39.7s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=  33.7s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=  32.9s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=3, min_samples_split=2, n_estimators=575; total time= 3.8min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=3, min_samples_split=2, n_estimators=575; total time= 3.8min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=3, min_samples_split=2, n_estimators=1525; total time=10.2min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=3, min_samples_split=2, n_estimators=2000; total time=13.0min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=3, min_samples_split=3, n_estimators=2000; total time=13.5min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=3, min_samples_split=4, n_estimators=1050; total time= 6.6min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=3, min_samples_split=4, n_estimators=2000; total time=13.9min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=4, min_samples_split=2, n_estimators=1050; total time= 5.0min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=4, min_samples_split=2, n_estimators=2000; total time= 9.1min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=4, min_samples_split=3, n_estimators=575; total time= 2.1min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=4, min_samples_split=3, n_estimators=1050; total time= 4.8min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=4, min_samples_split=3, n_estimators=2000; total time= 9.7min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=4, min_samples_split=4, n_estimators=1050; total time= 5.0min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=4, min_samples_split=4, n_estimators=2000; total time=11.4min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=5, min_samples_split=2, n_estimators=1050; total time= 4.4min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=5, min_samples_split=2, n_estimators=2000; total time= 9.3min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=5, min_samples_split=3, n_estimators=1050; total time= 3.9min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=5, min_samples_split=3, n_estimators=1525; total time= 5.4min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=5, min_samples_split=4, n_estimators=100; total time=  31.5s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=5, min_samples_split=4, n_estimators=100; total time=  31.6s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=5, min_samples_split=4, n_estimators=100; total time=  29.1s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=5, min_samples_split=4, n_estimators=575; total time= 3.1min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=5, min_samples_split=4, n_estimators=1050; total time= 5.6min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=5, min_samples_split=4, n_estimators=2000; total time=10.2min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=2, min_samples_split=2, n_estimators=575; total time= 4.0min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=2, min_samples_split=2, n_estimators=1525; total time=26.2min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=  46.2s
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=  44.9s
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=  34.3s
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=2, min_samples_split=3, n_estimators=575; total time= 4.3min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=2, min_samples_split=3, n_estimators=575; total time= 3.3min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=2, min_samples_split=3, n_estimators=1050; total time= 7.4min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=2, min_samples_split=3, n_estimators=2000; total time=22.3min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=2, min_samples_split=4, n_estimators=1050; total time= 5.8min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=2, min_samples_split=4, n_estimators=1525; total time= 9.9min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=  30.6s
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=  38.8s
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=3, min_samples_split=2, n_estimators=575; total time= 3.1min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=3, min_samples_split=2, n_estimators=575; total time= 3.2min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=3, min_samples_split=2, n_estimators=1050; total time= 6.9min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=3, min_samples_split=2, n_estimators=2000; total time=10.2min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=3, min_samples_split=3, n_estimators=1050; total time= 5.3min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=3, min_samples_split=3, n_estimators=1525; total time= 6.4min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=3, min_samples_split=4, n_estimators=100; total time=  20.8s
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=3, min_samples_split=4, n_estimators=100; total time=  25.7s
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=3, min_samples_split=4, n_estimators=575; total time= 2.0min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=3, min_samples_split=4, n_estimators=575; total time= 2.5min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=3, min_samples_split=4, n_estimators=1525; total time= 6.7min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=3, min_samples_split=4, n_estimators=2000; total time= 8.8min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=4, min_samples_split=2, n_estimators=2000; total time= 6.2min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=4, min_samples_split=3, n_estimators=1050; total time= 2.5min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=4, min_samples_split=3, n_estimators=1525; total time= 3.6min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=  22.6s
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=  18.2s
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=  14.3s
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=4, min_samples_split=4, n_estimators=575; total time= 1.7min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=4, min_samples_split=4, n_estimators=575; total time= 1.4min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=4, min_samples_split=4, n_estimators=1050; total time= 2.5min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=4, min_samples_split=4, n_estimators=2000; total time= 7.3min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=5, min_samples_split=2, n_estimators=1050; total time= 2.9min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=5, min_samples_split=2, n_estimators=2000; total time= 6.2min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=5, min_samples_split=3, n_estimators=1050; total time= 2.5min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=5, min_samples_split=3, n_estimators=1525; total time= 3.6min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=5, min_samples_split=4, n_estimators=100; total time=  20.4s
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=5, min_samples_split=4, n_estimators=100; total time=  18.7s
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=5, min_samples_split=4, n_estimators=100; total time=  16.6s
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=5, min_samples_split=4, n_estimators=575; total time= 1.8min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=5, min_samples_split=4, n_estimators=1050; total time= 3.5min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=5, min_samples_split=4, n_estimators=2000; total time= 6.7min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=2, min_samples_split=2, n_estimators=575; total time= 2.7min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=2, min_samples_split=2, n_estimators=1525; total time= 6.6min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=2, min_samples_split=2, n_estimators=2000; total time= 9.3min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=2, min_samples_split=3, n_estimators=1525; total time= 6.6min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=  26.4s
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=  27.6s
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=2, min_samples_split=4, n_estimators=575; total time= 2.7min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=2, min_samples_split=4, n_estimators=575; total time= 2.7min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=2, min_samples_split=4, n_estimators=1525; total time= 7.1min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=2, min_samples_split=4, n_estimators=2000; total time= 9.5min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=3, min_samples_split=2, n_estimators=2000; total time= 9.1min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=3, min_samples_split=3, n_estimators=1050; total time= 4.0min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=3, min_samples_split=3, n_estimators=2000; total time= 7.7min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=3, min_samples_split=4, n_estimators=575; total time= 2.2min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=3, min_samples_split=4, n_estimators=1050; total time= 4.7min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=3, min_samples_split=4, n_estimators=2000; total time= 7.0min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=4, min_samples_split=2, n_estimators=1050; total time= 3.1min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  14.1s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=575; total time= 1.4min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=1050; total time= 3.4min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=2000; total time= 9.3min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=3, n_estimators=1050; total time= 4.1min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=3, n_estimators=1525; total time= 7.5min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=4, n_estimators=575; total time= 2.6min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=4, n_estimators=1050; total time= 5.3min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=4, n_estimators=2000; total time= 9.9min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=3, min_samples_split=2, n_estimators=1050; total time= 3.8min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=3, min_samples_split=2, n_estimators=1525; total time= 5.8min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=  21.0s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=  22.5s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=3, min_samples_split=3, n_estimators=575; total time= 2.6min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=3, min_samples_split=3, n_estimators=1050; total time= 3.9min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=3, min_samples_split=3, n_estimators=1525; total time= 6.1min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=3, min_samples_split=4, n_estimators=100; total time=  23.4s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=3, min_samples_split=4, n_estimators=100; total time=  29.8s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=3, min_samples_split=4, n_estimators=575; total time= 2.3min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=3, min_samples_split=4, n_estimators=575; total time= 2.7min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=3, min_samples_split=4, n_estimators=1525; total time= 7.3min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=3, min_samples_split=4, n_estimators=2000; total time= 9.5min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=2000; total time= 7.1min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=3, n_estimators=1050; total time= 2.8min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=3, n_estimators=1525; total time= 4.9min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=4, n_estimators=575; total time= 2.1min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=4, n_estimators=575; total time= 1.6min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=4, n_estimators=1050; total time= 3.4min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=4, n_estimators=2000; total time= 6.8min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=2, n_estimators=1050; total time= 3.7min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=2, n_estimators=2000; total time= 6.3min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=3, n_estimators=575; total time= 1.9min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=3, n_estimators=1525; total time= 4.9min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=3, n_estimators=2000; total time= 7.6min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=4, n_estimators=1525; total time= 8.0min
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=5, min_samples_split=4, n_estimators=2000; total time= 8.5min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=1525; total time=11.2min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=2000; total time=14.3min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=3, n_estimators=1525; total time= 9.9min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=  38.7s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=  41.8s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=4, n_estimators=575; total time= 4.0min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=4, n_estimators=575; total time= 4.1min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=4, n_estimators=1525; total time=10.7min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=4, n_estimators=2000; total time=14.1min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=3, min_samples_split=2, n_estimators=2000; total time=13.2min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=3, min_samples_split=3, n_estimators=1050; total time= 5.8min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=3, min_samples_split=3, n_estimators=2000; total time=11.0min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=3, min_samples_split=4, n_estimators=575; total time= 3.4min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=3, min_samples_split=4, n_estimators=1050; total time= 7.8min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=3, min_samples_split=4, n_estimators=2000; total time=10.5min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=4, min_samples_split=2, n_estimators=1050; total time= 5.2min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=4, min_samples_split=2, n_estimators=1525; total time= 7.1min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=4, min_samples_split=3, n_estimators=100; total time=  28.8s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=4, min_samples_split=3, n_estimators=575; total time= 3.2min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=4, min_samples_split=3, n_estimators=1050; total time= 4.8min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=4, min_samples_split=3, n_estimators=1525; total time= 5.9min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=  34.4s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=  28.4s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=  26.4s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=4, min_samples_split=4, n_estimators=575; total time= 2.8min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=4, min_samples_split=4, n_estimators=575; total time= 2.6min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=4, min_samples_split=4, n_estimators=1525; total time= 7.1min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=4, min_samples_split=4, n_estimators=2000; total time= 7.4min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=5, min_samples_split=2, n_estimators=1050; total time= 3.7min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=5, min_samples_split=2, n_estimators=2000; total time=10.0min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=5, min_samples_split=3, n_estimators=1050; total time= 5.2min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=5, min_samples_split=3, n_estimators=2000; total time= 9.5min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=5, min_samples_split=4, n_estimators=1050; total time= 5.0min
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=5, min_samples_split=4, n_estimators=1525; total time= 6.6min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  42.5s
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=2, min_samples_split=2, n_estimators=575; total time= 3.7min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=2, min_samples_split=2, n_estimators=1050; total time= 5.9min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=2, min_samples_split=2, n_estimators=1525; total time=24.9min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=  40.5s
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=  44.2s
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=2, min_samples_split=3, n_estimators=575; total time= 4.2min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=2, min_samples_split=3, n_estimators=575; total time= 4.1min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=2, min_samples_split=3, n_estimators=1525; total time=20.3min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=2, min_samples_split=3, n_estimators=2000; total time=14.0min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=2, min_samples_split=4, n_estimators=1525; total time= 8.6min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=  39.6s
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=  32.1s
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=  33.7s
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=3, min_samples_split=2, n_estimators=575; total time= 3.8min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=3, min_samples_split=2, n_estimators=1050; total time= 6.9min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=3, min_samples_split=2, n_estimators=1525; total time= 9.9min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=3, min_samples_split=3, n_estimators=575; total time= 2.9min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=3, min_samples_split=3, n_estimators=1050; total time= 6.8min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=3, min_samples_split=3, n_estimators=1525; total time= 7.1min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=3, min_samples_split=4, n_estimators=575; total time= 2.0min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=3, min_samples_split=4, n_estimators=1050; total time= 3.6min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=3, min_samples_split=4, n_estimators=1525; total time= 5.2min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  21.3s
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  18.2s
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  14.8s
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=4, min_samples_split=2, n_estimators=575; total time= 2.1min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=4, min_samples_split=2, n_estimators=1050; total time= 3.9min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=4, min_samples_split=2, n_estimators=1525; total time= 3.7min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=4, min_samples_split=2, n_estimators=2000; total time= 5.8min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=4, min_samples_split=3, n_estimators=1525; total time= 4.6min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=  18.2s
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=  17.4s
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=4, min_samples_split=4, n_estimators=575; total time= 1.8min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=4, min_samples_split=4, n_estimators=575; total time= 1.7min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=4, min_samples_split=4, n_estimators=1525; total time= 4.6min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=4, min_samples_split=4, n_estimators=2000; total time= 4.8min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=5, min_samples_split=2, n_estimators=1050; total time= 2.5min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=5, min_samples_split=2, n_estimators=1525; total time= 4.2min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=5, min_samples_split=3, n_estimators=575; total time= 1.7min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=5, min_samples_split=3, n_estimators=575; total time= 1.4min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=5, min_samples_split=3, n_estimators=1525; total time= 5.0min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=5, min_samples_split=3, n_estimators=2000; total time= 5.6min
# [CV] END criterion=gini, max_depth=60, min_samples_leaf=5, min_samples_split=4, n_estimators=1525; total time= 4.7min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  28.3s
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  27.6s
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=2, min_samples_split=2, n_estimators=575; total time= 2.6min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=2, min_samples_split=2, n_estimators=1050; total time= 4.5min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=2, min_samples_split=2, n_estimators=1525; total time= 7.1min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=2, min_samples_split=3, n_estimators=575; total time= 2.5min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=2, min_samples_split=3, n_estimators=1050; total time= 4.9min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=2, min_samples_split=3, n_estimators=2000; total time= 9.3min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=2, min_samples_split=4, n_estimators=1050; total time= 5.0min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=2, min_samples_split=4, n_estimators=2000; total time= 9.3min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=3, min_samples_split=2, n_estimators=1050; total time= 3.9min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=3, min_samples_split=2, n_estimators=1525; total time= 6.0min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=  20.7s
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=3, min_samples_split=3, n_estimators=100; total time=  26.4s
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=3, min_samples_split=3, n_estimators=575; total time= 2.1min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=3, min_samples_split=3, n_estimators=575; total time= 2.6min
# [CV] END criterion=gini, max_depth=80, min_samples_leaf=3, min_samples_split=3, n_estimators=1525; total time= 7.1min
# ...
# [CV] END criterion=entropy, max_depth=60, min_samples_leaf=4, min_samples_split=4, n_estimators=2000; total time= 4.3min
# [CV] END criterion=entropy, max_depth=60, min_samples_leaf=5, min_samples_split=2, n_estimators=1525; total time= 3.3min
# [CV] END criterion=entropy, max_depth=60, min_samples_leaf=5, min_samples_split=3, n_estimators=100; total time=  13.8s
# [CV] END criterion=entropy, max_depth=60, min_samples_leaf=5, min_samples_split=3, n_estimators=100; total time=  12.8s
# [CV] END criterion=entropy, max_depth=60, min_samples_leaf=5, min_samples_split=3, n_estimators=575; total time= 1.3min
# [CV] END criterion=entropy, max_depth=60, min_samples_leaf=5, min_samples_split=3, n_estimators=1050; total time= 2.3min
# [CV] END criterion=entropy, max_depth=60, min_samples_leaf=5, min_samples_split=3, n_estimators=2000; total time= 4.4min
# [CV] END criterion=entropy, max_depth=60, min_samples_leaf=5, min_samples_split=4, n_estimators=1050; total time= 2.1min
# [CV] END criterion=entropy, max_depth=60, min_samples_leaf=5, min_samples_split=4, n_estimators=1525; total time= 2.8min
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  12.0s
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  14.4s
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  11.6s
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=2, min_samples_split=2, n_estimators=575; total time= 1.2min
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=2, min_samples_split=2, n_estimators=575; total time= 1.3min
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=2, min_samples_split=2, n_estimators=1525; total time= 3.5min
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=2, min_samples_split=2, n_estimators=2000; total time= 4.5min
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=2, min_samples_split=3, n_estimators=1525; total time= 3.9min
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=  15.5s
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=  13.8s
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=2, min_samples_split=4, n_estimators=575; total time= 1.3min
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=2, min_samples_split=4, n_estimators=1050; total time= 2.3min
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=2, min_samples_split=4, n_estimators=2000; total time= 4.4min
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=3, min_samples_split=2, n_estimators=1050; total time= 2.3min
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=3, min_samples_split=2, n_estimators=2000; total time= 4.3min
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=3, min_samples_split=3, n_estimators=1050; total time= 2.0min
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=3, min_samples_split=3, n_estimators=1525; total time= 2.7min
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=3, min_samples_split=4, n_estimators=100; total time=  11.7s
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=3, min_samples_split=4, n_estimators=100; total time=  12.5s
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=3, min_samples_split=4, n_estimators=100; total time=  11.0s
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=3, min_samples_split=4, n_estimators=575; total time= 1.2min
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=3, min_samples_split=4, n_estimators=1050; total time= 2.2min
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=3, min_samples_split=4, n_estimators=2000; total time= 3.9min
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=4, min_samples_split=2, n_estimators=575; total time= 1.0min
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=4, min_samples_split=2, n_estimators=1050; total time= 2.2min
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=4, min_samples_split=2, n_estimators=2000; total time= 4.2min
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=4, min_samples_split=3, n_estimators=1050; total time= 2.0min
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=4, min_samples_split=3, n_estimators=1525; total time= 3.6min
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=4, min_samples_split=4, n_estimators=575; total time= 1.3min
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=4, min_samples_split=4, n_estimators=1050; total time= 2.3min
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=4, min_samples_split=4, n_estimators=2000; total time= 4.2min
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=5, min_samples_split=2, n_estimators=1050; total time= 2.0min
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=5, min_samples_split=2, n_estimators=1525; total time= 2.9min
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=5, min_samples_split=3, n_estimators=100; total time=  13.6s
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=5, min_samples_split=3, n_estimators=100; total time=  15.2s
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=5, min_samples_split=3, n_estimators=100; total time=  13.4s
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=5, min_samples_split=3, n_estimators=575; total time= 1.3min
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=5, min_samples_split=3, n_estimators=575; total time= 1.3min
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=5, min_samples_split=3, n_estimators=1525; total time= 3.2min
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=5, min_samples_split=3, n_estimators=2000; total time= 4.1min
# [CV] END criterion=entropy, max_depth=80, min_samples_leaf=5, min_samples_split=4, n_estimators=1525; total time= 3.1min
# [CV] END criterion=entropy, max_depth=100, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  12.9s
# [CV] END criterion=entropy, max_depth=100, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  12.3s
# [CV] END criterion=entropy, max_depth=100, min_samples_leaf=2, min_samples_split=2, n_estimators=575; total time= 1.2min
# [CV] END criterion=entropy, max_depth=100, min_samples_leaf=2, min_samples_split=2, n_estimators=1050; total time= 2.3min
# [CV] END criterion=entropy, max_depth=100, min_samples_leaf=2, min_samples_split=2, n_estimators=2000; total time= 4.5min
# [CV] END criterion=entropy, max_depth=100, min_samples_leaf=2, min_samples_split=3, n_estimators=1050; total time= 2.3min
# [CV] END criterion=entropy, max_depth=100, min_samples_leaf=2, min_samples_split=3, n_estimators=2000; total time= 4.9min
# [CV] END criterion=entropy, max_depth=100, min_samples_leaf=2, min_samples_split=4, n_estimators=1050; total time= 2.3min
# [CV] END criterion=entropy, max_depth=100, min_samples_leaf=2, min_samples_split=4, n_estimators=1525; total time= 2.9min
# [CV] END criterion=entropy, max_depth=100, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=  11.8s
# [CV] END criterion=entropy, max_depth=100, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=  12.7s
# [CV] END criterion=entropy, max_depth=100, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=  10.6s
# [CV] END criterion=entropy, max_depth=100, min_samples_leaf=3, min_samples_split=2, n_estimators=575; total time= 1.1min
# [CV] END criterion=entropy, max_depth=100, min_samples_leaf=3, min_samples_split=2, n_estimators=575; total time= 1.2min
# [CV] END criterion=entropy, max_depth=100, min_samples_leaf=3, min_samples_split=2, n_estimators=1525; total time= 3.3min
# [CV] END criterion=entropy, max_depth=100, min_samples_leaf=3, min_samples_split=2, n_estimators=2000; total time= 4.2min
# [CV] END criterion=entropy, max_depth=100, min_samples_leaf=3, min_samples_split=3, n_estimators=1525; total time= 3.3min
# [CV] END criterion=entropy, max_depth=100, min_samples_leaf=3, min_samples_split=4, n_estimators=100; total time=  12.2s
# [CV] END criterion=entropy, max_depth=100, min_samples_leaf=3, min_samples_split=4, n_estimators=100; total time=  12.3s
# [CV] END criterion=entropy, max_depth=100, min_samples_leaf=3, min_samples_split=4, n_estimators=575; total time= 1.2min
# [CV] END criterion=entropy, max_depth=100, min_samples_leaf=3, min_samples_split=4, n_estimators=1050; total time= 2.2min
# [CV] END criterion=entropy, max_depth=100, min_samples_leaf=3, min_samples_split=4, n_estimators=2000; total time= 3.8min
# [CV] END criterion=entropy, max_depth=100, min_samples_leaf=4, min_samples_split=2, n_estimators=575; total time= 1.0min
# [CV] END criterion=entropy, max_depth=100, min_samples_leaf=4, min_samples_split=2, n_estimators=1050; total time= 2.2min
# [CV] END criterion=entropy, max_depth=100, min_samples_leaf=4, min_samples_split=2, n_estimators=2000; total time= 4.1min
# [CV] END criterion=entropy, max_depth=100, min_samples_leaf=4, min_samples_split=3, n_estimators=1050; total time= 1.9min
# [CV] END criterion=entropy, max_depth=100, min_samples_leaf=4, min_samples_split=3, n_estimators=1525; total time= 3.1min
# [CV] END criterion=entropy, max_depth=100, min_samples_leaf=4, min_samples_split=4, n_estimators=575; total time= 1.2min
# [CV] END criterion=entropy, max_depth=100, min_samples_leaf=4, min_samples_split=4, n_estimators=1050; total time= 2.2min
# [CV] END criterion=entropy, max_depth=100, min_samples_leaf=4, min_samples_split=4, n_estimators=2000; total time= 3.8min
# [CV] END criterion=entropy, max_depth=100, min_samples_leaf=5, min_samples_split=2, n_estimators=575; total time= 1.0min
# [CV] END criterion=entropy, max_depth=100, min_samples_leaf=5, min_samples_split=2, n_estimators=1525; total time= 2.9min
# [CV] END criterion=entropy, max_depth=100, min_samples_leaf=5, min_samples_split=2, n_estimators=2000; total time= 3.6min
# [CV] END criterion=entropy, max_depth=100, min_samples_leaf=5, min_samples_split=3, n_estimators=1050; total time= 2.1min
# [CV] END criterion=entropy, max_depth=100, min_samples_leaf=5, min_samples_split=3, n_estimators=2000; total time= 4.1min
# [CV] END criterion=entropy, max_depth=100, min_samples_leaf=5, min_samples_split=4, n_estimators=1050; total time= 1.9min
# [CV] END criterion=entropy, max_depth=100, min_samples_leaf=5, min_samples_split=4, n_estimators=1525; total time= 3.1min
# [CV] END criterion=entropy, max_depth=150, min_samples_leaf=2, min_samples_split=2, n_estimators=575; total time= 1.2min
# [CV] END criterion=entropy, max_depth=150, min_samples_leaf=2, min_samples_split=2, n_estimators=1050; total time= 2.3min
# [CV] END criterion=entropy, max_depth=150, min_samples_leaf=2, min_samples_split=2, n_estimators=2000; total time= 3.9min
# [CV] END criterion=entropy, max_depth=150, min_samples_leaf=2, min_samples_split=3, n_estimators=575; total time= 1.0min
# [CV] END criterion=entropy, max_depth=150, min_samples_leaf=2, min_samples_split=3, n_estimators=1525; total time= 3.0min
# [CV] END criterion=entropy, max_depth=150, min_samples_leaf=2, min_samples_split=3, n_estimators=2000; total time= 3.7min
# [CV] END criterion=entropy, max_depth=150, min_samples_leaf=2, min_samples_split=4, n_estimators=1525; total time= 2.9min
# [CV] END criterion=entropy, max_depth=150, min_samples_leaf=2, min_samples_split=4, n_estimators=2000; total time= 3.6min
# [CV] END criterion=entropy, max_depth=150, min_samples_leaf=3, min_samples_split=2, n_estimators=1050; total time= 2.2min
# [CV] END criterion=entropy, max_depth=150, min_samples_leaf=3, min_samples_split=2, n_estimators=2000; total time= 4.1min
# [CV] END criterion=entropy, max_depth=150, min_samples_leaf=3, min_samples_split=3, n_estimators=1050; total time= 1.9min
# [CV] END criterion=entropy, max_depth=150, min_samples_leaf=3, min_samples_split=3, n_estimators=1525; total time= 3.2min
# [CV] END criterion=entropy, max_depth=150, min_samples_leaf=3, min_samples_split=4, n_estimators=575; total time= 1.2min
# [CV] END criterion=entropy, max_depth=150, min_samples_leaf=3, min_samples_split=4, n_estimators=1050; total time= 2.3min
# [CV] END criterion=entropy, max_depth=150, min_samples_leaf=3, min_samples_split=4, n_estimators=2000; total time= 4.3min
# [CV] END criterion=entropy, max_depth=150, min_samples_leaf=4, min_samples_split=2, n_estimators=1050; total time= 2.0min
# [CV] END criterion=entropy, max_depth=150, min_samples_leaf=4, min_samples_split=2, n_estimators=1525; total time= 2.7min
# [CV] END criterion=entropy, max_depth=150, min_samples_leaf=4, min_samples_split=3, n_estimators=100; total time=  11.3s
# [CV] END criterion=entropy, max_depth=150, min_samples_leaf=4, min_samples_split=3, n_estimators=100; total time=  12.4s
# [CV] END criterion=entropy, max_depth=150, min_samples_leaf=4, min_samples_split=3, n_estimators=100; total time=  10.5s
# [CV] END criterion=entropy, max_depth=150, min_samples_leaf=4, min_samples_split=3, n_estimators=575; total time= 1.1min
# [CV] END criterion=entropy, max_depth=150, min_samples_leaf=4, min_samples_split=3, n_estimators=575; total time= 1.2min
# [CV] END criterion=entropy, max_depth=150, min_samples_leaf=4, min_samples_split=3, n_estimators=1525; total time= 3.2min
# [CV] END criterion=entropy, max_depth=150, min_samples_leaf=4, min_samples_split=3, n_estimators=2000; total time= 4.1min
# [CV] END criterion=entropy, max_depth=150, min_samples_leaf=4, min_samples_split=4, n_estimators=1525; total time= 3.1min
# [CV] END criterion=entropy, max_depth=150, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=  12.1s
# [CV] END criterion=entropy, max_depth=150, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=  12.1s
# [CV] END criterion=entropy, max_depth=150, min_samples_leaf=5, min_samples_split=2, n_estimators=575; total time= 1.2min
# [CV] END criterion=entropy, max_depth=150, min_samples_leaf=5, min_samples_split=2, n_estimators=1050; total time= 2.1min
# [CV] END criterion=entropy, max_depth=150, min_samples_leaf=5, min_samples_split=2, n_estimators=2000; total time= 3.8min
# [CV] END criterion=entropy, max_depth=150, min_samples_leaf=5, min_samples_split=3, n_estimators=575; total time= 1.0min
# [CV] END criterion=entropy, max_depth=150, min_samples_leaf=5, min_samples_split=3, n_estimators=1050; total time= 2.1min
# [CV] END criterion=entropy, max_depth=150, min_samples_leaf=5, min_samples_split=3, n_estimators=2000; total time= 4.1min
# [CV] END criterion=entropy, max_depth=150, min_samples_leaf=5, min_samples_split=4, n_estimators=1050; total time= 1.9min
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 result1_best = find_best_models(train_x, train_y, test_x, test_y, 'Basic RF', {},
#       2                                 param_grid, 'Binding', verbose_val=2)
#       3 # result1_best = find_best_models(train_x, train_y, test_x, test_y, 'Basic RF', {'bootstrap':True, 'class_weight':'balanced'},
#       4 #                                 param_grid, 'Binding', 'NEK2bind_gridsearch_basic_best', verbose_val=2)
#
# Cell In[2], line 8, in timing.<locals>.wrap(*args, **kw)
#       5 @wraps(f)
#       6 def wrap(*args, **kw):
#       7     ts = time()
# ----> 8     result = f(*args, **kw)
#       9     te = time()
#      10     print('func:%r  took: %2.4f sec' % (f.__name__,  te-ts))
#
# Cell In[11], line 41, in find_best_models(train_x, train_y, test_x, test_y, rf_type, parameters, param_dist, dataset_type, verbose_val)
#      38 rand_search.fit(train_x, train_y)
#      39 best_rf = rand_search.best_estimator_
# ---> 41 return {'best_model': best_rf, 'train_pred':train_pred, 'test_pred': test_pred, 'train_prob':train_prob, 'test_prob': test_prob}
#
# NameError: name 'train_pred' is not defined

# %%
best_params = result1_best['best_model'].get_params()
    for param, value in best_params.items():
        print(f"{param}: {value}")
    train_pred, test_pred, train_acc, test_acc, train_prob, test_prob = rf_results(result1_best['best_model'], train_x, train_y, test_x, test_y)
    classes = ['0','1']
    plot_confusion_matrix(train_y, train_pred, classes, title=f"Best NEK2 Binding Train: Basic RF")
    plot_confusion_matrix(test_y, test_pred, classes, title=f"Best NEK2 Binding Test: Basic RF")
    pklfile = 'NEK2bind_gridsearch_basic_best.pkl'
    with open(pklfile, 'wb') as f:
        pickle.dump(result1_best['best_model'], f)

# %%
result2 = rf_models(train_x, train_y, test_x, test_y, 'balanced class_weight', {}, 'Binding')
# Out:
# train accuracy: 1.0
# test accuracy: 0.9363957597173145

# %%
result2_best = find_best_models(train_x, train_y, test_x, test_y, 'balanced class_weight', {'bootstrap':True, 'class_weight':'balanced'}, 
                                param_grid, 'Binding', 'NEK2bind_gridsearch_classweightbal_best', verbose_val=2)

# %%
best_params2 = result2_best['best_model'].get_params()
    for param, value in best_params2.items():
        print(f"{param}: {value}")
    train_pred, test_pred, train_acc, test_acc, train_prob, test_prob = rf_results(result2_best['best_model'], train_x, train_y, test_x, test_y)
    classes = ['0','1']
    plot_confusion_matrix(train_y, train_pred, classes, title=f"Best NEK2 Binding Train: balanced class_weight")
    plot_confusion_matrix(test_y, test_pred, classes, title=f"Best NEK2 Binding Test: balanced class_weight")
    pklfile = 'NEK2bind_gridsearch_classweightbal_best.pkl'
    with open(pklfile, 'wb') as f:
        pickle.dump(result2_best['best_model'], f)

# %%
result3 = rf_models(train_x, train_y, test_x, test_y, 'balanced RF', {}, 'Binding')
# Out:
# /Users/jayceepang/miniconda3/envs/atom2024/lib/python3.9/site-packages/imblearn/ensemble/_forest.py:576: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# /Users/jayceepang/miniconda3/envs/atom2024/lib/python3.9/site-packages/imblearn/ensemble/_forest.py:588: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# train accuracy: 0.7333333333333333
# test accuracy: 0.7314487632508834

# %%
result3_best = find_best_models(train_x, train_y, test_x, test_y, 'balanced RF', {}, 
                                param_grid, 'Binding', 'NEK2bind_gridsearch_BRF_best', 2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 result3_best = find_best_models(train_x, train_y, test_x, test_y, 'balanced RF', {},
#       2                                 param_grid, 'Binding', 'NEK2bind_gridsearch_BRF_best', verbose_val=2)
#
# Cell In[2], line 8, in timing.<locals>.wrap(*args, **kw)
#       5 @wraps(f)
#       6 def wrap(*args, **kw):
#       7     ts = time()
# ----> 8     result = f(*args, **kw)
#       9     te = time()
#      10     print('func:%r  took: %2.4f sec' % (f.__name__,  te-ts))
#
# TypeError: find_best_models() got multiple values for argument 'verbose_val'

# %%
best_params3 = result3_best['best_model'].get_params()
    for param, value in best_params3.items():
        print(f"{param}: {value}")
    train_pred, test_pred, train_acc, test_acc, train_prob, test_prob = rf_results(result3_best['best_model'], train_x, train_y, test_x, test_y)
    classes = ['0','1']
    plot_confusion_matrix(train_y, train_pred, classes, title=f"Best NEK2 Binding Train: Balanced RF")
    plot_confusion_matrix(test_y, test_pred, classes, title=f"Best NEK2 Binding Test: Balanced RF")
    pklfile = 'NEK2bind_gridsearch_BRF_best.pkl'
    with open(pklfile, 'wb') as f:
        pickle.dump(result2_best['best_model'], f)
