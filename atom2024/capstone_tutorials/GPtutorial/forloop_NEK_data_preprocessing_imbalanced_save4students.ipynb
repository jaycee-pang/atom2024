# %% [markdown]
# ## Dealing with imbalanced data
# Use the NEK2 Binding data set as an example

# %%
import math
import torch
import numpy as np
import gpytorch
import pandas as pd
import os
from matplotlib import pyplot as plt

from sklearn.model_selection import KFold

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# Binding
nekAll = ["2","3","5","9"]
#nekAll = ["3","5","9"]

for nek in nekAll:
    # Get training data
    data_path = "/p/lustre2/fan4/NEK_data/NEK"+nek+"/scaled_descriptors/"

    binding_df = pd.read_csv(data_path+"NEK"+nek+"_1_uM_min_50_pct_binding_with_moe_descriptors.csv") 
    print(binding_df.shape)

    print(binding_df.active.value_counts())
    num_gap = (binding_df.loc[binding_df['active']==0].shape[0]) - (binding_df.loc[binding_df['active']==1].shape[0])
    print(num_gap)
    num_minority = binding_df.loc[binding_df['active']==1].shape[0]
    print(num_minority)

    # Separate majority and minority classes
    df_majority = binding_df[binding_df['active']==0]
    df_minority = binding_df[binding_df['active']==1]

    #=======================
    # Create 5-fold splits
    #=======================
    kf = KFold(n_splits=5, shuffle=True, random_state=0)

    # majority
    for i, (_, v_ind) in enumerate(kf.split(df_majority)):
        df_majority.loc[df_majority.index[v_ind], 'fold'] = f"fold{i+1}"

    # minority
    for i, (_, v_ind) in enumerate(kf.split(df_minority)):
        df_minority.loc[df_minority.index[v_ind], 'fold'] = f"fold{i+1}"


    print(df_majority['fold'].value_counts())
    print(df_minority['fold'].value_counts())


    # Concat
    all_fold_df = pd.concat([df_majority,df_minority])
    print(all_fold_df.shape)
    print(all_fold_df.active.value_counts())


    # Save to file
    split_path = "/p/lustre2/fan4/NEK_data/NEK_data_4Berkeley/NEK"+nek
    
    if not os.path.exists(split_path):
        os.makedirs(split_path)

    all_fold_df.to_csv(split_path+"/NEK"+nek+"_1_uM_min_50_pct_binding_5fold_random_imbalanced.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 9
#       5 for nek in nekAll:
#       6     # Get training data
#       7     data_path = "/p/lustre2/fan4/NEK_data/NEK"+nek+"/scaled_descriptors/"
# ----> 9     binding_df = pd.read_csv(data_path+"NEK"+nek+"_1_uM_min_50_pct_binding_with_moe_descriptors.csv")
#      10     print(binding_df.shape)
#      12     print(binding_df.active.value_counts())
#
# File ~/miniconda3/envs/atom2024/lib/python3.9/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/envs/atom2024/lib/python3.9/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~/miniconda3/envs/atom2024/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniconda3/envs/atom2024/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~/miniconda3/envs/atom2024/lib/python3.9/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/p/lustre2/fan4/NEK_data/NEK2/scaled_descriptors/NEK2_1_uM_min_50_pct_binding_with_moe_descriptors.csv'

# %%
# inhibition
source = "inhibition"
nekAll = ["2","9"]

for nek in nekAll:
    # Get training data
    data_path = "/p/lustre2/fan4/NEK_data/NEK"+nek+"/scaled_descriptors/"

    binding_df = pd.read_csv(data_path+"NEK"+nek+"_1_uM_min_50_pct_"+source+"_with_moe_descriptors.csv") 
    print(binding_df.shape)

    print(binding_df.active.value_counts())
    num_gap = (binding_df.loc[binding_df['active']==0].shape[0]) - (binding_df.loc[binding_df['active']==1].shape[0])
    print(num_gap)
    num_minority = binding_df.loc[binding_df['active']==1].shape[0]
    print(num_minority)

    # Separate majority and minority classes
    df_majority = binding_df[binding_df['active']==0]
    df_minority = binding_df[binding_df['active']==1]

    #=======================
    # Create 5-fold splits
    #=======================
    kf = KFold(n_splits=5, shuffle=True, random_state=0)

    # majority
    for i, (_, v_ind) in enumerate(kf.split(df_majority)):
        df_majority.loc[df_majority.index[v_ind], 'fold'] = f"fold{i+1}"

    # minority
    for i, (_, v_ind) in enumerate(kf.split(df_minority)):
        df_minority.loc[df_minority.index[v_ind], 'fold'] = f"fold{i+1}"


    print(df_majority['fold'].value_counts())
    print(df_minority['fold'].value_counts())


    # Concat
    all_fold_df = pd.concat([df_majority,df_minority])
    print(all_fold_df.shape)
    print(all_fold_df.active.value_counts())


    # Save to file
    split_path = "/p/lustre2/fan4/NEK_data/NEK_data_4Berkeley/NEK"+nek
    all_fold_df.to_csv(split_path+"/NEK"+nek+"_1_uM_min_50_pct_"+source+"_5fold_random_imbalanced.csv", index=False)
# Out:
# (2044, 309)
# active
# 0    1904
# 1     140
# Name: count, dtype: int64
# 1764
# 140
# fold
# fold4    381
# fold1    381
# fold2    381
# fold3    381
# fold5    380
# Name: count, dtype: int64
# fold
# fold4    28
# fold3    28
# fold1    28
# fold5    28
# fold2    28
# Name: count, dtype: int64
# (2044, 310)
# active
# 0    1904
# 1     140
# Name: count, dtype: int64
# /tmp/ipykernel_57826/1117010811.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_majority.loc[df_majority.index[v_ind], 'fold'] = f"fold{i+1}"
# /tmp/ipykernel_57826/1117010811.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minority.loc[df_minority.index[v_ind], 'fold'] = f"fold{i+1}"
# (393, 309)
# active
# 0    351
# 1     42
# Name: count, dtype: int64
# 309
# 42
# fold
# fold1    71
# fold4    70
# fold2    70
# fold3    70
# fold5    70
# Name: count, dtype: int64
# fold
# fold2    9
# fold1    9
# fold5    8
# fold4    8
# fold3    8
# Name: count, dtype: int64
# (393, 310)
# active
# 0    351
# 1     42
# Name: count, dtype: int64
# /tmp/ipykernel_57826/1117010811.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_majority.loc[df_majority.index[v_ind], 'fold'] = f"fold{i+1}"
# /tmp/ipykernel_57826/1117010811.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_minority.loc[df_minority.index[v_ind], 'fold'] = f"fold{i+1}"

# %% [markdown]
# ## 5-fold Split

# %%
# Binding
method = "binding"
nekAll = ["2","3","5","9"]
foldAll = ["fold1","fold2","fold3","fold4","fold5"]

for nek in nekAll:
    # Get training data
    split_path = "/p/lustre2/fan4/NEK_data/NEK_data_4Berkeley/NEK"+nek
    random_df = pd.read_csv(split_path+"/NEK"+nek+"_1_uM_min_50_pct_binding_5fold_random_imbalanced.csv")
    random_df.head

    moe_columns = random_df.columns[3:]
    moe_columns = moe_columns[:-1]
    moe_columns

    # Use the fold 0 as the test set, fold 1,2,3,4 as the train set
    for fold in foldAll:
        test_moe_df = random_df.loc[random_df['fold'] == fold]
        train_moe_df = random_df.loc[random_df['fold'] != fold]
        print(test_moe_df.shape)
        print(train_moe_df.shape)

        test_x_df = test_moe_df[moe_columns]
        test_y_df = test_moe_df['active']
        print(test_x_df)
        print(test_y_df.value_counts())

        train_x_df = train_moe_df[moe_columns]
        train_y_df = train_moe_df['active']
        print(train_x_df.shape)
        print(train_y_df.value_counts())


        # Save to file
        uq_path = "/p/lustre2/fan4/NEK_data/NEK_data_4Berkeley/NEK"+nek
        #uq_path = "/p/lustre2/fan4/myGPyTorch/classification_NEK/data/"

        train_x_df.to_csv(uq_path+"/NEK"+nek+"_binding_random_"+fold+"_trainX.csv", index=False)
        train_y_df.to_csv(uq_path+"/NEK"+nek+"_binding_random_"+fold+"_trainY.csv", index=False)
        test_x_df.to_csv(uq_path+"/NEK"+nek+"_binding_random_"+fold+"_testX.csv", index=False)
        test_y_df.to_csv(uq_path+"/NEK"+nek+"_binding_random_"+fold+"_testY.csv", index=False)
# Out:
# (283, 310)
# (1125, 310)
#       ASA+_per_atom       ASA-  ASA_H_per_atom       ASA_P  ASA_per_atom  \
# 1          6.511466  299.14301        8.385662  196.062190     11.950429
# 4          9.173611  133.46625        9.677048  114.335650     12.685881
# 5          8.296552  237.38503        9.749090  192.898510     14.825367
# 8          9.887776  210.51236       13.607906   81.717201     15.877828
# 9          7.022085  194.07881        7.802077  156.386930     10.452703
# ...             ...        ...             ...         ...           ...
# 1385       6.990230  193.16020        8.167764  135.191250     10.348269
# 1386       9.424202  155.31209       13.011127   73.114189     15.935694
# 1392       9.204168  170.90587       10.350260  128.671800     12.923696
# 1406       7.843355  171.71243        8.605889  130.535580     11.023215
# 1407       8.132017  268.25793        9.818810  181.742920     13.184420
#
#       BCUT_PEOE_0  BCUT_PEOE_1  BCUT_PEOE_2  BCUT_PEOE_3  \
# 1       -2.311277    -0.649332     0.697356     2.351013
# 4       -2.513905    -0.540779     0.624816     2.521958
# 5       -2.390822    -0.686825     0.680286     2.329389
# 8       -2.301079    -0.600969     0.588427     2.266870
# 9       -2.358481    -0.619637     0.689030     2.307832
# ...           ...          ...          ...          ...
# 1385    -2.766122    -0.529788     0.601506     2.834108
# 1386    -2.216968    -0.648471     0.698113     2.208924
# 1392    -2.514880    -0.556009     0.533804     2.488622
# 1406    -2.665598    -0.627511     0.665772     2.597974
# 1407    -2.446876    -0.664095     0.723524     2.553751
#
#       BCUT_SLOGP_0_per_atom  ...  vsurf_Wp2_per_atom  vsurf_Wp3  vsurf_Wp4  \
# 1                 -0.040882  ...           10.279545    141.125     30.125
# 4                 -0.079574  ...            9.536184     96.250     22.875
# 5                 -0.061154  ...           12.016447    104.750     15.375
# 8                 -0.063283  ...           11.472222     89.250     14.125
# 9                 -0.040761  ...            9.466102    193.250     57.000
# ...                     ...  ...                 ...        ...        ...
# 1385              -0.055001  ...            8.881048    154.375     34.625
# 1386              -0.080621  ...           13.465000     65.000     16.125
# 1392              -0.052263  ...            9.690000    117.750     17.250
# 1406              -0.051504  ...            9.939815    183.000     51.250
# 1407              -0.047565  ...           12.333333    189.750     37.250
#
#       vsurf_Wp5  vsurf_Wp6  vsurf_Wp7  vsurf_Wp8  weinerPath  \
# 1        12.250      2.875      0.000        0.0        4495
# 4         7.500      0.750      0.000        0.0         828
# 5         7.000      1.875      0.125        0.0        1498
# 8         6.000      2.250      0.250        0.0        1054
# 9        20.625      5.125      0.000        0.0        4157
# ...         ...        ...        ...        ...         ...
# 1385     14.250      3.750      0.000        0.0        2737
# 1386      6.125      1.500      0.000        0.0         343
# 1392      6.750      2.375      0.000        0.0        2483
# 1406     19.625      5.625      0.125        0.0        3068
# 1407     13.625      3.875      0.375        0.0        3394
#
#       weinerPol_per_atom  zagreb_per_atom
# 1               0.945455         3.418182
# 4               0.763158         2.736842
# 5               1.078947         3.526316
# 8               0.972222         3.166667
# 9               0.864407         2.949153
# ...                  ...              ...
# 1385            1.370968         3.548387
# 1386            0.840000         3.200000
# 1392            0.960000         3.040000
# 1406            0.888889         2.962963
# 1407            1.018519         3.444444
#
# [283 rows x 306 columns]
# active
# 0    271
# 1     12
# Name: count, dtype: int64
# (1125, 306)
# active
# 0    1080
# 1      45
# Name: count, dtype: int64
# (282, 310)
# (1126, 310)
#       ASA+_per_atom       ASA-  ASA_H_per_atom       ASA_P  ASA_per_atom  \
# 2          8.496225  275.10083        8.517174  278.048280     13.229856
# 10         9.588181  139.56625        8.656191  190.438230     12.464956
# 15         8.682929  125.17341       10.801831   43.827816     11.797918
# 16         8.300217  199.91940        7.987547  213.364210     12.949506
# 30         7.848063  208.34720        9.244219  130.162430     11.568548
# ...             ...        ...             ...         ...           ...
# 1388       8.947021  174.32123       10.178468  129.989180     13.789278
# 1391       8.085720  139.53337        7.867777  153.481740     10.265929
# 1397       7.761542  323.33942       12.324422  118.009840     14.946863
# 1401       7.410218  280.09659        8.489622  226.126420     13.012150
# 1402       7.506570  264.71802        7.469703  267.224980     11.399482
#
#       BCUT_PEOE_0  BCUT_PEOE_1  BCUT_PEOE_2  BCUT_PEOE_3  \
# 2       -2.568112    -0.618748     0.691940     2.629537
# 10      -2.604160    -0.536553     0.606227     2.575685
# 15      -2.745140    -0.637493     0.696970     2.755602
# 16      -2.763723    -0.676670     0.652720     2.760477
# 30      -2.537478    -0.611682     0.652224     2.707293
# ...           ...          ...          ...          ...
# 1388    -2.250333    -0.579852     0.796035     2.284195
# 1391    -2.771892    -0.531475     0.690826     2.732305
# 1397    -2.406267    -0.646633     0.661950     2.394524
# 1401    -2.660094    -0.433179     0.429850     2.608499
# 1402    -2.805323    -0.516295     0.590813     2.815987
#
#       BCUT_SLOGP_0_per_atom  ...  vsurf_Wp2_per_atom  vsurf_Wp3  vsurf_Wp4  \
# 2                 -0.056514  ...           12.677966    231.750     54.000
# 10                -0.069264  ...           13.402500    255.250     70.875
# 15                -0.077583  ...            9.369318     81.000     12.750
# 16                -0.079626  ...           12.834302    223.625     72.500
# 30                -0.048752  ...            8.433036    108.875     31.125
# ...                     ...  ...                 ...        ...        ...
# 1388              -0.064613  ...           13.496528    148.750     52.500
# 1391              -0.054798  ...            9.349609    169.125     33.875
# 1397              -0.055367  ...           11.638889    117.125     16.750
# 1401              -0.055422  ...            7.797500     74.500      0.750
# 1402              -0.053332  ...            9.847426    228.750     60.125
#
#       vsurf_Wp5  vsurf_Wp6  vsurf_Wp7  vsurf_Wp8  weinerPath  \
# 2        20.250      4.625      0.125       0.00        3645
# 10       25.875      6.500      0.500       0.00        1637
# 15        4.125      0.875      0.000       0.00        1152
# 16       27.875      7.625      0.750       0.00        1586
# 30       16.750      9.375      5.125       1.75        3903
# ...         ...        ...        ...        ...         ...
# 1388     22.750      7.875      0.625       0.00        1052
# 1391     12.625      2.375      0.000       0.00        3571
# 1397      7.000      2.625      0.000       0.00        2334
# 1401      0.000      0.000      0.000       0.00        2378
# 1402     23.375      5.125      0.250       0.00        4983
#
#       weinerPol_per_atom  zagreb_per_atom
# 2               0.932203         2.983051
# 10              0.880000         2.800000
# 15              0.795455         2.772727
# 16              0.860465         2.976744
# 30              0.839286         3.035714
# ...                  ...              ...
# 1388            0.916667         3.277778
# 1391            0.812500         2.750000
# 1397            1.133333         3.466667
# 1401            1.040000         3.280000
# 1402            0.911765         3.058824
#
# [282 rows x 306 columns]
# active
# 0    270
# 1     12
# Name: count, dtype: int64
# (1126, 306)
# active
# 0    1081
# 1      45
# Name: count, dtype: int64
# (281, 310)
# (1127, 310)
#       ASA+_per_atom       ASA-  ASA_H_per_atom       ASA_P  ASA_per_atom  \
# 6          7.619170  252.39272        8.119836  235.214870     13.346833
# 12         8.838330  181.76501       10.581412   94.610909     12.473630
# 13         6.719306  271.63354       10.025254  159.231320     14.708529
# 17         6.900424  263.65964        7.199639  246.903550     11.608632
# 20         7.839983  216.33952        9.570605  148.845260     13.387151
# ...             ...        ...             ...         ...           ...
# 1377       9.495379  170.24603       10.778347  110.813720     12.830453
# 1381       7.481115  245.78061        8.806173  153.026540     10.992267
# 1399       9.242912  191.47179        9.231081  192.205340     12.331167
# 1400       6.818578  206.08147        8.474474  113.351310     10.498605
# 1405       7.708636  180.38467        8.409422  144.357180     11.133142
#
#       BCUT_PEOE_0  BCUT_PEOE_1  BCUT_PEOE_2  BCUT_PEOE_3  \
# 6       -2.349532    -0.622879     0.664782     2.752413
# 12      -2.704441    -0.564066     0.541019     2.724162
# 13      -2.338762    -0.586009     0.647049     2.363099
# 17      -2.315191    -0.630334     0.640504     2.370748
# 20      -2.312390    -0.615785     0.635777     2.298570
# ...           ...          ...          ...          ...
# 1377    -2.738001    -0.603809     0.706068     2.725313
# 1381    -2.333626    -0.657909     0.637603     2.311153
# 1399    -2.771892    -0.510433     0.662294     2.732305
# 1400    -2.746016    -0.655292     0.698405     2.666615
# 1405    -2.448838    -0.593953     0.638381     2.554231
#
#       BCUT_SLOGP_0_per_atom  ...  vsurf_Wp2_per_atom  vsurf_Wp3  vsurf_Wp4  \
# 6                 -0.055313  ...           11.805556    165.875     27.500
# 12                -0.068539  ...            9.625000    146.750     43.875
# 13                -0.070736  ...            9.937500     82.250     25.000
# 17                -0.042953  ...            9.629464    181.875     54.250
# 20                -0.056613  ...           11.717949     96.000     17.875
# ...                     ...  ...                 ...        ...        ...
# 1377              -0.064262  ...           11.590278    166.625     34.750
# 1381              -0.032895  ...            8.516071    153.375     28.000
# 1399              -0.056566  ...           10.491935    181.500     34.750
# 1400              -0.048908  ...            8.562500     96.500     16.875
# 1405              -0.048464  ...            8.625000    117.250     24.875
#
#       vsurf_Wp5  vsurf_Wp6  vsurf_Wp7  vsurf_Wp8  weinerPath  \
# 6        10.500      2.500      0.000      0.000        1981
# 12       21.625      9.875      4.375      1.375        2052
# 13        9.500      2.375      0.000      0.000        1044
# 17       22.125      5.375      0.000      0.000        5412
# 20        6.500      1.500      0.000      0.000        1709
# ...         ...        ...        ...        ...         ...
# 1377     12.750      2.875      0.000      0.000        3009
# 1381     11.875      3.500      0.000      0.000        7766
# 1399     12.875      3.125      0.000      0.000        3781
# 1400      7.000      1.750      0.000      0.000        3721
# 1405      8.750      2.000      0.000      0.000        2628
#
#       weinerPol_per_atom  zagreb_per_atom
# 6               1.000000         3.511111
# 12              0.760000         2.720000
# 13              0.823529         3.117647
# 17              1.035714         3.500000
# 20              0.923077         3.384615
# ...                  ...              ...
# 1377            0.833333         2.962963
# 1381            1.128571         3.457143
# 1399            0.822581         2.870968
# 1400            1.071429         3.392857
# 1405            0.962264         3.169811
#
# [281 rows x 306 columns]
# active
# 0    270
# 1     11
# Name: count, dtype: int64
# (1127, 306)
# active
# 0    1081
# 1      46
# Name: count, dtype: int64
# (281, 310)
# (1127, 310)
#       ASA+_per_atom        ASA-  ASA_H_per_atom      ASA_P  ASA_per_atom  \
# 0         14.897949   53.326256        8.903966  161.21796     17.860519
# 3          6.791036  344.713500        8.136228  261.31158     12.350931
# 7          9.629118  190.869540       11.334554  127.85452     14.530917
# 22         8.697605  166.925110        8.602409  171.78012     11.970647
# 26         8.426145  166.821290        9.244890  121.79031     11.459260
# ...             ...         ...             ...        ...           ...
# 1376       8.806886  163.197460        9.159060  146.61690     11.824821
# 1389       8.246741  241.523150       10.113879  152.88306     13.171541
# 1393       8.426281  172.753750        7.767350  212.94861     11.258310
# 1394       8.104833  161.416690        7.435220  190.21004     11.858710
# 1396       9.440269  132.677580        8.752351  178.08022     11.450536
#
#       BCUT_PEOE_0  BCUT_PEOE_1  BCUT_PEOE_2  BCUT_PEOE_3  \
# 0       -2.222484    -0.418766     0.435561     2.222894
# 3       -2.586196    -0.562002     0.583814     2.729245
# 7       -2.263912    -0.567763     0.769729     2.257300
# 22      -2.771563    -0.571837     0.642706     2.732413
# 26      -2.765182    -0.590753     0.704874     2.748807
# ...           ...          ...          ...          ...
# 1376    -2.326434    -0.584047     0.592415     2.374696
# 1389    -2.442411    -0.696711     0.591666     2.556199
# 1393    -2.771183    -0.539437     0.634014     2.733658
# 1394    -2.764348    -0.675757     0.652720     2.759740
# 1396    -2.665385    -0.478010     0.442054     2.647204
#
#       BCUT_SLOGP_0_per_atom  ...  vsurf_Wp2_per_atom  vsurf_Wp3  vsurf_Wp4  \
# 0                 -0.128968  ...           18.020833     95.250     30.125
# 3                 -0.043709  ...            7.979839    113.875     27.125
# 7                 -0.058621  ...           13.518750    149.000     32.625
# 22                -0.068766  ...           11.759804    207.625     44.875
# 26                -0.063794  ...            9.622727    177.750     54.500
# ...                     ...  ...                 ...        ...        ...
# 1376              -0.054630  ...            9.254545    169.125     48.500
# 1389              -0.051383  ...           10.495000    129.625     26.750
# 1393              -0.057493  ...           10.555328    204.750     54.500
# 1394              -0.079430  ...           11.712209    195.000     69.250
# 1396              -0.042139  ...            9.123106    165.875     28.000
#
#       vsurf_Wp5  vsurf_Wp6  vsurf_Wp7  vsurf_Wp8  weinerPath  \
# 0        12.500      3.750      0.250       0.00         137
# 3        10.625      2.500      0.000       0.00        4847
# 7        12.875      4.000      0.500       0.00        1310
# 22       12.125      1.750      0.000       0.00        2281
# 26       26.625     11.375      3.125       1.25        2313
# ...         ...        ...        ...        ...         ...
# 1376     19.000      5.125      0.000       0.00        3034
# 1389     10.000      2.250      0.125       0.00        3088
# 1393     21.000      6.875      0.875       0.00        3715
# 1394     25.875      6.625      0.500       0.00        1586
# 1396     10.375      2.625      0.000       0.00        3842
#
#       weinerPol_per_atom  zagreb_per_atom
# 0               0.833333         3.222222
# 3               1.064516         3.322581
# 7               0.925000         3.200000
# 22              1.019608         3.215686
# 26              0.781818         2.763636
# ...                  ...              ...
# 1376            1.000000         3.200000
# 1389            1.140000         3.600000
# 1393            0.901639         2.885246
# 1394            0.860465         2.976744
# 1396            0.969697         2.939394
#
# [281 rows x 306 columns]
# active
# 0    270
# 1     11
# Name: count, dtype: int64
# (1127, 306)
# active
# 0    1081
# 1      46
# Name: count, dtype: int64
# (281, 310)
# (1127, 310)
#       ASA+_per_atom       ASA-  ASA_H_per_atom       ASA_P  ASA_per_atom  \
# 11         6.873550  245.98434       10.211175   62.414948     11.345993
# 23         7.586992  208.02089        7.097357  253.416980     11.392561
# 24         8.224840  221.81551       10.469413  138.766300     14.219854
# 25         9.052394  203.92502       12.865377  108.600420     17.209394
# 28         6.722319  292.70175       10.207272  144.520690     13.491832
# ...             ...        ...             ...         ...           ...
# 1390       8.386387  195.18852        7.626461  242.303910     11.534589
# 1395       7.408929  118.22318        5.984303  240.741100      8.783618
# 1398       9.423163  173.10468        9.663991  164.775800     12.715394
# 1403       6.830101  267.09576        9.351566   88.071762     10.592014
# 1404       7.582028  226.90019        8.290327  182.277340     11.183618
#
#       BCUT_PEOE_0  BCUT_PEOE_1  BCUT_PEOE_2  BCUT_PEOE_3  \
# 11      -2.625533    -0.641608     0.706867     2.594863
# 23      -2.757838    -0.501422     0.529522     2.708966
# 24      -2.554365    -0.615955     0.599157     2.565347
# 25      -2.230777    -0.558488     0.626564     2.269167
# 28      -2.548146    -0.634871     0.631855     2.584251
# ...           ...          ...          ...          ...
# 1390    -2.763327    -0.579339     0.620557     2.757642
# 1395    -2.864783    -0.483557     0.567115     2.864172
# 1398    -2.447435    -0.578596     0.567191     2.554402
# 1403    -2.333702    -0.641136     0.634832     2.313544
# 1404    -2.786322    -0.552139     0.621606     2.780210
#
#       BCUT_SLOGP_0_per_atom  ...  vsurf_Wp2_per_atom  vsurf_Wp3  vsurf_Wp4  \
# 11                -0.048575  ...            9.025000    102.375     19.750
# 23                -0.048518  ...            9.391949    216.250     77.250
# 24                -0.088887  ...           13.371622    159.875     43.250
# 25                -0.086605  ...           12.755000     27.750      0.000
# 28                -0.058977  ...           12.059659    171.375     45.500
# ...                     ...  ...                 ...        ...        ...
# 1390              -0.055193  ...           11.858871    276.250     70.875
# 1395              -0.042404  ...            8.550872    270.000     86.000
# 1398              -0.047564  ...           10.099537    133.500     29.125
# 1403              -0.032431  ...            8.154930    136.875     26.000
# 1404              -0.055445  ...            9.577381    174.125     37.375
#
#       vsurf_Wp5  vsurf_Wp6  vsurf_Wp7  vsurf_Wp8  weinerPath  \
# 11        7.250      2.000      0.000      0.000        3818
# 23       35.750     15.250      5.000      0.625        2923
# 24       14.125      2.250      0.000      0.000         975
# 25        0.000      0.000      0.000      0.000         500
# 28       19.125      5.750      0.125      0.000        2026
# ...         ...        ...        ...        ...         ...
# 1390     29.875     12.250      4.875      2.000        3697
# 1395     36.250     12.625      0.875      0.000        6039
# 1398     10.875      3.375      0.250      0.000        2882
# 1403      8.000      2.750      0.375      0.000        7766
# 1404     12.250      2.375      0.125      0.000        4014
#
#       weinerPol_per_atom  zagreb_per_atom
# 11              1.000000         3.309091
# 23              0.796610         2.847458
# 24              0.810811         2.918919
# 25              1.040000         3.600000
# 28              1.045455         3.454545
# ...                  ...              ...
# 1390            0.919355         2.967742
# 1395            0.767442         2.441860
# 1398            0.981481         3.185185
# 1403            1.112676         3.408451
# 1404            0.888889         3.015873
#
# [281 rows x 306 columns]
# active
# 0    270
# 1     11
# Name: count, dtype: int64
# (1127, 306)
# active
# 0    1081
# 1      46
# Name: count, dtype: int64
# (282, 310)
# (1122, 310)
#       ASA+_per_atom       ASA-  ASA_H_per_atom      ASA_P  ASA_per_atom  \
# 1         10.215013  142.21526        6.836120  244.47214     15.890644
# 5          7.736764  220.71700        7.970176  205.31177     11.080960
# 8          8.211856  304.34698        8.814355  271.20950     13.745438
# 9          8.901980  195.95447        8.445429  222.74628     13.395346
# 14         7.612832  287.15073        9.292597  194.76367     12.833755
# ...             ...        ...             ...        ...           ...
# 1380      10.206247  174.56108       11.438849  117.39546     13.786759
# 1384       8.224840  221.81551       10.469413  138.76630     14.219854
# 1394       8.642949  161.90437        8.153549  186.68533     12.940353
# 1396       7.236550  241.08192        7.003955  254.33978     11.466057
# 1397       8.511531  277.76974        8.521127  280.75598     13.279703
#
#       BCUT_PEOE_0  BCUT_PEOE_1  BCUT_PEOE_2  BCUT_PEOE_3  \
# 1       -2.194154    -0.719023     0.731004     2.217017
# 5       -2.681831    -0.546122     0.637987     2.689039
# 8       -2.403042    -0.574742     0.596937     2.408815
# 9       -2.583713    -0.575453     0.617978     2.567737
# 14      -2.537550    -0.628175     0.660120     2.707292
# ...           ...          ...          ...          ...
# 1380    -2.647072    -0.620867     0.690330     2.605075
# 1384    -2.554365    -0.615955     0.599157     2.565347
# 1394    -2.492239    -0.584590     0.657366     2.468000
# 1396    -2.665590    -0.491930     0.530384     2.600261
# 1397    -2.568112    -0.618748     0.691940     2.629537
#
#       BCUT_SLOGP_0_per_atom  ...  vsurf_Wp2_per_atom  vsurf_Wp3  vsurf_Wp4  \
# 1                 -0.086358  ...           21.333333    243.750     81.125
# 5                 -0.052606  ...            9.878788    205.000     42.250
# 8                 -0.042698  ...           12.236364    216.750     48.000
# 9                 -0.057201  ...           12.941667    216.250     63.125
# 14                -0.049639  ...            9.900000    152.500     44.750
# ...                     ...  ...                 ...        ...        ...
# 1380              -0.055629  ...           11.690000    112.750     19.250
# 1384              -0.088887  ...           13.371622    159.875     43.250
# 1394              -0.066054  ...           11.259615    138.875     37.250
# 1396              -0.048795  ...            8.043860    118.500     19.125
# 1397              -0.056514  ...           12.631356    234.375     54.000
#
#       vsurf_Wp5  vsurf_Wp6  vsurf_Wp7  vsurf_Wp8  weinerPath  \
# 1        33.000     10.000      0.750      0.000         513
# 5        14.000      4.375      0.375      0.000        3825
# 8        19.125      5.750      0.250      0.000        4067
# 9        26.000      8.000      1.000      0.000        1508
# 14       19.875      7.750      1.000      0.375        3569
# ...         ...        ...        ...        ...         ...
# 1380      8.375      2.625      0.125      0.000        2944
# 1384     14.125      2.250      0.000      0.000         975
# 1394     13.875      3.500      0.250      0.000        1301
# 1396      7.250      2.250      0.000      0.000        4011
# 1397     19.125      4.250      0.125      0.000        3645
#
#       weinerPol_per_atom  zagreb_per_atom
# 1               0.925926         3.407407
# 5               0.878788         2.939394
# 8               0.909091         3.200000
# 9               0.933333         3.066667
# 14              0.818182         3.018182
# ...                  ...              ...
# 1380            0.880000         3.200000
# 1384            0.810811         2.918919
# 1394            0.846154         3.025641
# 1396            0.982456         3.333333
# 1397            0.932203         2.983051
#
# [282 rows x 306 columns]
# active
# 0    265
# 1     17
# Name: count, dtype: int64
# (1122, 306)
# active
# 0    1058
# 1      64
# Name: count, dtype: int64
# (281, 310)
# (1123, 310)
#       ASA+_per_atom       ASA-  ASA_H_per_atom      ASA_P  ASA_per_atom  \
# 2          9.101535  110.52470        7.935420  185.15604     10.828484
# 10         6.007288  174.51620        9.371731  160.40347     12.398212
# 15         7.162030  314.78915        9.065344  210.13132     12.567533
# 16         8.974845  158.77829        9.987769  119.27426     13.046083
# 19         8.747375  266.50034       10.316172  189.91547     14.114481
# ...             ...        ...             ...        ...           ...
# 1389       8.018614  208.74669       10.170798  119.24756     12.763136
# 1392       6.055027  197.22391        8.698582  180.47252     11.276761
# 1395       9.515752  166.51373       10.709387  111.35814     12.771575
# 1399       6.836198  264.85251       10.641759  143.07455     15.112839
# 1403       9.397039  184.02939        8.185000  257.96371     12.413913
#
#       BCUT_PEOE_0  BCUT_PEOE_1  BCUT_PEOE_2  BCUT_PEOE_3  \
# 2       -2.763372    -0.521646     0.614306     2.749081
# 10      -2.771648    -0.577210     0.571201     2.757304
# 15      -2.526301    -0.653436     0.711765     2.756262
# 16      -2.392998    -0.611255     0.634724     2.435691
# 19      -2.510593    -0.653889     0.691906     2.449687
# ...           ...          ...          ...          ...
# 1389    -2.604164    -0.641112     0.704622     2.575687
# 1392    -2.771648    -0.459768     0.384400     2.757304
# 1395    -2.738001    -0.603809     0.706068     2.725313
# 1399    -2.262449    -0.641645     0.686736     2.399311
# 1403    -2.771183    -0.539437     0.634014     2.733658
#
#       BCUT_SLOGP_0_per_atom  ...  vsurf_Wp2_per_atom  vsurf_Wp3  vsurf_Wp4  \
# 2                 -0.054835  ...            9.894531    211.250     48.500
# 10                -0.052158  ...            8.497642    131.375     38.875
# 15                -0.042031  ...            8.964583    121.875     16.000
# 16                -0.063476  ...            9.666667     79.625     15.750
# 19                -0.053029  ...           12.190000    177.375     44.500
# ...                     ...  ...                 ...        ...        ...
# 1389              -0.054428  ...           12.236413    183.250     50.125
# 1392              -0.039491  ...            7.778571    166.625     48.750
# 1395              -0.064262  ...           11.606481    165.875     35.000
# 1399              -0.075443  ...           12.679688    119.875     30.500
# 1403              -0.057493  ...           12.405738    259.875     62.625
#
#       vsurf_Wp5  vsurf_Wp6  vsurf_Wp7  vsurf_Wp8  weinerPath  \
# 2        19.125      7.500      1.000      0.000        4095
# 10       16.125      5.000      0.000      0.000        2284
# 15        5.875      1.250      0.000      0.000        4053
# 16        5.500      1.500      0.000      0.000        1129
# 19       19.000      9.000      2.875      0.375        3332
# ...         ...        ...        ...        ...         ...
# 1389     21.375      7.125      0.750      0.000        1731
# 1392     23.625      9.625      1.375      0.000        5175
# 1395     12.875      2.750      0.000      0.000        3009
# 1399     11.500      2.875      0.000      0.000        1013
# 1403     23.375      6.500      0.250      0.000        3715
#
#       weinerPol_per_atom  zagreb_per_atom
# 2               0.890625         2.906250
# 10              0.679245         2.566038
# 15              0.950000         3.266667
# 16              0.948718         3.076923
# 19              0.960000         3.320000
# ...                  ...              ...
# 1389            1.065217         3.304348
# 1392            0.614286         2.485714
# 1395            0.833333         2.962963
# 1399            1.062500         3.625000
# 1403            0.901639         2.885246
#
# [281 rows x 306 columns]
# active
# 0    265
# 1     16
# Name: count, dtype: int64
# (1123, 306)
# active
# 0    1058
# 1      65
# Name: count, dtype: int64
# (281, 310)
# (1123, 310)
#       ASA+_per_atom       ASA-  ASA_H_per_atom      ASA_P  ASA_per_atom  \
# 6          9.127324  181.32414        9.379585  172.44165     12.458901
# 12         7.545916  132.96758        7.682200  121.92850      9.187491
# 17         7.229598  367.27264        8.616301  293.77740     14.159271
# 20         8.823787  219.23532       10.051857  176.80606     14.163625
# 21         9.560263  204.29153       11.358687  122.03899     13.751608
# ...             ...        ...             ...        ...           ...
# 1375       7.699158  224.81084        8.228582  203.66338     12.857296
# 1377       6.425180  282.09427        9.149226  107.75526     10.832902
# 1379       7.488240  157.07570        6.297847  222.54729     10.344162
# 1391       8.312957  237.20760        9.434376  195.71510     14.723973
# 1401       8.074292  250.34798        9.024254  212.67752     14.088004
#
#       BCUT_PEOE_0  BCUT_PEOE_1  BCUT_PEOE_2  BCUT_PEOE_3  \
# 6       -2.725006    -0.527911     0.468935     2.810652
# 12      -2.801611    -0.540056     0.553493     2.783026
# 17      -2.292603    -0.648090     0.658295     2.771008
# 20      -2.618969    -0.588563     0.703692     2.590384
# 21      -2.495548    -0.603612     0.676758     2.449105
# ...           ...          ...          ...          ...
# 1375    -2.567076    -0.586013     0.659881     2.630484
# 1377    -2.771892    -0.642438     0.696145     2.732305
# 1379    -2.771667    -0.532608     0.622759     2.734574
# 1391    -2.283936    -0.593697     0.636254     2.405050
# 1401    -2.418291    -0.632257     0.706670     2.424005
#
#       BCUT_SLOGP_0_per_atom  ...  vsurf_Wp2_per_atom  vsurf_Wp3  vsurf_Wp4  \
# 6                 -0.050508  ...            7.714286     76.625      0.000
# 12                -0.043139  ...            6.570988    150.625     33.000
# 17                -0.044498  ...           10.575472    151.125     35.500
# 20                -0.080763  ...           12.433140    167.375     42.000
# 21                -0.052497  ...           11.424020    140.500     26.750
# ...                     ...  ...                 ...        ...        ...
# 1375              -0.059044  ...           11.789773    152.250     34.500
# 1377              -0.054798  ...            9.341797    140.375     18.875
# 1379              -0.063765  ...            8.409091    123.750     35.750
# 1391              -0.065259  ...           11.719595    115.125     21.375
# 1401              -0.057956  ...           13.690476    173.750     37.125
#
#       vsurf_Wp5  vsurf_Wp6  vsurf_Wp7  vsurf_Wp8  weinerPath  \
# 6         0.000      0.000      0.000        0.0        2266
# 12       11.500      3.250      0.125        0.0        5701
# 17       15.375      5.000      0.000        0.0        4368
# 20       15.750      4.750      0.125        0.0        1501
# 21       10.500      3.125      0.000        0.0        3046
# ...         ...        ...        ...        ...         ...
# 1375     14.250      4.000      0.000        0.0        1670
# 1377      7.000      2.125      0.000        0.0        5603
# 1379     14.625      3.625      0.000        0.0        3399
# 1391      8.000      1.750      0.000        0.0        1299
# 1401     13.750      3.875      0.500        0.0        1811
#
#       weinerPol_per_atom  zagreb_per_atom
# 6               0.821429         2.964286
# 12              0.901235         2.666667
# 17              1.018868         3.622642
# 20              0.953488         3.209302
# 21              0.882353         3.019608
# ...                  ...              ...
# 1375            1.000000         3.272727
# 1377            1.125000         3.437500
# 1379            0.981818         3.309091
# 1391            1.027027         3.351351
# 1401            0.952381         3.238095
#
# [281 rows x 306 columns]
# active
# 0    265
# 1     16
# Name: count, dtype: int64
# (1123, 306)
# active
# 0    1058
# 1      65
# Name: count, dtype: int64
# (280, 310)
# (1124, 310)
#       ASA+_per_atom       ASA-  ASA_H_per_atom      ASA_P  ASA_per_atom  \
# 0          7.599453  298.18738       11.859049  127.80351     15.054137
# 3          6.918092  260.60046        7.163683  246.84738     11.571672
# 4          7.511612  233.22250       10.668658  113.33115     13.574585
# 7          8.762341  206.48380        9.801067  158.98901     13.113339
# 13         8.688241  243.89436        8.655428  245.56784     13.470484
# ...             ...        ...             ...        ...           ...
# 1374      10.721108  146.07849        8.124511  234.88597     15.242268
# 1383       8.925264  225.67209        8.842355  234.46103     13.266149
# 1385       7.434579  192.38780        7.954900  159.23985     10.331614
# 1398       7.293504  196.79784        6.618117  238.67181     10.467663
# 1402       7.586464  226.39537        8.496118  172.17287     11.144931
#
#       BCUT_PEOE_0  BCUT_PEOE_1  BCUT_PEOE_2  BCUT_PEOE_3  \
# 0       -2.307776    -0.644023     0.614944     2.324415
# 3       -2.315191    -0.630334     0.640504     2.370748
# 4       -2.219061    -0.669839     0.696512     2.274259
# 7       -2.329385    -0.665506     0.685697     2.351025
# 13      -2.553231    -0.612038     0.578254     2.951037
# ...           ...          ...          ...          ...
# 1374    -2.262462    -0.665792     0.698080     2.228232
# 1383    -2.665598    -0.635284     0.667129     2.597973
# 1385    -2.677684    -0.586335     0.689911     2.649157
# 1398    -2.763327    -0.579339     0.620557     2.757642
# 1402    -2.620964    -0.630059     0.688308     2.564217
#
#       BCUT_SLOGP_0_per_atom  ...  vsurf_Wp2_per_atom  vsurf_Wp3  vsurf_Wp4  \
# 0                 -0.061188  ...           12.165625    119.000     19.125
# 3                 -0.042953  ...            9.627232    182.000     54.125
# 4                 -0.055838  ...           10.785256     69.625      1.750
# 7                 -0.052911  ...           10.440104    102.500      7.500
# 13                -0.052603  ...           10.943627    147.875     33.125
# ...                     ...  ...                 ...        ...        ...
# 1374              -0.068137  ...           14.541667    148.125     36.875
# 1383              -0.052476  ...           11.558962    171.875     32.375
# 1385              -0.051807  ...            9.983209    192.125     44.625
# 1398              -0.055193  ...           11.493952    254.125     70.250
# 1402              -0.053308  ...           10.009615    206.625     55.250
#
#       vsurf_Wp5  vsurf_Wp6  vsurf_Wp7  vsurf_Wp8  weinerPath  \
# 0         5.625      1.375      0.250      0.000        1722
# 3        22.125      5.375      0.000      0.000        5412
# 4         0.000      0.000      0.000      0.000        1755
# 7         1.125      0.000      0.000      0.000        2936
# 13       12.375      3.625      0.250      0.000        3114
# ...         ...        ...        ...        ...         ...
# 1374     13.500      3.500      0.000      0.000        1045
# 1383     11.875      3.500      0.000      0.000        3304
# 1385     18.500      6.000      0.500      0.000        5640
# 1398     30.250     12.000      4.750      1.875        3697
# 1402     19.375      6.250      0.125      0.000        5907
#
#       weinerPol_per_atom  zagreb_per_atom
# 0               1.000000         3.500000
# 3               1.035714         3.500000
# 4               1.025641         3.743590
# 7               1.083333         3.541667
# 13              0.803922         3.254902
# ...                  ...              ...
# 1374            0.909091         3.272727
# 1383            0.867925         2.981132
# 1385            0.776119         2.776119
# 1398            0.919355         2.967742
# 1402            0.846154         2.953846
#
# [280 rows x 306 columns]
# active
# 0    264
# 1     16
# Name: count, dtype: int64
# (1124, 306)
# active
# 0    1059
# 1      65
# Name: count, dtype: int64
# (280, 310)
# (1124, 310)
#       ASA+_per_atom       ASA-  ASA_H_per_atom       ASA_P  ASA_per_atom  \
# 11         8.917764  153.35754        8.920795  157.043400     12.572967
# 23         8.739346  194.10822       10.344430  106.722490     12.250189
# 24         8.615438  159.62811        6.797009  240.598010     12.392311
# 25         7.796604  186.91588        8.385761  149.798980     10.763523
# 28         8.697266  216.59297       11.393547  100.652900     13.734311
# ...             ...        ...             ...         ...           ...
# 1387       7.199203  186.93825        7.093256  193.189190     10.367649
# 1388       8.156430  237.23343       10.997156  123.878350     14.094115
# 1390       7.852167  172.38380        8.631871  130.279750     11.044460
# 1393       9.718043  193.89278       12.875704   88.634361     15.408114
# 1400       6.507985  213.30025        9.257843  134.728740     11.396395
#
#       BCUT_PEOE_0  BCUT_PEOE_1  BCUT_PEOE_2  BCUT_PEOE_3  \
# 11      -2.604172    -0.616718     0.758951     2.737525
# 23      -2.763369    -0.572579     0.602639     2.749064
# 24      -2.808110    -0.536906     0.541156     2.756086
# 25      -2.760016    -0.571083     0.675460     2.770282
# 28      -2.497310    -0.584744     0.572798     2.520975
# ...           ...          ...          ...          ...
# 1387    -2.665369    -0.609325     0.613720     2.598740
# 1388    -2.278077    -0.640838     0.704874     2.313151
# 1390    -2.665598    -0.627511     0.665772     2.597974
# 1393    -2.222298    -0.628654     0.710430     2.242316
# 1400    -2.771649    -0.647159     0.685676     2.757304
#
#       BCUT_SLOGP_0_per_atom  ...  vsurf_Wp2_per_atom  vsurf_Wp3  vsurf_Wp4  \
# 11                -0.058225  ...           11.610465    168.000     48.375
# 23                -0.062669  ...            9.578125    146.750     31.875
# 24                -0.067042  ...            9.616279     96.000     15.375
# 25                -0.047121  ...            9.049603    180.875     38.250
# 28                -0.059585  ...           10.409884     99.875     17.500
# ...                     ...  ...                 ...        ...        ...
# 1387              -0.047138  ...            8.269068    113.875     21.625
# 1388              -0.055444  ...           11.431250    105.375     16.375
# 1390              -0.051504  ...            9.942130    183.000     51.250
# 1393              -0.062067  ...           13.060714     99.875     16.875
# 1400              -0.043880  ...            8.811508    178.125     58.125
#
#       vsurf_Wp5  vsurf_Wp6  vsurf_Wp7  vsurf_Wp8  weinerPath  \
# 11       19.750      6.375      0.875       0.00        1056
# 23       11.625      2.625      0.625       0.00        3020
# 24        5.625      1.250      0.000       0.00        1171
# 25       14.125      3.875      0.125       0.00        3447
# 28        7.500      2.375      0.125       0.00        1693
# ...         ...        ...        ...        ...         ...
# 1387      8.125      2.500      0.000       0.00        3816
# 1388      6.375      1.625      0.000       0.00        1496
# 1390     19.625      5.625      0.125       0.00        3068
# 1393      7.000      2.125      0.000       0.00        1124
# 1400     27.500     12.000      3.875       0.25        4039
#
#       weinerPol_per_atom  zagreb_per_atom
# 11              0.976744         3.116279
# 23              0.857143         2.857143
# 24              0.860465         2.790698
# 25              0.857143         2.825397
# 28              1.093023         3.395349
# ...                  ...              ...
# 1387            0.881356         3.016949
# 1388            1.100000         3.700000
# 1390            0.888889         2.962963
# 1393            0.857143         3.428571
# 1400            0.698413         2.666667
#
# [280 rows x 306 columns]
# active
# 0    264
# 1     16
# Name: count, dtype: int64
# (1124, 306)
# active
# 0    1059
# 1      65
# Name: count, dtype: int64
# (248, 310)
# (989, 310)
#       ASA+_per_atom       ASA-  ASA_H_per_atom      ASA_P  ASA_per_atom  \
# 1          5.994013  175.26022        9.389342  160.19148     12.411823
# 14         8.143989  172.74998        8.340377  158.41364     10.510427
# 15         7.558447  275.62744       10.419536  185.81779     15.728617
# 18         7.640180  209.40883        9.224951  131.75505     11.913830
# 27        10.034180  194.92766       11.159462  154.57048     14.929475
# ...             ...        ...             ...        ...           ...
# 1211       9.364868  148.06656        9.751122  122.57384     11.608300
# 1218       9.508312  134.60069        8.863824  177.13689     11.547717
# 1221       8.014165  278.35916        9.845626  181.29170     13.266225
# 1224       9.103675  200.99684        9.508262  174.29413     12.149082
# 1229       8.277690  283.83401        9.268148  237.64000     14.020948
#
#       BCUT_PEOE_0  BCUT_PEOE_1  BCUT_PEOE_2  BCUT_PEOE_3  \
# 1       -2.771648    -0.577210     0.571201     2.757304
# 14      -2.761202    -0.605943     0.736091     2.765514
# 15      -2.267313    -0.722016     0.690390     2.228887
# 18      -2.534188    -0.638915     0.706667     2.705784
# 27      -2.472854    -0.686740     0.731408     2.491220
# ...           ...          ...          ...          ...
# 1211    -2.537512    -0.599106     0.504315     2.707295
# 1218    -2.665385    -0.478010     0.442054     2.647204
# 1221    -2.441787    -0.582110     0.593952     2.439651
# 1224    -2.566612    -0.600858     0.577008     2.714610
# 1229    -2.318739    -0.635836     0.645020     2.756264
#
#       BCUT_SLOGP_0_per_atom  ...  vsurf_Wp2_per_atom  vsurf_Wp3  vsurf_Wp4  \
# 1                 -0.052158  ...            8.502358    131.625     39.500
# 14                -0.048581  ...           11.167808    314.375     84.125
# 15                -0.064243  ...           12.732143    115.250     17.500
# 18                -0.055374  ...            9.086735     94.375     19.375
# 27                -0.059509  ...           15.618902    214.250     54.125
# ...                     ...  ...                 ...        ...        ...
# 1211              -0.041365  ...            9.369318    173.875     60.000
# 1218              -0.042139  ...            9.153409    164.750     28.250
# 1221              -0.046212  ...           11.514151    157.250     27.875
# 1224              -0.042108  ...            8.604167    140.750     33.000
# 1229              -0.050437  ...            9.895000    141.750     33.625
#
#       vsurf_Wp5  vsurf_Wp6  vsurf_Wp7  vsurf_Wp8  weinerPath  \
# 1        16.500      4.875      0.000      0.000        2284
# 14       29.750      5.875      0.125      0.000        6535
# 15        6.000      2.125      0.000      0.000        1462
# 18        8.625      3.500      0.750      0.000        2904
# 27       22.500      6.500      0.875      0.000        1705
# ...         ...        ...        ...        ...         ...
# 1211     29.625     13.875      5.125      0.375        4841
# 1218     10.250      2.625      0.000      0.000        3842
# 1221     10.250      3.000      0.125      0.000        3401
# 1224     12.875      3.750      0.250      0.000        5121
# 1229     13.750      4.625      0.250      0.000        3061
#
#       weinerPol_per_atom  zagreb_per_atom
# 1               0.679245         2.566038
# 14              0.780822         2.821918
# 15              1.200000         3.885714
# 18              0.877551         3.183673
# 27              1.048780         3.560976
# ...                  ...              ...
# 1211            0.833333         2.787879
# 1218            0.969697         2.939394
# 1221            1.000000         3.433962
# 1224            0.909091         2.969697
# 1229            0.940000         3.320000
#
# [248 rows x 306 columns]
# active
# 0    228
# 1     20
# Name: count, dtype: int64
# (989, 306)
# active
# 0    912
# 1     77
# Name: count, dtype: int64
# (248, 310)
# (989, 310)
#       ASA+_per_atom       ASA-  ASA_H_per_atom      ASA_P  ASA_per_atom  \
# 2          9.052394  203.92502       12.865377  108.60042     17.209394
# 5          8.113001  256.92657        9.188730  216.04886     14.874227
# 6          6.756724  232.27261        8.051238  158.48526     10.831681
# 8          8.421641  253.13153       10.112097  180.44194     14.308420
# 9          7.646828  173.42555        8.803284  135.75764     11.631568
# ...             ...        ...             ...        ...           ...
# 1220       8.248162  158.60626        8.880183  115.62887     10.580607
# 1225       8.287183  254.54158        8.594911  246.01964     13.326058
# 1226       6.932258  257.92630        8.217948  167.92796     10.616919
# 1232       5.159087  223.60912        8.378988  176.98053     11.328663
# 1236       7.266205  231.48512        9.776360  108.96003     11.955562
#
#       BCUT_PEOE_0  BCUT_PEOE_1  BCUT_PEOE_2  BCUT_PEOE_3  \
# 2       -2.230777    -0.558488     0.626564     2.269167
# 5       -2.285914    -0.603387     0.680962     2.398444
# 6       -2.724012    -0.483202     0.522721     2.683994
# 8       -2.506317    -0.660031     0.662475     2.769528
# 9       -2.342459    -0.606049     0.650914     2.286108
# ...           ...          ...          ...          ...
# 1220    -2.538919    -0.541204     0.462140     2.707336
# 1225    -2.553973    -0.644236     0.697634     2.564650
# 1226    -2.333626    -0.657909     0.637603     2.311153
# 1232    -2.771648    -0.604474     0.652282     2.757304
# 1236    -2.517257    -0.649589     0.682544     2.455221
#
#       BCUT_SLOGP_0_per_atom  ...  vsurf_Wp2_per_atom  vsurf_Wp3  vsurf_Wp4  \
# 2                 -0.086605  ...           12.755000     27.750      0.000
# 5                 -0.063556  ...           11.141447    121.375     30.750
# 6                 -0.061305  ...            8.980263    171.125     42.250
# 8                 -0.078377  ...           14.779070    265.125     85.500
# 9                 -0.050099  ...           10.322917    160.875     46.375
# ...                     ...  ...                 ...        ...        ...
# 1220              -0.040152  ...            9.352941    184.750     57.375
# 1225              -0.063246  ...           14.475962    299.375     86.125
# 1226              -0.032895  ...            8.558929    145.625     27.125
# 1232              -0.046073  ...            9.075000    192.875     65.250
# 1236              -0.054187  ...            9.932500    117.125     36.500
#
#       vsurf_Wp5  vsurf_Wp6  vsurf_Wp7  vsurf_Wp8  weinerPath  \
# 2         0.000      0.000       0.00      0.000         500
# 5        12.375      4.250       0.25      0.000        1527
# 6        13.375      3.000       0.00      0.000        2452
# 8        34.125     10.250       0.00      0.000        1638
# 9        15.625      4.375       0.25      0.000        2315
# ...         ...        ...        ...        ...         ...
# 1220     28.375     14.500       6.50      3.125        4783
# 1225     30.500      6.500       0.50      0.000        2660
# 1226      9.625      2.125       0.00      0.000        7766
# 1232     32.625     14.250       6.75      2.750        3426
# 1236     17.375      7.250       1.25      0.000        3192
#
#       weinerPol_per_atom  zagreb_per_atom
# 2               1.040000         3.600000
# 5               1.026316         3.421053
# 6               0.807018         2.631579
# 8               0.906977         3.255814
# 9               0.916667         3.125000
# ...                  ...              ...
# ...
# 10         9.047011  173.58115        9.969411  140.112260     12.716710
# 13         8.625034  210.75249        9.844337  170.556720     14.453978
# 15         7.965699  205.62173        9.388618  118.127560     11.205966
# 16         7.368256  382.28207        9.299453  258.685490     13.341413
# ...             ...        ...             ...         ...           ...
# 1390       7.121467  305.15039        8.897802  173.701610     11.245121
# 1391       8.164441  293.74420       11.320729   93.388382     12.757474
# 1397       8.218877  164.34877        9.047612  118.050420     11.048466
# 1399       7.571245  263.85355        7.595244  262.437620     12.043339
# 1403       9.041518  149.92638        9.610198  121.696650     11.822865
#
#       BCUT_PEOE_0  BCUT_PEOE_1  BCUT_PEOE_2  BCUT_PEOE_3  \
# 2       -2.514189    -0.641112     0.704622     2.540930
# 10      -2.510440    -0.661898     0.749336     2.600872
# 13      -2.331102    -0.613577     0.672446     2.316037
# 15      -2.799085    -0.664211     0.720815     2.847422
# 16      -2.478194    -0.644858     0.624516     2.770415
# ...           ...          ...          ...          ...
# 1390    -2.657489    -0.649489     0.653458     2.600508
# 1391    -2.799085    -0.664465     0.719810     2.847422
# 1397    -2.361218    -0.587000     0.649607     2.323906
# 1399    -2.551524    -0.605494     0.696106     2.784320
# 1403    -2.326434    -0.584047     0.592415     2.374696
#
#       BCUT_SLOGP_0_per_atom  ...  vsurf_Wp2_per_atom  vsurf_Wp3  vsurf_Wp4  \
# 2                 -0.056876  ...           12.921512    179.000     49.875
# 10                -0.064877  ...           12.737745    212.375     62.750
# 13                -0.062438  ...           15.070946    174.375     49.625
# 15                -0.053531  ...            9.532692    157.375     34.250
# 16                -0.039415  ...           10.212891    158.875     25.625
# ...                     ...  ...                 ...        ...        ...
# 1390              -0.037590  ...            8.972973    165.250     30.500
# 1391              -0.053531  ...           10.861538    166.000     36.750
# 1397              -0.039875  ...            9.997881    180.000     48.000
# 1399              -0.051646  ...           10.495763    211.625     59.000
# 1403              -0.054630  ...            9.711364    178.500     45.625
#
#       vsurf_Wp5  vsurf_Wp6  vsurf_Wp7  vsurf_Wp8  weinerPath  \
# 2        21.750      6.875      0.875        0.0        1570
# 10       23.000      5.250      0.375        0.0        2657
# 13       20.000      6.375      0.625        0.0        1155
# 15       13.750      3.375      0.000        0.0        4574
# 16       10.125      2.750      0.000        0.0        6143
# ...         ...        ...        ...        ...         ...
# 1390     12.625      4.625      0.625        0.0        8185
# 1391     14.625      4.000      0.000        0.0        4863
# 1397     19.375      5.375      0.000        0.0        3952
# 1399     25.125      8.750      1.125        0.0        3547
# 1403     17.000      3.750      0.000        0.0        3034
#
#       weinerPol_per_atom  zagreb_per_atom
# 2               1.116279         3.441860
# 10              0.803922         2.941176
# 13              0.837838         3.243243
# 15              0.830769         2.953846
# 16              1.031250         3.406250
# ...                  ...              ...
# 1390            1.013514         3.297297
# 1391            0.876923         3.046154
# 1397            0.864407         2.881356
# 1399            0.932203         3.288136
# 1403            1.000000         3.200000
#
# [282 rows x 306 columns]
# active
# 0    270
# 1     12
# Name: count, dtype: int64
# (1127, 306)
# active
# 0    1078
# 1      49
# Name: count, dtype: int64
# (282, 310)
# (1127, 310)
#       ASA+_per_atom       ASA-  ASA_H_per_atom      ASA_P  ASA_per_atom  \
# 6          7.283914  224.05176        7.469044  209.42651     10.120012
# 12         7.981978  210.70854        9.054797  141.30231     11.163786
# 17        10.198786  148.00465       10.975819  121.58556     14.551865
# 20         7.259599  186.75813        6.054498  273.74100     12.420568
# 21         7.727154  156.12662        8.981752  109.77815     11.659268
# ...             ...        ...             ...        ...           ...
# 1375       6.927236  229.99966        8.184779  170.89514     11.820845
# 1379       9.182127  224.95250        9.254382  223.36211     13.468762
# 1400       6.559870  212.03343        9.315139  134.70073     11.453246
# 1405       7.939941  283.70764        9.863111  181.77962     13.292915
# 1406       7.542306  249.01140        9.443520  152.04947     12.424883
#
#       BCUT_PEOE_0  BCUT_PEOE_1  BCUT_PEOE_2  BCUT_PEOE_3  \
# 6       -2.664777    -0.641297     0.689109     2.598816
# 12      -2.722069    -0.649000     0.687332     2.785305
# 17      -2.406945    -0.618618     0.644789     2.375549
# 20      -2.809557    -0.559339     0.541926     2.801074
# 21      -2.659269    -0.575403     0.615370     2.745942
# ...           ...          ...          ...          ...
# 1375    -2.670776    -0.462990     0.502536     2.606068
# 1379    -2.665598    -0.635284     0.667129     2.597973
# 1400    -2.771649    -0.647159     0.685676     2.757304
# 1405    -2.441787    -0.582110     0.593952     2.439651
# 1406    -2.441789    -0.603292     0.570460     2.439688
#
#       BCUT_SLOGP_0_per_atom  ...  vsurf_Wp2_per_atom  vsurf_Wp3  vsurf_Wp4  \
# 6                 -0.043861  ...            8.642405    208.125     54.625
# 12                -0.051826  ...            9.867537    155.500     22.500
# 17                -0.068370  ...           11.091912     68.375     13.750
# 20                -0.067104  ...            9.252907     91.000     17.875
# 21                -0.082976  ...            9.844512    109.000     32.250
# ...                     ...  ...                 ...        ...        ...
# 1375              -0.059326  ...            7.087766     44.375      0.250
# 1379              -0.052476  ...           11.625000    171.500     35.125
# 1400              -0.043880  ...            8.809524    179.625     58.250
# 1405              -0.046212  ...           11.525943    155.250     27.125
# 1406              -0.048024  ...           10.120098    138.125     22.875
#
#       vsurf_Wp5  vsurf_Wp6  vsurf_Wp7  vsurf_Wp8  weinerPath  \
# 6        24.500      9.375      1.500       0.00        9015
# 12        7.500      1.875      0.000       0.00        6013
# 17        5.250      1.750      0.000       0.00         745
# 20        7.500      1.875      0.000       0.00        1682
# 21       12.500      2.125      0.000       0.00         936
# ...         ...        ...        ...        ...         ...
# 1375      0.000      0.000      0.000       0.00        2045
# 1379     12.125      3.375      0.000       0.00        3304
# 1400     28.125     12.125      3.875       0.25        4039
# 1405     10.250      3.500      0.125       0.00        3401
# 1406      7.625      1.875      0.000       0.00        2744
#
#       weinerPol_per_atom  zagreb_per_atom
# 6               0.822785         2.860759
# 12              0.895522         3.134328
# 17              0.794118         2.882353
# 20              0.976744         3.395349
# 21              1.024390         2.878049
# ...                  ...              ...
# 1375            1.000000         3.276596
# 1379            0.867925         2.981132
# 1400            0.698413         2.666667
# 1405            1.000000         3.433962
# 1406            1.019608         3.254902
#
# [282 rows x 306 columns]
# active
# 0    270
# 1     12
# Name: count, dtype: int64
# (1127, 306)
# active
# 0    1078
# 1      49
# Name: count, dtype: int64
# (281, 310)
# (1128, 310)
#       ASA+_per_atom       ASA-  ASA_H_per_atom       ASA_P  ASA_per_atom  \
# 0          7.883086  153.95410        8.725966  113.495890     11.090464
# 3          8.411578  222.33913       12.737668   66.599869     14.587665
# 4          8.287487  183.06439        7.755779  213.420750     13.228106
# 7          6.692531  237.76653        8.087123  133.172120      9.862751
# 22         6.452667  275.56476        7.350988  238.733610     13.173760
# ...             ...        ...             ...         ...           ...
# 1386       5.955156  299.83179        7.854027  193.495000     11.309295
# 1393       7.732639  211.90147        9.358958  119.201280     11.450209
# 1394       6.764417  205.41473        7.854536  124.745920      9.540291
# 1396       8.313942  281.27042        9.581525  228.031910     15.010857
# 1402       5.512654  330.02377        7.531693  188.691060     10.227279
#
#       BCUT_PEOE_0  BCUT_PEOE_1  BCUT_PEOE_2  BCUT_PEOE_3  \
# 0       -2.533041    -0.598235     0.619428     2.706484
# 3       -2.268596    -0.628702     0.710388     2.313735
# 4       -2.510290    -0.707746     0.723539     2.492597
# 7       -2.852835    -0.609622     0.693294     2.814569
# 22      -2.326806    -0.531548     0.565643     2.402646
# ...           ...          ...          ...          ...
# 1386    -2.313782    -0.644976     0.683974     2.370742
# 1393    -2.326086    -0.639025     0.723666     2.299159
# 1394    -2.678135    -0.532679     0.623648     2.789068
# 1396    -2.263985    -0.589319     0.613752     2.323931
# 1402    -2.495910    -0.703385     0.652720     2.580966
#
#       BCUT_SLOGP_0_per_atom  ...  vsurf_Wp2_per_atom  vsurf_Wp3  vsurf_Wp4  \
# 0                 -0.056552  ...            8.908854     93.000     17.250
# 3                 -0.062046  ...           10.170139     54.000      0.000
# 4                 -0.061396  ...           12.509615    154.750     53.125
# 7                 -0.046913  ...            7.600000    132.750     24.750
# 22                -0.055097  ...            8.609756     45.250      0.250
# ...                     ...  ...                 ...        ...        ...
# 1386              -0.042953  ...            9.645089    172.625     47.125
# 1393              -0.040865  ...           10.934211    199.500     60.625
# 1394              -0.046901  ...            8.271959    161.375     28.125
# 1396              -0.054176  ...           10.639881    103.875     18.500
# 1402              -0.038741  ...            9.400000    190.125     42.250
#
#       vsurf_Wp5  vsurf_Wp6  vsurf_Wp7  vsurf_Wp8  weinerPath  \
# 0         7.125      2.125      0.000        0.0        2364
# 3         0.000      0.000      0.000        0.0        1107
# 4        21.500      8.250      0.750        0.0        1108
# 7        11.000      4.500      0.750        0.0        6863
# 22        0.000      0.000      0.000        0.0        2331
# ...         ...        ...        ...        ...         ...
# 1386     18.625      5.250      0.125        0.0        6428
# 1393     25.250      6.750      0.000        0.0        4039
# 1394     12.375      3.875      0.250        0.0        5387
# 1396      8.000      2.500      0.000        0.0        2485
# 1402     16.500      5.250      0.625        0.0        8024
#
#       weinerPol_per_atom  zagreb_per_atom
# 0               0.812500         3.083333
# 3               1.027778         3.500000
# 4               1.000000         3.333333
# 7               0.946667         3.040000
# 22              1.024390         3.707317
# ...                  ...              ...
# 1386            1.035714         3.750000
# 1393            0.964912         3.192982
# 1394            0.702703         2.621622
# 1396            1.023810         3.714286
# 1402            1.042857         3.485714
#
# [281 rows x 306 columns]
# active
# 0    269
# 1     12
# Name: count, dtype: int64
# (1128, 306)
# active
# 0    1079
# 1      49
# Name: count, dtype: int64
# (281, 310)
# (1128, 310)
#       ASA+_per_atom       ASA-  ASA_H_per_atom      ASA_P  ASA_per_atom  \
# 11         6.597302  269.55774        9.289743  146.21255     12.400649
# 23         6.915927  279.08621        9.073022  165.46645     12.137215
# 24         7.622621  267.57904       10.796947  108.86273     12.974202
# 25         8.111009  207.80315        7.777934  230.07573     11.744756
# 28         8.158625  151.82555        7.851771  171.77100     10.494403
# ...             ...        ...             ...        ...           ...
# 1392       7.037028  211.23691        8.277765  123.83814      9.997739
# 1395       8.222930  249.58772        8.175062  252.65121     12.122738
# 1398       6.244014  210.93532        7.860112  206.42007     10.987688
# 1401       7.886995  172.40407        8.645343  131.45326     11.079662
# 1404       6.286192  292.03253        8.459011  163.83620     11.235896
#
#       BCUT_PEOE_0  BCUT_PEOE_1  BCUT_PEOE_2  BCUT_PEOE_3  \
# 11      -2.331276    -0.682637     0.689241     2.307407
# 23      -2.671957    -0.609988     0.691926     2.662334
# 24      -2.607322    -0.551579     0.657489     2.590046
# 25      -2.620959    -0.574410     0.694674     2.564265
# 28      -2.537300    -0.605920     0.528743     2.707309
# ...           ...          ...          ...          ...
# 1392    -2.799085    -0.653614     0.714373     2.847422
# 1395    -2.612446    -0.587720     0.300368     2.591770
# 1398    -2.771653    -0.593669     0.643923     2.757315
# 1401    -2.665598    -0.627511     0.665772     2.597974
# 1404    -2.313783    -0.644787     0.684021     2.370742
#
#       BCUT_SLOGP_0_per_atom  ...  vsurf_Wp2_per_atom  vsurf_Wp3  vsurf_Wp4  \
# 11                -0.046954  ...           10.797872    126.500     26.375
# 23                -0.063125  ...           11.432870    191.375     48.000
# 24                -0.050669  ...            8.627500     91.375     20.750
# 25                -0.059742  ...           10.803879    232.250     58.125
# 28                -0.042001  ...            9.338462    157.875     38.250
# ...                     ...  ...                 ...        ...        ...
# 1392              -0.048327  ...            8.171875    137.375     19.250
# 1395              -0.042196  ...            8.976562    146.500     30.625
# 1398              -0.041886  ...            7.537879    159.250     48.000
# 1401              -0.051504  ...            9.932870    183.250     51.500
# 1404              -0.040769  ...            9.317797    167.875     63.750
#
#       vsurf_Wp5  vsurf_Wp6  vsurf_Wp7  vsurf_Wp8  weinerPath  \
# 11        9.375      2.625      0.000        0.0        3108
# 23       18.750      3.250      0.000        0.0        2637
# 24        7.750      2.125      0.000        0.0        1749
# 25       23.125      6.500      0.250        0.0        3320
# 28       13.750      3.875      0.000        0.0        5228
# ...         ...        ...        ...        ...         ...
# 1392      6.875      1.875      0.000        0.0        5514
# 1395     12.250      4.000      0.250        0.0        5819
# 1398     22.000     10.125      1.875        0.0        4858
# 1401     19.625      5.625      0.125        0.0        3068
# 1404     29.625     11.250      2.875        0.0        6924
#
#       weinerPol_per_atom  zagreb_per_atom
# 11              0.978723         3.574468
# 23              0.814815         2.888889
# 24              0.740000         2.720000
# 25              0.896552         2.862069
# 28              0.876923         3.015385
# ...                  ...              ...
# 1392            0.847222         2.972222
# 1395            1.078125         3.343750
# 1398            0.757576         2.818182
# 1401            0.888889         2.962963
# 1404            1.033898         3.627119
#
# [281 rows x 306 columns]
# active
# 0    269
# 1     12
# Name: count, dtype: int64
# (1128, 306)
# active
# 0    1079
# 1      49
# Name: count, dtype: int64

# %%
# inhibition
method = "inhibition"
nekAll = ["2","9"]
foldAll = ["fold1","fold2","fold3","fold4","fold5"]

for nek in nekAll:
    # Get training data
    split_path = "/p/lustre2/fan4/NEK_data/NEK_data_4Berkeley/NEK"+nek
    random_df = pd.read_csv(split_path+"/NEK"+nek+"_1_uM_min_50_pct_"+method+"_5fold_random_imbalanced.csv")
    random_df.head

    moe_columns = random_df.columns[3:]
    moe_columns = moe_columns[:-1]
    moe_columns

    # Use the fold 0 as the test set, fold 1,2,3,4 as the train set
    for fold in foldAll:
        test_moe_df = random_df.loc[random_df['fold'] == fold]
        train_moe_df = random_df.loc[random_df['fold'] != fold]
        print(test_moe_df.shape)
        print(train_moe_df.shape)

        test_x_df = test_moe_df[moe_columns]
        test_y_df = test_moe_df['active']
        print(test_x_df)
        print(test_y_df.value_counts())

        train_x_df = train_moe_df[moe_columns]
        train_y_df = train_moe_df['active']
        print(train_x_df.shape)
        print(train_y_df.value_counts())


        # Save to file
        uq_path = "/p/lustre2/fan4/NEK_data/NEK_data_4Berkeley/NEK"+nek
        #uq_path = "/p/lustre2/fan4/myGPyTorch/classification_NEK/data/"

        train_x_df.to_csv(uq_path+"/NEK"+nek+"_"+method+"_random_"+fold+"_trainX.csv", index=False)
        train_y_df.to_csv(uq_path+"/NEK"+nek+"_"+method+"_random_"+fold+"_trainY.csv", index=False)
        test_x_df.to_csv(uq_path+"/NEK"+nek+"_"+method+"_random_"+fold+"_testX.csv", index=False)
        test_y_df.to_csv(uq_path+"/NEK"+nek+"_"+method+"_random_"+fold+"_testY.csv", index=False)
# Out:
# (409, 310)
# (1635, 310)
#       ASA+_per_atom       ASA-  ASA_H_per_atom      ASA_P  ASA_per_atom  \
# 1          7.934616  158.87631        7.420585  189.45982     10.865310
# 4          7.463830  237.68829       10.271510  108.22626     12.574197
# 5          8.182241  281.36035       11.570551  134.44797     14.558284
# 6          9.252768  169.27931       10.768620  118.69076     13.735889
# 9          8.561838  226.01562       10.099210  161.08264     13.601007
# ...             ...        ...             ...        ...           ...
# 2015       7.525463  138.65553        7.565813  140.20396      9.340547
# 2026       8.021498  323.03540        8.850160  277.65530     13.477749
# 2027       7.554388  255.61058        7.652859  252.85341     16.683338
# 2035       7.552055  179.63304        8.890672  104.67045     10.759787
# 2041       9.273098  136.72115        9.210555  140.78642     11.376500
#
#       BCUT_PEOE_0  BCUT_PEOE_1  BCUT_PEOE_2  BCUT_PEOE_3  \
# 1       -2.743183    -0.533248     0.614770     2.720497
# 4       -2.524593    -0.529721     0.607196     2.480697
# 5       -2.489196    -0.670815     0.669381     2.438753
# 6       -2.659860    -0.594148     0.651706     2.606751
# 9       -2.767401    -0.635034     0.619455     2.755650
# ...           ...          ...          ...          ...
# 2015    -2.864978    -0.527267     0.634660     2.864001
# 2026    -2.406214    -0.640363     0.703956     2.406396
# 2027    -2.245200    -0.667280     0.722810     2.316447
# 2035    -2.665601    -0.606444     0.660149     2.640098
# 2041    -2.771752    -0.532007     0.610847     2.732557
#
#       BCUT_SLOGP_0_per_atom  ...  vsurf_Wp2_per_atom  vsurf_Wp3  vsurf_Wp4  \
# 1                 -0.063273  ...           10.134091    163.375     31.750
# 4                 -0.055694  ...           11.364362    131.750     35.625
# 5                 -0.056731  ...           14.505556    186.375     49.625
# 6                 -0.069626  ...           10.403125     92.375     15.500
# 9                 -0.074390  ...           14.828804    252.750     79.000
# ...                     ...  ...                 ...        ...        ...
# 2015              -0.046161  ...            8.142405    181.000     35.375
# 2026              -0.040597  ...           12.235417    219.250     46.250
# 2027              -0.088240  ...           15.625000    116.000     29.250
# 2035              -0.049665  ...            8.187500    105.625     19.125
# 2041              -0.053955  ...            9.205769    161.375     23.000
#
#       vsurf_Wp5  vsurf_Wp6  vsurf_Wp7  vsurf_Wp8  weinerPath  \
# 1        11.375      3.125      0.125        0.0        2905
# 4        15.250      4.750      0.375        0.0        1925
# 5        19.500      5.125      0.125        0.0        2356
# 6         6.000      1.500      0.000        0.0        1233
# 9        35.125     13.750      5.125        1.5        1795
# ...         ...        ...        ...        ...         ...
# 2015     13.875      4.000      0.250        0.0        6409
# 2026     17.375      4.625      0.250        0.0        5692
# 2027     11.375      3.625      0.375        0.0         846
# 2035      8.000      1.875      0.000        0.0        3082
# 2041      7.000      1.375      0.000        0.0        3861
#
#       weinerPol_per_atom  zagreb_per_atom
# 1               0.909091         3.127273
# 4               1.148936         3.276596
# 5               0.933333         3.422222
# 6               0.875000         3.100000
# 9               0.869565         3.173913
# ...                  ...              ...
# 2015            0.962025         2.936709
# 2026            0.983333         3.366667
# 2027            1.035714         3.857143
# 2035            1.035714         3.250000
# 2041            1.000000         3.046154
#
# [409 rows x 306 columns]
# active
# 0    381
# 1     28
# Name: count, dtype: int64
# (1635, 306)
# active
# 0    1523
# 1     112
# Name: count, dtype: int64
# (409, 310)
# (1635, 310)
#       ASA+_per_atom       ASA-  ASA_H_per_atom      ASA_P  ASA_per_atom  \
# 2          8.484605  202.84538        9.316943  162.70578     12.507252
# 8          8.909427  165.23715        8.501627  194.38589     11.688280
# 13         9.003415  260.63043        4.795829  740.29523     11.289647
# 22         7.955508  233.50639        7.705778  251.11830     12.728143
# 29         5.903161  328.97800        9.438087  251.20963     20.856706
# ...             ...        ...             ...        ...           ...
# 2018       7.493446  128.02803        7.035855  167.44228      9.572859
# 2022       6.061657  329.63852       10.526571  115.32268     12.929127
# 2024       6.615774  291.43829        8.959462  127.38008     10.779177
# 2025       7.374209  220.87090        7.421318  223.26105     11.022303
# 2038       8.458617  145.24304        7.292164  205.89859     11.251753
#
#       BCUT_PEOE_0  BCUT_PEOE_1  BCUT_PEOE_2  BCUT_PEOE_3  \
# 2       -2.663910    -0.574060     0.591567     2.599414
# 8       -2.624192    -0.572714     0.599617     2.599538
# 13      -2.730885    -0.482043     0.516358     2.696097
# 22      -2.785494    -0.553310     0.668863     2.773533
# 29      -2.171314    -0.628195     0.569734     2.361153
# ...           ...          ...          ...          ...
# 2018    -2.788403    -0.568835     0.634648     2.750068
# 2022    -2.594704    -0.646343     0.698230     2.663032
# 2024    -2.443827    -0.636519     0.697364     2.626561
# 2025    -2.771667    -0.544989     0.632999     2.734574
# 2038    -2.320617    -0.643492     0.701088     2.411365
#
#       BCUT_SLOGP_0_per_atom  ...  vsurf_Wp2_per_atom  vsurf_Wp3  vsurf_Wp4  \
# 2                 -0.054526  ...           10.022059    145.000     33.500
# 8                 -0.053883  ...            9.956967    212.750     58.625
# 13                -0.030548  ...           16.708333   1034.750    412.250
# 22                -0.069033  ...           12.302500    212.625     56.625
# 29                -0.100442  ...           14.704545     85.000     15.750
# ...                     ...  ...                 ...        ...        ...
# 2018              -0.053244  ...            8.287879    169.500     34.125
# 2022              -0.053638  ...            8.950521     60.625      1.750
# 2024              -0.035270  ...            9.692857    178.500     32.875
# 2025              -0.056566  ...            9.816532    180.000     33.375
# 2038              -0.058117  ...           11.242788    226.500     74.000
#
#       vsurf_Wp5  vsurf_Wp6  vsurf_Wp7  vsurf_Wp8  weinerPath  \
# 2        12.500      3.875      0.000      0.000        1989
# 8        19.500      3.125      0.000      0.000        2938
# 13      217.125    110.875     56.250     23.125       18491
# 22       21.000      5.875      0.125      0.000        2343
# 29        5.875      1.500      0.000      0.000         550
# ...         ...        ...        ...        ...         ...
# 2018     13.500      3.125      0.000      0.000        4240
# 2022      0.000      0.000      0.000      0.000        2244
# 2024     12.375      3.250      0.000      0.000        7203
# 2025     11.625      2.625      0.000      0.000        4405
# 2038     31.875     14.500      5.250      1.875        2865
#
#       weinerPol_per_atom  zagreb_per_atom
# 2               0.803922         2.823529
# 8               0.754098         2.491803
# 13              0.666667         2.315789
# 22              0.960000         3.280000
# 29              1.272727         4.545455
# ...                  ...              ...
# 2018            1.015152         3.060606
# 2022            1.083333         3.291667
# 2024            0.957143         3.371429
# 2025            1.112903         3.419355
# 2038            1.000000         3.153846
#
# [409 rows x 306 columns]
# active
# 0    381
# 1     28
# Name: count, dtype: int64
# (1635, 306)
# active
# 0    1523
# 1     112
# Name: count, dtype: int64
# (409, 310)
# (1635, 310)
#       ASA+_per_atom       ASA-  ASA_H_per_atom      ASA_P  ASA_per_atom  \
# 10         9.703475  163.31120       11.247541  113.90109     14.806950
# 15         8.162067  189.85312        9.916524  105.75157     11.990085
# 16         7.608127  325.93158       11.055047  163.92630     14.542841
# 38         8.941737  218.81108       11.619250  103.73114     13.924387
# 44         8.815493  205.26054       10.491014  150.35580     14.786895
# ...             ...        ...             ...        ...           ...
# 2028       7.004943  211.50069        6.053876  274.27118     10.209500
# 2030       7.577481  297.31125        7.791531  288.48969     12.444591
# 2031       7.120121  195.58270        7.897255  147.40041     10.274681
# 2033       7.373997  242.25273        8.240083  197.96237     12.047052
# 2040       7.264791  196.14305        7.586167  182.00252     11.722588
#
#       BCUT_PEOE_0  BCUT_PEOE_1  BCUT_PEOE_2  BCUT_PEOE_3  \
# 10      -2.470160    -0.563589     0.420436     2.458867
# 15      -2.668645    -0.616341     0.684337     2.792577
# 16      -2.331142    -0.682387     0.689250     2.307145
# 38      -2.573330    -0.631480     0.705485     2.543256
# 44      -2.234988    -0.665101     0.739208     2.357255
# ...           ...          ...          ...          ...
# 2028    -2.657911    -0.553521     0.601612     2.636454
# 2030    -2.530909    -0.614108     0.654674     2.583203
# 2031    -2.749528    -0.670951     0.698023     2.757000
# 2033    -2.455553    -0.643509     0.684659     2.391380
# 2040    -2.342211    -0.624804     0.683706     2.278281
#
#       BCUT_SLOGP_0_per_atom  ...  vsurf_Wp2_per_atom  vsurf_Wp3  vsurf_Wp4  \
# 10                -0.078079  ...            7.863281     36.250      0.000
# 15                -0.067954  ...           10.450980    153.000     32.750
# 16                -0.046945  ...           12.220745    152.375     36.750
# 38                -0.056284  ...           11.919444    109.250     19.375
# 44                -0.063093  ...           13.517857    135.500     32.500
# ...                     ...  ...                 ...        ...        ...
# 2028              -0.052609  ...            9.842803    247.625     80.250
# 2030              -0.042062  ...           12.846774    309.125     75.000
# 2031              -0.054978  ...            9.945565    187.875     58.375
# 2033              -0.050092  ...           12.093750    253.250     87.750
# 2040              -0.054653  ...           12.522727    194.250     52.250
#
#       vsurf_Wp5  vsurf_Wp6  vsurf_Wp7  vsurf_Wp8  weinerPath  \
# 10        0.000      0.000      0.000      0.000         505
# 15       13.375      3.500      0.250      0.000        2381
# 16       14.000      4.500      0.750      0.000        3108
# 38        7.125      2.000      0.000      0.000        1804
# 44       13.000      3.375      0.000      0.000        1051
# ...         ...        ...        ...        ...         ...
# 2028     35.875     15.750      2.875      0.000        4412
# 2030     26.000      6.500      0.250      0.000        5383
# 2031     24.250      7.750      1.125      0.125        5003
# 2033     38.125     13.250      2.125      0.000        3368
# 2040     20.500      6.000      0.375      0.000        2124
#
#       weinerPol_per_atom  zagreb_per_atom
# 10              0.781250         2.687500
# 15              0.784314         3.019608
# 16              0.978723         3.574468
# 38              0.844444         3.022222
# 44              0.914286         3.428571
# ...                  ...              ...
# 2028            0.924242         3.030303
# 2030            1.032258         3.354839
# 2031            0.919355         3.129032
# 2033            0.980769         3.230769
# 2040            0.931818         3.272727
#
# [409 rows x 306 columns]
# active
# 0    381
# 1     28
# Name: count, dtype: int64
# (1635, 306)
# active
# 0    1523
# 1     112
# Name: count, dtype: int64
# (409, 310)
# (1635, 310)
#       ASA+_per_atom       ASA-  ASA_H_per_atom       ASA_P  ASA_per_atom  \
# 0         10.828989  121.34690       10.714393  124.440990     15.323319
# 3          6.847276  246.11134        8.917394  130.184710     11.242121
# 7          9.007080  211.36525       12.433657  123.350210     17.002184
# 12         9.210639  220.20757       14.834701   62.733829     17.075195
# 20         9.840159  204.23480       12.099922  131.922410     16.222498
# ...             ...        ...             ...         ...           ...
# 2012       7.195989  211.14612        8.421276  144.613800     11.050618
# 2023       7.600487  132.85730        7.883537  116.157370      9.852305
# 2029       7.663664  272.46390       10.050291  189.469210     14.671492
# 2032      10.058188  120.01466        9.615865  134.611300     13.694995
# 2037       8.319601  180.82919        8.728214  159.029740     11.101793
#
#       BCUT_PEOE_0  BCUT_PEOE_1  BCUT_PEOE_2  BCUT_PEOE_3  \
# 0       -2.513579    -0.604552     0.690716     2.510186
# 3       -2.754876    -0.641494     0.704588     2.755171
# 7       -2.102135    -0.677702     0.722369     2.220978
# 12      -2.279931    -0.642124     0.703745     2.257224
# 20      -2.556005    -0.440580     0.498074     2.496167
# ...           ...          ...          ...          ...
# 2012    -2.338827    -0.643509     0.701650     2.278920
# 2023    -2.771892    -0.604340     0.689597     2.732305
# 2029    -2.320111    -0.644557     0.702048     2.258586
# 2032    -2.626495    -0.485865     0.562799     2.584748
# 2037    -2.679096    -0.527291     0.575472     2.610034
#
#       BCUT_SLOGP_0_per_atom  ...  vsurf_Wp2_per_atom  vsurf_Wp3  vsurf_Wp4  \
# 0                 -0.099043  ...           13.648148    104.000     29.125
# 3                 -0.060868  ...            9.799107    130.625     18.500
# 7                 -0.072347  ...           15.305556    124.875     35.625
# 12                -0.080272  ...           11.312500     34.750      0.000
# 20                -0.080813  ...           12.378906    120.000     38.875
# ...                     ...  ...                 ...        ...        ...
# 2012              -0.043708  ...           10.170455    181.125     44.000
# 2023              -0.059442  ...            8.745763    136.500     26.375
# 2029              -0.058607  ...           13.993902    176.250     56.625
# 2032              -0.105015  ...            9.973485     85.625     19.625
# 2037              -0.041612  ...            8.729478    159.375     21.500
#
#       vsurf_Wp5  vsurf_Wp6  vsurf_Wp7  vsurf_Wp8  weinerPath  \
# 0        11.500      3.375      0.000        0.0         426
# 3         6.375      0.875      0.000        0.0        3565
# 7        14.375      4.625      0.250        0.0         675
# 12        0.000      0.000      0.000        0.0         630
# 20       15.750      3.750      0.000        0.0         645
# ...         ...        ...        ...        ...         ...
# 2012     15.000      3.875      0.125        0.0        3661
# 2023      9.750      2.125      0.000        0.0        3409
# 2029     22.750      6.375      0.625        0.0        1906
# 2032      6.625      1.625      0.000        0.0         494
# 2037      7.125      2.375      0.000        0.0        4603
#
#       weinerPol_per_atom  zagreb_per_atom
# 0               0.851852         3.185185
# 3               0.964286         3.250000
# 7               1.074074         4.000000
# 12              0.964286         3.428571
# 20              0.687500         2.812500
# ...                  ...              ...
# 2012            0.945455         3.272727
# 2023            1.016949         3.186441
# 2029            0.951220         3.365854
# 2032            0.818182         2.666667
# 2037            1.029851         3.223881
#
# [409 rows x 306 columns]
# active
# 0    381
# 1     28
# Name: count, dtype: int64
# (1635, 306)
# active
# 0    1523
# 1     112
# Name: count, dtype: int64
# (408, 310)
# (1636, 310)
#       ASA+_per_atom       ASA-  ASA_H_per_atom      ASA_P  ASA_per_atom  \
# 11         7.619515  228.86229        9.646632  126.73836     12.083908
# 23         8.393629  213.86617       11.114749  108.52623     13.761731
# 24         9.554990  119.35461        9.670249  114.51375     12.396766
# 25         8.842140  220.87392        9.367804  198.79604     14.101042
# 28         7.930079  209.54773        7.973012  212.30325     11.764142
# ...             ...        ...             ...        ...           ...
# 2034       6.904142  181.67436        7.016569  175.96358      9.394455
# 2036       8.112466  265.47824        9.769130  186.37447     13.496619
# 2039       6.803084  250.57068        8.309640  148.12486     10.487947
# 2042       7.466881  267.99036        8.378218  207.84203     11.527340
# 2043       8.012742  277.25531        7.568118  300.82034     13.243974
#
#       BCUT_PEOE_0  BCUT_PEOE_1  BCUT_PEOE_2  BCUT_PEOE_3  \
# 11      -2.809193    -0.553288     0.618718     2.773178
# 23      -2.785557    -0.629254     0.716855     2.725302
# 24      -2.328095    -0.595223     0.761024     2.353489
# 25      -2.319789    -0.745793     0.756554     2.271414
# 28      -2.764033    -0.550938     0.654687     2.736177
# ...           ...          ...          ...          ...
# 2034    -2.695497    -0.562492     0.640423     2.650519
# 2036    -2.371176    -0.599669     0.612282     2.310835
# 2039    -2.727067    -0.673099     0.659697     2.698536
# 2042    -2.812550    -0.552125     0.602776     2.795035
# 2043    -2.467217    -0.581729     0.625248     2.476072
#
#       BCUT_SLOGP_0_per_atom  ...  vsurf_Wp2_per_atom  vsurf_Wp3  vsurf_Wp4  \
# 11                -0.067723  ...           10.375000    165.750     44.500
# 23                -0.066330  ...           10.908537    118.125     24.250
# 24                -0.055856  ...           11.934524    172.125     62.875
# 25                -0.058546  ...           14.196429    212.000     64.500
# 28                -0.062627  ...           11.649554    215.875     49.875
# ...                     ...  ...                 ...        ...        ...
# 2034              -0.044412  ...           10.354730    308.625    100.375
# 2036              -0.048137  ...           11.537500    163.875     45.250
# 2039              -0.050457  ...           10.196691    212.375     46.750
# 2042              -0.052903  ...           10.037879    202.375     41.625
# 2043              -0.047780  ...           12.485849    210.375     54.000
#
#       vsurf_Wp5  vsurf_Wp6  vsurf_Wp7  vsurf_Wp8  weinerPath  \
# 11       18.500      5.625      0.125      0.000        2199
# 23        9.375      2.125      0.125      0.000        1211
# 24       27.500      7.875      0.000      0.000        1480
# 25       26.000      8.625      1.000      0.000        1692
# 28       18.000      3.375      0.000      0.000        2885
# ...         ...        ...        ...        ...         ...
# 2034     39.875     10.875      1.125      0.000        6106
# 2036     18.375      6.000      1.250      0.125        2535
# 2039     16.625      4.250      0.000      0.000        6127
# 2042     14.125      3.375      0.250      0.000        4452
# 2043     20.125      4.750      0.125      0.000        3738
#
#       weinerPol_per_atom  zagreb_per_atom
# 11              0.884615         3.038462
# 23              0.829268         3.024390
# 24              1.047619         3.190476
# 25              0.857143         3.047619
# 28              1.053571         3.357143
# ...                  ...              ...
# 2034            0.743243         2.567568
# 2036            0.920000         3.120000
# 2039            0.955882         3.058824
# 2042            0.863636         2.939394
# 2043            1.037736         3.283019
#
# [408 rows x 306 columns]
# active
# 0    380
# 1     28
# Name: count, dtype: int64
# (1636, 306)
# active
# 0    1524
# 1     112
# Name: count, dtype: int64
# (80, 310)
# (313, 310)
#      ASA+_per_atom       ASA-  ASA_H_per_atom       ASA_P  ASA_per_atom  \
# 6         8.374246  328.62073       11.542304  154.377530     14.349169
# 7         7.758642  244.31856        8.307437  228.265290     13.495285
# 15        8.195133  228.10043       10.528911  127.748020     13.499794
# 20        6.011307  307.66388        8.825967  127.525680     10.818555
# 26        8.396451  143.84105       10.291826   47.176929     11.216864
# ..             ...        ...             ...         ...           ...
# 378       7.901700  118.15869        7.773070  126.867940      9.923374
# 379       9.873726  135.60989        5.137539  362.946900     12.698933
# 381       7.490092  226.18387        8.357902  168.908430     10.917121
# 387       7.617204  248.43605        9.455220  154.697240     12.488499
# 388       7.386707  183.26013        6.687333  229.288560     10.214849
#
#      BCUT_PEOE_0  BCUT_PEOE_1  BCUT_PEOE_2  BCUT_PEOE_3  \
# 6      -2.331544    -0.658705     0.681410     2.307206
# 7      -2.432877    -0.619397     0.673476     2.770989
# 15     -2.494596    -0.585848     0.670067     2.536325
# 20     -2.618160    -0.658815     0.681439     2.675990
# 26     -2.765233    -0.612527     0.710465     2.748773
# ..           ...          ...          ...          ...
# 378    -2.771892    -0.604340     0.689597     2.732305
# 379    -2.549973    -0.374637     0.379556     2.562951
# 381    -2.812550    -0.552125     0.602776     2.795035
# 387    -2.441789    -0.603292     0.570460     2.439688
# 388    -2.771667    -0.544894     0.628043     2.734574
#
#      BCUT_SLOGP_0_per_atom  ...  vsurf_Wp2_per_atom  vsurf_Wp3  vsurf_Wp4  \
# 6                -0.046156  ...           11.827273    165.125     26.000
# 7                -0.057802  ...           12.272727    170.375     47.000
# 15               -0.058605  ...           10.084302     86.500     12.125
# 20               -0.052460  ...            9.667969    172.750     42.125
# 26               -0.068798  ...            7.735294     70.500      0.375
# ..                     ...  ...                 ...        ...        ...
# 378              -0.059442  ...            8.192797    125.375     26.625
# 379              -0.068502  ...           15.942708    359.125    107.875
# 381              -0.052903  ...            9.509470    165.500     38.500
# 387              -0.048024  ...           10.117647    138.000     23.000
# 388              -0.053955  ...            8.290385    151.625     32.500
#
#      vsurf_Wp5  vsurf_Wp6  vsurf_Wp7  vsurf_Wp8  weinerPath  \
# 6        9.875      1.750      0.125        0.0        4544
# 7       19.750      6.500      0.250        0.0        1904
# 15       4.625      1.625      0.000        0.0        1771
# 20      16.125      3.375      0.000        0.0        6306
# 26       0.000      0.000      0.000        0.0        1949
# ..         ...        ...        ...        ...         ...
# 378     11.375      3.500      0.125        0.0        3409
# 379     34.875      4.500      0.125        0.0        1610
# 381     14.000      3.875      0.250        0.0        4452
# 387      7.750      1.875      0.000        0.0        2744
# 388     13.125      3.375      0.000        0.0        4706
#
#      weinerPol_per_atom  zagreb_per_atom
# 6              0.945455         3.236364
# 7              0.863636         3.272727
# 15             0.930233         3.162791
# 20             0.875000         3.250000
# 26             0.764706         2.745098
# ..                  ...              ...
# 378            1.016949         3.186441
# 379            0.854167         2.750000
# 381            0.863636         2.939394
# 387            1.019608         3.254902
# 388            1.092308         3.323077
#
# [80 rows x 306 columns]
# active
# 0    71
# 1     9
# Name: count, dtype: int64
# (313, 306)
# active
# 0    280
# 1     33
# Name: count, dtype: int64
# (79, 310)
# (314, 310)
#      ASA+_per_atom       ASA-  ASA_H_per_atom       ASA_P  ASA_per_atom  \
# 1         8.584988  255.29848        9.869930  183.341670     13.143889
# 5         8.867048  181.31946        9.370875  167.430450     13.010667
# 8         9.482415  214.35144       13.958587   71.113968     16.180899
# 12        7.607816  304.18521       10.844918  143.639310     13.717705
# 17        7.102113  410.88959        8.947090  286.857850     13.045060
# ..             ...        ...             ...         ...           ...
# 373       9.660049  156.93013       10.041747  140.898820     13.396480
# 380       7.282692  275.65182        7.766187  242.290650     11.277645
# 382       8.039699  155.56841        7.579986  185.193070     10.566971
# 390       9.148384  172.83737        9.838884  130.716900     11.981783
# 392       6.766839  194.49434        6.565108  211.939940      9.825722
#
#      BCUT_PEOE_0  BCUT_PEOE_1  BCUT_PEOE_2  BCUT_PEOE_3  \
# 1      -2.429073    -0.628973     0.659947     2.373543
# 5      -2.787595    -0.543811     0.698352     2.790214
# 8      -2.323690    -0.643008     0.658479     2.270539
# 12     -2.444944    -0.633454     0.664447     2.782577
# 17     -2.612002    -0.605632     0.651995     2.681728
# ..           ...          ...          ...          ...
# 373    -2.311001    -0.594773     0.589194     2.270573
# 380    -2.812550    -0.518767     0.587567     2.795035
# 382    -2.771892    -0.604263     0.687459     2.732305
# 390    -2.771892    -0.534682     0.693423     2.732305
# 392    -2.788320    -0.536534     0.632993     2.751698
#
#      BCUT_SLOGP_0_per_atom  ...  vsurf_Wp2_per_atom  vsurf_Wp3  vsurf_Wp4  \
# 1                -0.043018  ...           10.593750    187.500     55.375
# 5                -0.075896  ...           11.888587    164.750     39.250
# 8                -0.079338  ...           11.269531     76.375     16.000
# 12               -0.052269  ...            9.702500    119.750     28.000
# 17               -0.047967  ...           10.496429    215.125     49.500
# ..                     ...  ...                 ...        ...        ...
# 373              -0.054182  ...           10.446429    114.125     18.375
# 380              -0.050603  ...            9.019928    174.375     37.375
# 382              -0.056566  ...            9.022177    162.250     32.875
# 390              -0.057493  ...            9.762295    138.625     26.000
# 392              -0.054063  ...            8.198077    154.375     37.125
#
#      vsurf_Wp5  vsurf_Wp6  vsurf_Wp7  vsurf_Wp8  weinerPath  \
# 1       18.125      4.000      0.000        0.0        4073
# 5       13.750      4.375      0.000        0.0        1591
# 8        6.000      1.875      0.125        0.0         782
# 12      10.875      4.000      0.375        0.0        2347
# 17      20.375      4.750      0.625        0.0        7719
# ..         ...        ...        ...        ...         ...
# 373      7.625      2.125      0.000        0.0        1757
# 380     13.500      3.750      0.250        0.0        5484
# 382     12.625      3.500      0.000        0.0        3663
# 390      9.750      3.000      0.375        0.0        3409
# 392     14.500      3.625      0.000        0.0        4800
#
#      weinerPol_per_atom  zagreb_per_atom
# 1              0.839286         3.035714
# 5              0.826087         2.913043
# 8              0.812500         2.875000
# 12             0.800000         2.960000
# 17             0.928571         3.285714
# ..                  ...              ...
# 373            0.952381         3.285714
# 380            0.913043         3.072464
# 382            1.000000         3.096774
# 390            0.983607         3.081967
# 392            1.092308         3.323077
#
# [79 rows x 306 columns]
# active
# 0    70
# 1     9
# Name: count, dtype: int64
# (314, 306)
# active
# 0    281
# 1     33
# Name: count, dtype: int64
# (78, 310)
# (315, 310)
#      ASA+_per_atom       ASA-  ASA_H_per_atom       ASA_P  ASA_per_atom  \
# 4         7.933414  219.04028        9.006277  149.355480     11.235464
# 16        7.097154  288.57471        8.719131  182.862350     11.448419
# 18        7.518355  194.65184        9.469836   81.465935     10.874421
# 27        8.312452  282.65628        9.274107  236.496860     14.201125
# 29        8.096133  226.83469       13.725744   35.427925     14.767741
# ..             ...        ...             ...         ...           ...
# 365       7.014045  317.37509        8.687913  233.681700     13.361547
# 367       7.376904  124.74966        6.921709  167.284730      9.456327
# 368       7.355366  256.03052        8.319663  206.851410     12.375573
# 383       8.562517  151.13855        9.137600  115.483370     11.000235
# 389       7.326045  245.15779        7.613341  232.735950     11.367146
#
#      BCUT_PEOE_0  BCUT_PEOE_1  BCUT_PEOE_2  BCUT_PEOE_3  \
# 4      -2.722069    -0.649000     0.687332     2.785305
# 16     -2.612002    -0.649000     0.693181     2.681728
# 18     -2.793984    -0.640839     0.704874     2.779629
# 27     -2.383669    -0.555612     0.530808     2.372793
# 29     -2.230744    -0.638733     0.704875     2.291979
# ..           ...          ...          ...          ...
# 365    -2.450229    -0.559399     0.568219     2.480439
# 367    -2.788403    -0.568835     0.634648     2.750068
# 368    -2.335487    -0.554463     0.554152     2.411413
# 383    -2.326717    -0.624913     0.623484     2.372989
# 389    -2.771667    -0.544989     0.632999     2.734574
#
#      BCUT_SLOGP_0_per_atom  ...  vsurf_Wp2_per_atom  vsurf_Wp3  vsurf_Wp4  \
# 4                -0.051826  ...            9.878731    154.000     22.250
# 16               -0.050114  ...           10.736940    201.375     40.125
# 18               -0.060161  ...            9.793103    158.875     36.125
# 27               -0.049871  ...            9.528646    114.250     18.875
# 29               -0.061856  ...           10.694853     49.500      0.000
# ..                     ...  ...                 ...        ...        ...
# 365              -0.048990  ...            9.862500    138.000     23.500
# 367              -0.053244  ...            8.373106    169.125     34.625
# 368              -0.047991  ...            9.715686    130.625     22.125
# 383              -0.048461  ...            8.929435    162.625     42.375
# 389              -0.056566  ...            9.727823    187.875     34.375
#
#      vsurf_Wp5  vsurf_Wp6  vsurf_Wp7  vsurf_Wp8  weinerPath  \
# 4        8.125      1.750       0.00        0.0        6013
# 16      13.875      2.750       0.00        0.0        6177
# 18      13.000      3.625       0.00        0.0        2907
# 27       8.500      3.125       0.25        0.0        2917
# 29       0.000      0.000       0.00        0.0         978
# ..         ...        ...        ...        ...         ...
# 365      8.125      1.875       0.25        0.0        2954
# 367     13.500      3.250       0.00        0.0        4240
# 368      7.250      1.750       0.00        0.0        3312
# 383     16.875      3.750       0.25        0.0        4354
# 389     13.250      3.125       0.00        0.0        4405
#
#      weinerPol_per_atom  zagreb_per_atom
# 4              0.895522         3.134328
# 16             0.850746         3.074627
# 18             0.862069         2.965517
# 27             1.020833         3.458333
# 29             1.029412         3.529412
# ..                  ...              ...
# 365            1.060000         3.480000
# 367            1.015152         3.060606
# 368            1.078431         3.490196
# 383            0.967742         3.096774
# 389            1.112903         3.419355
#
# [78 rows x 306 columns]
# active
# 0    70
# 1     8
# Name: count, dtype: int64
# (315, 306)
# active
# 0    281
# 1     34
# Name: count, dtype: int64
# (78, 310)
# (315, 310)
#      ASA+_per_atom       ASA-  ASA_H_per_atom       ASA_P  ASA_per_atom  \
# 0         7.198067  238.05016       10.308654   70.078506     11.606404
# 2         8.436406  242.07368        9.897842  167.642700     13.121741
# 3        10.045031  125.68558        8.381568  190.560610     13.267738
# 10        8.084502  255.44708        7.789168  266.374420     14.988476
# 11        8.568521  220.87935        9.312148  187.932590     12.997100
# ..             ...        ...             ...         ...           ...
# 375       9.567549  168.41643       10.600521  106.438110     12.374489
# 377       7.632904  161.98938        7.552203  170.207210     10.211691
# 384       7.843064  282.79941       10.644639  151.125410     13.860074
# 385       8.109280  243.94350       10.486092  129.856520     13.191437
# 386       8.332951  127.57986        7.626329  170.760010     10.570467
#
#      BCUT_PEOE_0  BCUT_PEOE_1  BCUT_PEOE_2  BCUT_PEOE_3  \
# 0      -2.754876    -0.652160     0.696727     2.755171
# 2      -2.564378    -0.515322     0.588656     2.782577
# 3      -2.450437    -0.614177     0.483119     2.663802
# 10     -2.334328    -0.623562     0.720114     2.369285
# 11     -2.389542    -0.580941     0.605389     2.365642
# ..           ...          ...          ...          ...
# 375    -2.665372    -0.573628     0.601246     2.640113
# 377    -2.797443    -0.653192     0.663100     2.774142
# 384    -2.441788    -0.600693     0.586668     2.439661
# 385    -2.314566    -0.613964     0.571433     2.320374
# 386    -2.752911    -0.527250     0.667225     2.743216
#
#      BCUT_SLOGP_0_per_atom  ...  vsurf_Wp2_per_atom  vsurf_Wp3  vsurf_Wp4  \
# 0                -0.063122  ...            9.268519    118.250     19.375
# 2                -0.051353  ...            8.401442    114.750     32.625
# 3                -0.064658  ...           10.471154    113.875     19.875
# 10               -0.069516  ...           16.945946    234.375     72.500
# 11               -0.050436  ...           11.267157    184.375     54.875
# ..                     ...  ...                 ...        ...        ...
# 375              -0.046353  ...            9.289583    125.875     14.125
# 377              -0.054526  ...            8.525391    147.250     32.500
# 384              -0.052112  ...           10.771277    132.750     22.750
# 385              -0.050989  ...           10.710938    128.875     19.750
# 386              -0.060481  ...            8.724138    128.625     25.375
#
#      vsurf_Wp5  vsurf_Wp6  vsurf_Wp7  vsurf_Wp8  weinerPath  \
# 0        5.000      0.500      0.000      0.000        3196
# 2       13.750      4.250      0.375      0.000        1889
# 3        7.375      2.000      0.125      0.000         965
# 10      29.750      9.875      0.875      0.000        1582
# 11      24.500     10.500      2.000      0.125        2679
# ..         ...        ...        ...        ...         ...
# 375      6.000      2.000      0.250      0.000        3517
# 377     12.000      2.750      0.000      0.000        3861
# 384      7.500      2.000      0.125      0.000        2276
# 385      6.250      1.375      0.250      0.000        2562
# 386      9.750      2.125      0.000      0.000        3474
#
#      weinerPol_per_atom  zagreb_per_atom
# 0              0.981481         3.296296
# 2              0.730769         2.576923
# 3              0.897436         3.128205
# 10             1.081081         3.783784
# 11             0.960784         3.215686
# ..                  ...              ...
# 375            1.050000         3.200000
# 377            1.015625         3.093750
# 384            1.000000         3.319149
# 385            1.020833         3.333333
# 386            0.965517         3.206897
#
# [78 rows x 306 columns]
# active
# 0    70
# 1     8
# Name: count, dtype: int64
# (315, 306)
# active
# 0    281
# 1     34
# Name: count, dtype: int64
# (78, 310)
# (315, 310)
#      ASA+_per_atom       ASA-  ASA_H_per_atom      ASA_P  ASA_per_atom  \
# 9         7.689045  283.49344        9.293339  228.94746     16.027087
# 25        8.576159  287.81873       11.474097  132.61452     13.929921
# 28        8.201295  198.85703        8.634501  184.34319     13.130676
# 31        9.033944  276.49051       10.662632  195.05614     14.563755
# 32        8.329972  206.15544       10.103390  125.64126     12.834722
# ..             ...        ...             ...        ...           ...
# 360       8.853831  230.00462        9.448083  198.22482     12.545346
# 370       7.609641  185.17105        8.089722  154.44589     10.502938
# 372       6.463862  255.59172        6.860234  241.69716     12.353352
# 374       7.851351  191.50912        9.422294  113.30672     11.560156
# 391       7.050497  258.01022        7.987365  206.48250     11.741592
#
#      BCUT_PEOE_0  BCUT_PEOE_1  BCUT_PEOE_2  BCUT_PEOE_3  \
# 9      -2.326767    -0.623328     0.720357     2.366596
# 25     -2.402980    -0.612854     0.633123     2.350243
# 28     -2.281963    -0.701319     0.753175     2.246323
# 31     -2.317931    -0.653677     0.686269     2.259077
# 32     -2.537413    -0.618915     0.698982     2.482202
# ..           ...          ...          ...          ...
# 360    -2.743642    -0.651901     0.619058     2.712534
# 370    -2.788525    -0.534486     0.693295     2.749863
# 372    -2.403222    -0.644114     0.636794     2.451830
# 374    -2.657490    -0.645162     0.633709     2.600510
# 391    -2.509107    -0.611979     0.617741     2.534711
#
#      BCUT_SLOGP_0_per_atom  ...  vsurf_Wp2_per_atom  vsurf_Wp3  vsurf_Wp4  \
# 9                -0.075649  ...           16.849265    214.125     74.750
# 25               -0.045864  ...            9.710648     93.875     15.125
# 28               -0.059974  ...           14.896341    224.625     78.625
# 31               -0.048053  ...           13.465000    205.625     59.375
# 32               -0.051658  ...           10.676630     97.625     16.125
# ..                     ...  ...                 ...        ...        ...
# 360              -0.043693  ...           11.376953    212.000     44.750
# 370              -0.054908  ...            8.925781    142.375     30.625
# 372              -0.056790  ...            9.122159     86.000     15.500
# 374              -0.052485  ...            8.750000    105.250     18.875
# 391              -0.048708  ...           10.181818    149.500     33.375
#
#      vsurf_Wp5  vsurf_Wp6  vsurf_Wp7  vsurf_Wp8  weinerPath  \
# 9       31.000     10.250      1.250       0.00        1303
# 25       6.375      2.750      0.375       0.00        3217
# 28      33.750     10.625      1.125       0.00        1829
# 31      28.500     11.125      4.250       0.75        3403
# 32       6.375      1.625      0.000       0.00        1760
# ..         ...        ...        ...        ...         ...
# 360     17.500      6.125      0.625       0.00        4621
# 370     11.625      2.500      0.000       0.00        3769
# 372      6.875      1.625      0.000       0.00        2258
# 374      7.625      2.500      0.125       0.00        3082
# 391     12.500      3.375      0.125       0.00        3406
#
#      weinerPol_per_atom  zagreb_per_atom
# 9              1.029412         3.647059
# 25             0.870370         3.000000
# 28             0.926829         3.365854
# 31             0.860000         3.200000
# 32             0.869565         3.000000
# ..                  ...              ...
# 360            1.078125         3.250000
# 370            0.968750         3.000000
# 372            1.136364         3.727273
# 374            1.094340         3.433962
# 391            0.945455         3.163636
#
# [78 rows x 306 columns]
# active
# 0    70
# 1     8
# Name: count, dtype: int64
# (315, 306)
# active
# 0    281
# 1     34
# Name: count, dtype: int64
